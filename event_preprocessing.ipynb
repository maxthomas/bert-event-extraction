# %%
#!/usr/bin/env python3

import sys
import os
import logging
import json
import spacy
from stanfordcorenlp import StanfordCoreNLP
from preproc.tokens import find_token_index, fix_entity_index, fix_entity_indices, get_stanford_core_data, verify_result

import glob 
import pandas as pd

#from tqdm import tqdm
# from main import find_token_index
# from _parser import Parser
# import main

# %%
nlp = spacy.load('en_core_web_lg', disable=["tagger", "parser"])
max_length = os.getenv("MAX_DOCUMENT_LENGTH")
if max_length:
    nlp.max_length = int(max_length)

# %%
globbed_files = glob.glob("/Users/chilv/Documents/proj-wm/bias-stance/bias_stance/MITRE Six-Twelve Month and November Docs CDRs/*.cdr")
data = []
for one_file in globbed_files:
    frame = pd.read_json(one_file, lines=True)
    data.append(frame)

# %%
cdr_data = pd.concat(data, ignore_index = True, sort = False);

# %%
sentencizer = nlp.create_pipe("sentencizer")
nlp.add_pipe(sentencizer)

# %%
text = "jewell just got married to max."

# %%
txt = cdr_data['extracted_text'][120]

# %%
txt = txt.replace('\n',' ')

# %%
# def remove_line_breaks(doc):
#     cleaned_doc = doc.replace('/n', ' ')
#     return cleaned_doc

# %%
# txt = remove_line_breaks(txt)

# %%
doc = nlp(txt)

# %%
def sentence_dict_list(doc):
    """Returns a list of dictionaries for each sentence in a CDR.
    This is just a few of those necessary for the model.
    """
    sentences = []
    for sent in doc.sents:
        sentence_dict = {}
        sentence_dict['sentence'] = sent.text
        sentence_dict['position'] = [sent.start_char, sent.end_char]
        entities = []
        for ent in sent.ents:
            entity_dict = {}
            entity_dict['text'] = ent.text
            entity_dict['position'] = [ent.start_char, ent.end_char]
            entity_dict['entity-type'] = ent.label_
            entities.append(entity_dict)
        sentence_dict['golden-entity-mentions'] = entities
        sentence_dict['golden-event-mentions'] = []
        sentences.append(sentence_dict)
    return sentences

# %%
sentences = sentence_dict_list(doc)
sentences
# Out:
# [{'sentence': 'HOTSPOTS ?',
#   'position': [0, 10],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'JUNE 2017  (228 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [11, 58],
#   'golden-entity-mentions': [{'text': 'JUNE 2017',
#     'position': [11, 20],
#     'entity-type': 'DATE'},
#    {'text': '228', 'position': [23, 26], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'MAY 2015 (97 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [59, 103],
#   'golden-entity-mentions': [{'text': 'MAY 2015',
#     'position': [59, 67],
#     'entity-type': 'DATE'},
#    {'text': '97', 'position': [69, 71], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'AUGUST 2015 (142 Priority 1 woredas)  The number of woredas (districts) requiring urgent humanitarian response has returned to levels not seen since the height of El Ni?o drought impacts in 2016, and have increased in terms of total number affected and those classified as Priority 1.',
#   'position': [104, 388],
#   'golden-entity-mentions': [{'text': 'AUGUST 2015',
#     'position': [104, 115],
#     'entity-type': 'DATE'},
#    {'text': '142', 'position': [117, 120], 'entity-type': 'CARDINAL'},
#    {'text': '1', 'position': [130, 131], 'entity-type': 'CARDINAL'},
#    {'text': 'El Ni?o', 'position': [267, 274], 'entity-type': 'LOC'},
#    {'text': '2016', 'position': [294, 298], 'entity-type': 'DATE'},
#    {'text': 'Priority 1', 'position': [377, 387], 'entity-type': 'LAW'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Of the 461 current hotspots, nearly half (228) are considered top priority.',
#   'position': [389, 464],
#   'golden-entity-mentions': [{'text': '461',
#     'position': [396, 399],
#     'entity-type': 'CARDINAL'},
#    {'text': 'nearly half', 'position': [418, 429], 'entity-type': 'CARDINAL'},
#    {'text': '228', 'position': [431, 434], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'From December 2016 to June 2017, the status of 102 woredas worsened while just 34 improved.',
#   'position': [465, 556],
#   'golden-entity-mentions': [{'text': 'December 2016 to June 2017',
#     'position': [470, 496],
#     'entity-type': 'DATE'},
#    {'text': '102', 'position': [512, 515], 'entity-type': 'CARDINAL'},
#    {'text': 'just 34', 'position': [539, 546], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': ' The 19% increase in Priority 1 woredas is largely due to prevailing drought conditions in southern and southeastern Ethiopia, where the October?December rains failed and the subsequent March?May rains were late, below average and erratic.',
#   'position': [557, 796],
#   'golden-entity-mentions': [{'text': '19%',
#     'position': [562, 565],
#     'entity-type': 'PERCENT'},
#    {'text': 'Priority 1', 'position': [578, 588], 'entity-type': 'LAW'},
#    {'text': 'Ethiopia', 'position': [674, 682], 'entity-type': 'GPE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'As a result, water and pasture availability is extremely low, significantly impacting livestock production, the main source of food and income for the majority of households in the affected areas.',
#   'position': [797, 993],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'Prices for livestock have plummeted, while nationally the cost of staple foods has increased.',
#   'position': [994, 1087],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'Livelihood response has generally been too little too late, and remains underfunded.',
#   'position': [1088, 1172],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'Insufficient coverage has contributed to a surge in food aid and nutrition needs, particularly in Somali Region.',
#   'position': [1173, 1285],
#   'golden-entity-mentions': [{'text': 'Somali Region',
#     'position': [1271, 1284],
#     'entity-type': 'LOC'}],
#   'golden-event-mentions': []},
#  {'sentence': ' As food reserves deplete and livestock body conditions decline, the ongoing long dry season in southern and southeastern pastoral areas is likely to be characterized by sustained and increasing vulnerability ?',
#   'position': [1286, 1496],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'especially in view of a possible pipeline break for food aid and nutrition support in July.',
#   'position': [1497, 1588],
#   'golden-entity-mentions': [{'text': 'July',
#     'position': [1583, 1587],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'In farming areas, belg harvests are expected to be below average due to poor rainfall, while the production of meher crops is threatened by the rapid spread of a devastating new crop pest, the fall armyworm.',
#   'position': [1589, 1796],
#   'golden-entity-mentions': [{'text': 'belg',
#     'position': [1607, 1611],
#     'entity-type': 'PERSON'},
#    {'text': 'meher crops', 'position': [1700, 1711], 'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': ' To prevent further deterioration in the food security situation, emergency livelihood support will remain critical through the rest of the year to protect remaining livestock assets and safeguard agricultural production.',
#   'position': [1797, 2018],
#   'golden-entity-mentions': [{'text': 'the year',
#     'position': [1933, 1941],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': ' Hotspot classification is derived using six multisector indicators, including agriculture, nutrition and markets, agreed at regional and federal levels.',
#   'position': [2019, 2172],
#   'golden-entity-mentions': [{'text': 'six',
#     'position': [2060, 2063],
#     'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'A hotspot matrix is often used as a proxy for the acute Integrated Food Security Phase Classification (IPC) and is indicative of food security and nutrition status.',
#   'position': [2173, 2337],
#   'golden-entity-mentions': [{'text': 'Integrated Food Security Phase Classification',
#     'position': [2229, 2274],
#     'entity-type': 'ORG'},
#    {'text': 'IPC', 'position': [2276, 2279], 'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Scaled from Priority 1 to 3, hotspot woredas require urgent humanitarian response.',
#   'position': [2338, 2420],
#   'golden-entity-mentions': [{'text': 'Priority 1 to 3',
#     'position': [2350, 2365],
#     'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': ' HOTSPOTS ?',
#   'position': [2421, 2432],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'DECEMBER 2015 (186 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [2433, 2483],
#   'golden-entity-mentions': [{'text': 'DECEMBER 2015',
#     'position': [2433, 2446],
#     'entity-type': 'DATE'},
#    {'text': '186', 'position': [2448, 2451], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'MARCH 2016 (224 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [2484, 2531],
#   'golden-entity-mentions': [{'text': 'MARCH 2016',
#     'position': [2484, 2494],
#     'entity-type': 'DATE'},
#    {'text': '224', 'position': [2496, 2499], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'JULY 2016 (205 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [2532, 2578],
#   'golden-entity-mentions': [{'text': 'JULY 2016',
#     'position': [2532, 2541],
#     'entity-type': 'DATE'},
#    {'text': '205', 'position': [2543, 2546], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'DECEMBER 2016  (192 Priority 1 woredas)  Feb-15 May-15 Aug-15 Dec-15 Mar-16 Jul-16 Dec-16 Jun-17  HOTSPOT CLASSIFICATION CHRONOLOGY (number of woredas)  Priority 1 Priority 2 Priority 3',
#   'position': [2579, 2764],
#   'golden-entity-mentions': [{'text': 'DECEMBER 2016',
#     'position': [2579, 2592],
#     'entity-type': 'DATE'},
#    {'text': '192', 'position': [2595, 2598], 'entity-type': 'CARDINAL'},
#    {'text': '3', 'position': [2763, 2764], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []}]

# %%
class StanfordNLP:
    """Getting Stanford running with necessary annotators"""
    def __init__(self, host='http://localhost', port=9000):
        self.nlp = StanfordCoreNLP(host, port=port,
                                   timeout=60000)  # , quiet=False, logging_level=logging.DEBUG)
        self.props = {
            'annotators': 'tokenize,ssplit,pos,lemma,parse',
            'pipelineLanguage': 'en',
            'outputFormat': 'json'
        }

    def annotate(self, sentence):
        return self.nlp.annotate(sentence, properties=self.props)

# %%
Snlp = StanfordNLP()

# %%
post11 = get_stanford_core_data(sentences, Snlp)

# %%
post11
# Out:
# [{'sentence': 'HOTSPOTS ?',
#   'position': [0, 10],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['HOTSPOTS', '?'],
#   'pos-tags': ['NNS', '.'],
#   'lemma': ['hotspot', '?'],
#   'parse': '(ROOT\n  (NP (NNS HOTSPOTS) (. ?)))'},
#  {'sentence': 'JUNE 2017  (228 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [11, 58],
#   'golden-entity-mentions': [{'text': 'JUNE 2017',
#     'position': [11, 20],
#     'entity-type': 'DATE'},
#    {'text': '228', 'position': [23, 26], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'dep/dep=8/gov=1',
#    'punct/dep=9/gov=0'],
#   'words': ['JUNE',
#    '2017',
#    '-LRB-',
#    '228',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'HOTSPOTS',
#    '?'],
#   'pos-tags': ['NNP',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    '-RRB-',
#    'NNS',
#    '.'],
#   'lemma': ['JUNE',
#    '2017',
#    '-lrb-',
#    '228',
#    'priority',
#    '1',
#    'woredas',
#    '-rrb-',
#    'hotspot',
#    '?'],
#   'parse': '(ROOT\n  (NP\n    (NP (NNP JUNE))\n    (NP\n      (NP (CD 2017))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 228) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'},
#  {'sentence': 'MAY 2015 (97 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [59, 103],
#   'golden-entity-mentions': [{'text': 'MAY 2015',
#     'position': [59, 67],
#     'entity-type': 'DATE'},
#    {'text': '97', 'position': [69, 71], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'dep/dep=8/gov=1',
#    'punct/dep=9/gov=0'],
#   'words': ['MAY',
#    '2015',
#    '-LRB-',
#    '97',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'HOTSPOTS',
#    '?'],
#   'pos-tags': ['NNP',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    '-RRB-',
#    'NNS',
#    '.'],
#   'lemma': ['MAY',
#    '2015',
#    '-lrb-',
#    '97',
#    'priority',
#    '1',
#    'woredas',
#    '-rrb-',
#    'hotspot',
#    '?'],
#   'parse': '(ROOT\n  (NP\n    (NP (NNP MAY))\n    (NP\n      (NP (CD 2015))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 97) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'},
#  {'sentence': 'AUGUST 2015 (142 Priority 1 woredas)  The number of woredas (districts) requiring urgent humanitarian response has returned to levels not seen since the height of El Ni?o drought impacts in 2016, and have increased in terms of total number affected and those classified as Priority 1.',
#   'position': [104, 388],
#   'golden-entity-mentions': [{'text': 'AUGUST 2015',
#     'position': [104, 115],
#     'entity-type': 'DATE'},
#    {'text': '142', 'position': [117, 120], 'entity-type': 'CARDINAL'},
#    {'text': '1', 'position': [130, 131], 'entity-type': 'CARDINAL'},
#    {'text': 'El Ni?o', 'position': [267, 274], 'entity-type': 'LOC'},
#    {'text': '2016', 'position': [294, 298], 'entity-type': 'DATE'},
#    {'text': 'Priority 1', 'position': [377, 387], 'entity-type': 'LAW'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=20/gov=-1',
#    'nsubj/dep=0/gov=20',
#    'nsubj/dep=0/gov=38',
#    'nummod/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=0',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'det/dep=8/gov=9',
#    'nsubj/dep=9/gov=15',
#    'case/dep=10/gov=11',
#    'nmod:of/dep=11/gov=9',
#    'punct/dep=12/gov=13',
#    'appos/dep=13/gov=11',
#    'punct/dep=14/gov=13',
#    'parataxis/dep=15/gov=20',
#    'amod/dep=16/gov=18',
#    'amod/dep=17/gov=18',
#    'dobj/dep=18/gov=15',
#    'aux/dep=19/gov=20',
#    'case/dep=21/gov=22',
#    'nmod:to/dep=22/gov=20',
#    'neg/dep=23/gov=24',
#    'acl/dep=24/gov=22',
#    'case/dep=25/gov=27',
#    'det/dep=26/gov=27',
#    'nmod:since/dep=27/gov=24',
#    'case/dep=28/gov=32',
#    'compound/dep=29/gov=32',
#    'compound/dep=30/gov=32',
#    'compound/dep=31/gov=32',
#    'nmod:of/dep=32/gov=27',
#    'case/dep=33/gov=34',
#    'nmod:in/dep=34/gov=27',
#    'punct/dep=35/gov=20',
#    'cc/dep=36/gov=20',
#    'aux/dep=37/gov=38',
#    'conj:and/dep=38/gov=20',
#    'case/dep=39/gov=40',
#    'nmod:in/dep=40/gov=38',
#    'case/dep=41/gov=43',
#    'amod/dep=42/gov=43',
#    'nmod:of/dep=43/gov=40',
#    'acl/dep=44/gov=43',
#    'cc/dep=45/gov=40',
#    'det/dep=46/gov=50',
#    'amod/dep=47/gov=50',
#    'case/dep=48/gov=49',
#    'nmod:as/dep=49/gov=47',
#    'nmod:in/dep=50/gov=38',
#    'conj:and/dep=50/gov=40',
#    'punct/dep=51/gov=20'],
#   'words': ['AUGUST',
#    '2015',
#    '-LRB-',
#    '142',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'The',
#    'number',
#    'of',
#    'woredas',
#    '-LRB-',
#    'districts',
#    '-RRB-',
#    'requiring',
#    'urgent',
#    'humanitarian',
#    'response',
#    'has',
#    'returned',
#    'to',
#    'levels',
#    'not',
#    'seen',
#    'since',
#    'the',
#    'height',
#    'of',
#    'El',
#    'Ni?o',
#    'drought',
#    'impacts',
#    'in',
#    '2016',
#    ',',
#    'and',
#    'have',
#    'increased',
#    'in',
#    'terms',
#    'of',
#    'total',
#    'number',
#    'affected',
#    'and',
#    'those',
#    'classified',
#    'as',
#    'Priority',
#    '1',
#    '.'],
#   'pos-tags': ['NNP',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NNS',
#    '-RRB-',
#    'DT',
#    'NN',
#    'IN',
#    'NNS',
#    '-LRB-',
#    'NNS',
#    '-RRB-',
#    'VBG',
#    'JJ',
#    'JJ',
#    'NN',
#    'VBZ',
#    'VBN',
#    'TO',
#    'NNS',
#    'RB',
#    'VBN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'NNP',
#    'NNP',
#    'NN',
#    'NNS',
#    'IN',
#    'CD',
#    ',',
#    'CC',
#    'VBP',
#    'VBN',
#    'IN',
#    'NNS',
#    'IN',
#    'JJ',
#    'NN',
#    'VBN',
#    'CC',
#    'DT',
#    'VBN',
#    'IN',
#    'NN',
#    'CD',
#    '.'],
#   'lemma': ['AUGUST',
#    '2015',
#    '-lrb-',
#    '142',
#    'priority',
#    '1',
#    'woreda',
#    '-rrb-',
#    'the',
#    'number',
#    'of',
#    'woreda',
#    '-lrb-',
#    'district',
#    '-rrb-',
#    'require',
#    'urgent',
#    'humanitarian',
#    'response',
#    'have',
#    'return',
#    'to',
#    'level',
#    'not',
#    'see',
#    'since',
#    'the',
#    'height',
#    'of',
#    'El',
#    'Ni?o',
#    'drought',
#    'impact',
#    'in',
#    '2016',
#    ',',
#    'and',
#    'have',
#    'increase',
#    'in',
#    'term',
#    'of',
#    'total',
#    'number',
#    'affect',
#    'and',
#    'those',
#    'classify',
#    'as',
#    'priority',
#    '1',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (NNP AUGUST) (CD 2015))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 142) (NN Priority))\n          (NP (CD 1) (NNS woredas)))\n        (-RRB- -RRB-)))\n    (PRN\n      (S\n        (NP\n          (NP (DT The) (NN number))\n          (PP (IN of)\n            (NP\n              (NP (NNS woredas))\n              (PRN (-LRB- -LRB-)\n                (NP (NNS districts))\n                (-RRB- -RRB-)))))\n        (VP (VBG requiring)\n          (NP (JJ urgent) (JJ humanitarian) (NN response)))))\n    (VP\n      (VP (VBZ has)\n        (VP (VBN returned)\n          (PP (TO to)\n            (NP\n              (NP (NNS levels))\n              (VP (RB not) (VBN seen)\n                (PP (IN since)\n                  (NP\n                    (NP (DT the) (NN height))\n                    (PP (IN of)\n                      (NP (NNP El) (NNP Ni?o) (NN drought) (NNS impacts)))\n                    (PP (IN in)\n                      (NP (CD 2016))))))))))\n      (, ,)\n      (CC and)\n      (VP (VBP have)\n        (VP (VBN increased)\n          (PP (IN in)\n            (NP\n              (NP\n                (NP (NNS terms))\n                (PP (IN of)\n                  (NP\n                    (NP (JJ total) (NN number))\n                    (VP (VBN affected)))))\n              (CC and)\n              (NP (DT those)\n                (ADJP (VBN classified)\n                  (PP (IN as)\n                    (NP (NN Priority))))\n                (CD 1)))))))\n    (. .)))'},
#  {'sentence': 'Of the 461 current hotspots, nearly half (228) are considered top priority.',
#   'position': [389, 464],
#   'golden-entity-mentions': [{'text': '461',
#     'position': [396, 399],
#     'entity-type': 'CARDINAL'},
#    {'text': 'nearly half', 'position': [418, 429], 'entity-type': 'CARDINAL'},
#    {'text': '228', 'position': [431, 434], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=12/gov=-1',
#    'case/dep=0/gov=4',
#    'det/dep=1/gov=4',
#    'nummod/dep=2/gov=4',
#    'amod/dep=3/gov=4',
#    'nmod:of/dep=4/gov=12',
#    'punct/dep=5/gov=12',
#    'advmod/dep=6/gov=7',
#    'nsubjpass/dep=7/gov=12',
#    'punct/dep=8/gov=9',
#    'dep/dep=9/gov=7',
#    'punct/dep=10/gov=9',
#    'auxpass/dep=11/gov=12',
#    'amod/dep=13/gov=14',
#    'dobj/dep=14/gov=12',
#    'punct/dep=15/gov=12'],
#   'words': ['Of',
#    'the',
#    '461',
#    'current',
#    'hotspots',
#    ',',
#    'nearly',
#    'half',
#    '-LRB-',
#    '228',
#    '-RRB-',
#    'are',
#    'considered',
#    'top',
#    'priority',
#    '.'],
#   'pos-tags': ['IN',
#    'DT',
#    'CD',
#    'JJ',
#    'NNS',
#    ',',
#    'RB',
#    'NN',
#    '-LRB-',
#    'CD',
#    '-RRB-',
#    'VBP',
#    'VBN',
#    'JJ',
#    'NN',
#    '.'],
#   'lemma': ['of',
#    'the',
#    '461',
#    'current',
#    'hotspot',
#    ',',
#    'nearly',
#    'half',
#    '-lrb-',
#    '228',
#    '-rrb-',
#    'be',
#    'consider',
#    'top',
#    'priority',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (PP (IN Of)\n      (NP (DT the) (CD 461) (JJ current) (NNS hotspots)))\n    (, ,)\n    (NP\n      (QP (RB nearly) (NN half))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (QP (CD 228)))\n        (-RRB- -RRB-)))\n    (VP (VBP are)\n      (VP (VBN considered)\n        (NP (JJ top) (NN priority))))\n    (. .)))'},
#  {'sentence': 'From December 2016 to June 2017, the status of 102 woredas worsened while just 34 improved.',
#   'position': [465, 556],
#   'golden-entity-mentions': [{'text': 'December 2016 to June 2017',
#     'position': [470, 496],
#     'entity-type': 'DATE'},
#    {'text': '102', 'position': [512, 515], 'entity-type': 'CARDINAL'},
#    {'text': 'just 34', 'position': [539, 546], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=12/gov=-1',
#    'case/dep=0/gov=1',
#    'nmod:from/dep=1/gov=12',
#    'nummod/dep=2/gov=1',
#    'case/dep=3/gov=4',
#    'nmod:to/dep=4/gov=1',
#    'nummod/dep=5/gov=4',
#    'punct/dep=6/gov=12',
#    'det/dep=7/gov=8',
#    'nsubj/dep=8/gov=12',
#    'case/dep=9/gov=11',
#    'nummod/dep=10/gov=11',
#    'nmod:of/dep=11/gov=8',
#    'mark/dep=13/gov=16',
#    'advmod/dep=14/gov=15',
#    'nsubj/dep=15/gov=16',
#    'advcl:while/dep=16/gov=12',
#    'punct/dep=17/gov=12'],
#   'words': ['From',
#    'December',
#    '2016',
#    'to',
#    'June',
#    '2017',
#    ',',
#    'the',
#    'status',
#    'of',
#    '102',
#    'woredas',
#    'worsened',
#    'while',
#    'just',
#    '34',
#    'improved',
#    '.'],
#   'pos-tags': ['IN',
#    'NNP',
#    'CD',
#    'TO',
#    'NNP',
#    'CD',
#    ',',
#    'DT',
#    'NN',
#    'IN',
#    'CD',
#    'NNS',
#    'VBD',
#    'IN',
#    'RB',
#    'CD',
#    'VBN',
#    '.'],
#   'lemma': ['from',
#    'December',
#    '2016',
#    'to',
#    'June',
#    '2017',
#    ',',
#    'the',
#    'status',
#    'of',
#    '102',
#    'woreda',
#    'worsen',
#    'while',
#    'just',
#    '34',
#    'improve',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (PP (IN From)\n      (NP\n        (NP (NNP December) (CD 2016))\n        (PP (TO to)\n          (NP (NNP June) (CD 2017)))))\n    (, ,)\n    (NP\n      (NP (DT the) (NN status))\n      (PP (IN of)\n        (NP (CD 102) (NNS woredas))))\n    (VP (VBD worsened)\n      (SBAR (IN while)\n        (S\n          (NP (RB just) (CD 34))\n          (VP (VBN improved)))))\n    (. .)))'},
#  {'sentence': ' The 19% increase in Priority 1 woredas is largely due to prevailing drought conditions in southern and southeastern Ethiopia, where the October?December rains failed and the subsequent March?May rains were late, below average and erratic.',
#   'position': [557, 796],
#   'golden-entity-mentions': [{'text': '19%',
#     'position': [562, 565],
#     'entity-type': 'PERCENT'},
#    {'text': 'Priority 1', 'position': [578, 588], 'entity-type': 'LAW'},
#    {'text': 'Ethiopia', 'position': [674, 682], 'entity-type': 'GPE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=10/gov=-1',
#    'det/dep=0/gov=3',
#    'compound/dep=1/gov=2',
#    'amod/dep=2/gov=3',
#    'nsubj/dep=3/gov=10',
#    'nsubj/dep=3/gov=37',
#    'case/dep=4/gov=7',
#    'compound/dep=5/gov=7',
#    'nummod/dep=6/gov=7',
#    'nmod:in/dep=7/gov=3',
#    'cop/dep=8/gov=10',
#    'advmod/dep=9/gov=10',
#    'case/dep=11/gov=14',
#    'amod/dep=12/gov=14',
#    'compound/dep=13/gov=14',
#    'nmod:to/dep=14/gov=10',
#    'case/dep=15/gov=19',
#    'amod/dep=16/gov=19',
#    'cc/dep=17/gov=16',
#    'conj:and/dep=18/gov=16',
#    'amod/dep=18/gov=19',
#    'nmod:in/dep=19/gov=14',
#    'punct/dep=20/gov=19',
#    'advmod/dep=21/gov=25',
#    'det/dep=22/gov=24',
#    'compound/dep=23/gov=24',
#    'nsubj/dep=24/gov=25',
#    'acl:relcl/dep=25/gov=19',
#    'cc/dep=26/gov=25',
#    'det/dep=27/gov=30',
#    'amod/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nsubj/dep=30/gov=35',
#    'cop/dep=31/gov=35',
#    'advmod/dep=32/gov=35',
#    'punct/dep=33/gov=35',
#    'case/dep=34/gov=35',
#    'acl:relcl/dep=35/gov=19',
#    'conj:and/dep=35/gov=25',
#    'cc/dep=36/gov=10',
#    'conj:and/dep=37/gov=10',
#    'punct/dep=38/gov=10'],
#   'words': ['The',
#    '19',
#    '%',
#    'increase',
#    'in',
#    'Priority',
#    '1',
#    'woredas',
#    'is',
#    'largely',
#    'due',
#    'to',
#    'prevailing',
#    'drought',
#    'conditions',
#    'in',
#    'southern',
#    'and',
#    'southeastern',
#    'Ethiopia',
#    ',',
#    'where',
#    'the',
#    'October?December',
#    'rains',
#    'failed',
#    'and',
#    'the',
#    'subsequent',
#    'March?May',
#    'rains',
#    'were',
#    'late',
#    ',',
#    'below',
#    'average',
#    'and',
#    'erratic',
#    '.'],
#   'pos-tags': ['DT',
#    'CD',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'CD',
#    'NN',
#    'VBZ',
#    'RB',
#    'JJ',
#    'TO',
#    'VBG',
#    'NN',
#    'NNS',
#    'IN',
#    'JJ',
#    'CC',
#    'JJ',
#    'NNP',
#    ',',
#    'WRB',
#    'DT',
#    'NN',
#    'NNS',
#    'VBD',
#    'CC',
#    'DT',
#    'JJ',
#    'NN',
#    'NNS',
#    'VBD',
#    'RB',
#    ',',
#    'IN',
#    'NN',
#    'CC',
#    'JJ',
#    '.'],
#   'lemma': ['the',
#    '19',
#    '%',
#    'increase',
#    'in',
#    'priority',
#    '1',
#    'woredas',
#    'be',
#    'largely',
#    'due',
#    'to',
#    'prevail',
#    'drought',
#    'condition',
#    'in',
#    'southern',
#    'and',
#    'southeastern',
#    'Ethiopia',
#    ',',
#    'where',
#    'the',
#    'october?december',
#    'rain',
#    'fail',
#    'and',
#    'the',
#    'subsequent',
#    'march?may',
#    'rain',
#    'be',
#    'late',
#    ',',
#    'below',
#    'average',
#    'and',
#    'erratic',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (DT The)\n        (ADJP (CD 19) (NN %))\n        (NN increase))\n      (PP (IN in)\n        (NP (NN Priority) (CD 1) (NN woredas))))\n    (VP (VBZ is)\n      (ADJP\n        (ADJP (RB largely) (JJ due)\n          (PP (TO to)\n            (NP\n              (NP (VBG prevailing) (NN drought) (NNS conditions))\n              (PP (IN in)\n                (NP\n                  (NP\n                    (ADJP (JJ southern)\n                      (CC and)\n                      (JJ southeastern))\n                    (NNP Ethiopia))\n                  (, ,)\n                  (SBAR\n                    (WHADVP (WRB where))\n                    (S\n                      (S\n                        (NP (DT the) (NN October?December) (NNS rains))\n                        (VP (VBD failed)))\n                      (CC and)\n                      (S\n                        (NP (DT the) (JJ subsequent) (NN March?May) (NNS rains))\n                        (VP (VBD were)\n                          (ADVP (RB late))\n                          (, ,)\n                          (PP (IN below)\n                            (NP (NN average))))))))))))\n        (CC and)\n        (ADJP (JJ erratic))))\n    (. .)))'},
#  {'sentence': 'As a result, water and pasture availability is extremely low, significantly impacting livestock production, the main source of food and income for the majority of households in the affected areas.',
#   'position': [797, 993],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=10/gov=-1',
#    'case/dep=0/gov=2',
#    'det/dep=1/gov=2',
#    'nmod:as/dep=2/gov=10',
#    'punct/dep=3/gov=10',
#    'compound/dep=4/gov=7',
#    'cc/dep=5/gov=4',
#    'conj:and/dep=6/gov=4',
#    'compound/dep=6/gov=7',
#    'nsubj/dep=7/gov=10',
#    'cop/dep=8/gov=10',
#    'advmod/dep=9/gov=10',
#    'punct/dep=11/gov=10',
#    'advmod/dep=12/gov=13',
#    'xcomp/dep=13/gov=10',
#    'compound/dep=14/gov=15',
#    'dobj/dep=15/gov=13',
#    'punct/dep=16/gov=15',
#    'det/dep=17/gov=19',
#    'amod/dep=18/gov=19',
#    'appos/dep=19/gov=15',
#    'case/dep=20/gov=21',
#    'nmod:of/dep=21/gov=19',
#    'cc/dep=22/gov=21',
#    'nmod:of/dep=23/gov=19',
#    'conj:and/dep=23/gov=21',
#    'case/dep=24/gov=26',
#    'det/dep=25/gov=26',
#    'nmod:for/dep=26/gov=13',
#    'case/dep=27/gov=28',
#    'nmod:of/dep=28/gov=26',
#    'case/dep=29/gov=32',
#    'det/dep=30/gov=32',
#    'amod/dep=31/gov=32',
#    'nmod:in/dep=32/gov=28',
#    'punct/dep=33/gov=10'],
#   'words': ['As',
#    'a',
#    'result',
#    ',',
#    'water',
#    'and',
#    'pasture',
#    'availability',
#    'is',
#    'extremely',
#    'low',
#    ',',
#    'significantly',
#    'impacting',
#    'livestock',
#    'production',
#    ',',
#    'the',
#    'main',
#    'source',
#    'of',
#    'food',
#    'and',
#    'income',
#    'for',
#    'the',
#    'majority',
#    'of',
#    'households',
#    'in',
#    'the',
#    'affected',
#    'areas',
#    '.'],
#   'pos-tags': ['IN',
#    'DT',
#    'NN',
#    ',',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'VBZ',
#    'RB',
#    'JJ',
#    ',',
#    'RB',
#    'VBG',
#    'NN',
#    'NN',
#    ',',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'NNS',
#    'IN',
#    'DT',
#    'VBN',
#    'NNS',
#    '.'],
#   'lemma': ['as',
#    'a',
#    'result',
#    ',',
#    'water',
#    'and',
#    'pasture',
#    'availability',
#    'be',
#    'extremely',
#    'low',
#    ',',
#    'significantly',
#    'impact',
#    'livestock',
#    'production',
#    ',',
#    'the',
#    'main',
#    'source',
#    'of',
#    'food',
#    'and',
#    'income',
#    'for',
#    'the',
#    'majority',
#    'of',
#    'household',
#    'in',
#    'the',
#    'affect',
#    'area',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (PP (IN As)\n      (NP (DT a) (NN result)))\n    (, ,)\n    (NP (NN water)\n      (CC and)\n      (NN pasture) (NN availability))\n    (VP (VBZ is)\n      (ADJP (RB extremely) (JJ low))\n      (, ,)\n      (S\n        (ADVP (RB significantly))\n        (VP (VBG impacting)\n          (NP\n            (NP (NN livestock) (NN production))\n            (, ,)\n            (NP\n              (NP (DT the) (JJ main) (NN source))\n              (PP (IN of)\n                (NP (NN food)\n                  (CC and)\n                  (NN income)))))\n          (PP (IN for)\n            (NP\n              (NP (DT the) (NN majority))\n              (PP (IN of)\n                (NP\n                  (NP (NNS households))\n                  (PP (IN in)\n                    (NP (DT the) (VBN affected) (NNS areas))))))))))\n    (. .)))'},
#  {'sentence': 'Prices for livestock have plummeted, while nationally the cost of staple foods has increased.',
#   'position': [994, 1087],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=4/gov=-1',
#    'nsubj/dep=0/gov=4',
#    'case/dep=1/gov=2',
#    'nmod:for/dep=2/gov=0',
#    'aux/dep=3/gov=4',
#    'punct/dep=5/gov=4',
#    'mark/dep=6/gov=14',
#    'advmod/dep=7/gov=14',
#    'det/dep=8/gov=9',
#    'nsubj/dep=9/gov=14',
#    'case/dep=10/gov=12',
#    'amod/dep=11/gov=12',
#    'nmod:of/dep=12/gov=9',
#    'aux/dep=13/gov=14',
#    'advcl:while/dep=14/gov=4',
#    'punct/dep=15/gov=4'],
#   'words': ['Prices',
#    'for',
#    'livestock',
#    'have',
#    'plummeted',
#    ',',
#    'while',
#    'nationally',
#    'the',
#    'cost',
#    'of',
#    'staple',
#    'foods',
#    'has',
#    'increased',
#    '.'],
#   'pos-tags': ['NNS',
#    'IN',
#    'NN',
#    'VBP',
#    'VBN',
#    ',',
#    'IN',
#    'RB',
#    'DT',
#    'NN',
#    'IN',
#    'JJ',
#    'NNS',
#    'VBZ',
#    'VBN',
#    '.'],
#   'lemma': ['price',
#    'for',
#    'livestock',
#    'have',
#    'plummet',
#    ',',
#    'while',
#    'nationally',
#    'the',
#    'cost',
#    'of',
#    'staple',
#    'food',
#    'have',
#    'increase',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (NNS Prices))\n      (PP (IN for)\n        (NP (NN livestock))))\n    (VP (VBP have)\n      (VP (VBN plummeted) (, ,)\n        (SBAR (IN while)\n          (S\n            (ADVP (RB nationally))\n            (NP\n              (NP (DT the) (NN cost))\n              (PP (IN of)\n                (NP (JJ staple) (NNS foods))))\n            (VP (VBZ has)\n              (VP (VBN increased)))))))\n    (. .)))'},
#  {'sentence': 'Livelihood response has generally been too little too late, and remains underfunded.',
#   'position': [1088, 1172],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=8/gov=-1',
#    'compound/dep=0/gov=1',
#    'nsubj/dep=1/gov=8',
#    'nsubj/dep=1/gov=11',
#    'aux/dep=2/gov=8',
#    'advmod/dep=3/gov=8',
#    'cop/dep=4/gov=8',
#    'advmod/dep=5/gov=8',
#    'advmod/dep=6/gov=8',
#    'advmod/dep=7/gov=8',
#    'punct/dep=9/gov=8',
#    'cc/dep=10/gov=8',
#    'conj:and/dep=11/gov=8',
#    'xcomp/dep=12/gov=11',
#    'punct/dep=13/gov=8'],
#   'words': ['Livelihood',
#    'response',
#    'has',
#    'generally',
#    'been',
#    'too',
#    'little',
#    'too',
#    'late',
#    ',',
#    'and',
#    'remains',
#    'underfunded',
#    '.'],
#   'pos-tags': ['NN',
#    'NN',
#    'VBZ',
#    'RB',
#    'VBN',
#    'RB',
#    'RB',
#    'RB',
#    'JJ',
#    ',',
#    'CC',
#    'VBZ',
#    'VBN',
#    '.'],
#   'lemma': ['livelihood',
#    'response',
#    'have',
#    'generally',
#    'be',
#    'too',
#    'little',
#    'too',
#    'late',
#    ',',
#    'and',
#    'remain',
#    'underfund',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP (NN Livelihood) (NN response))\n    (VP\n      (VP (VBZ has)\n        (ADVP (RB generally))\n        (VP (VBN been)\n          (ADVP (RB too))\n          (ADJP (RB little) (RB too) (JJ late))))\n      (, ,)\n      (CC and)\n      (VP (VBZ remains)\n        (VP (VBN underfunded))))\n    (. .)))'},
#  {'sentence': 'Insufficient coverage has contributed to a surge in food aid and nutrition needs, particularly in Somali Region.',
#   'position': [1173, 1285],
#   'golden-entity-mentions': [{'text': 'Somali Region',
#     'position': [1271, 1284],
#     'entity-type': 'LOC'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'amod/dep=0/gov=1',
#    'nsubj/dep=1/gov=3',
#    'aux/dep=2/gov=3',
#    'case/dep=4/gov=6',
#    'det/dep=5/gov=6',
#    'advcl:to/dep=6/gov=3',
#    'case/dep=7/gov=9',
#    'compound/dep=8/gov=9',
#    'nmod:in/dep=9/gov=6',
#    'cc/dep=10/gov=9',
#    'compound/dep=11/gov=12',
#    'nmod:in/dep=12/gov=6',
#    'conj:and/dep=12/gov=9',
#    'punct/dep=13/gov=6',
#    'dep/dep=14/gov=6',
#    'case/dep=15/gov=17',
#    'compound/dep=16/gov=17',
#    'nmod:in/dep=17/gov=6',
#    'punct/dep=18/gov=3'],
#   'words': ['Insufficient',
#    'coverage',
#    'has',
#    'contributed',
#    'to',
#    'a',
#    'surge',
#    'in',
#    'food',
#    'aid',
#    'and',
#    'nutrition',
#    'needs',
#    ',',
#    'particularly',
#    'in',
#    'Somali',
#    'Region',
#    '.'],
#   'pos-tags': ['JJ',
#    'NN',
#    'VBZ',
#    'VBN',
#    'TO',
#    'DT',
#    'NN',
#    'IN',
#    'NN',
#    'NN',
#    'CC',
#    'NN',
#    'NNS',
#    ',',
#    'RB',
#    'IN',
#    'NNP',
#    'NNP',
#    '.'],
#   'lemma': ['insufficient',
#    'coverage',
#    'have',
#    'contribute',
#    'to',
#    'a',
#    'surge',
#    'in',
#    'food',
#    'aid',
#    'and',
#    'nutrition',
#    'need',
#    ',',
#    'particularly',
#    'in',
#    'Somali',
#    'Region',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP (JJ Insufficient) (NN coverage))\n    (VP (VBZ has)\n      (VP (VBN contributed)\n        (PP\n          (PP (TO to)\n            (NP\n              (NP (DT a) (NN surge))\n              (PP (IN in)\n                (NP (NN food) (NN aid)\n                  (CC and)\n                  (NN nutrition) (NNS needs)))))\n          (, ,) (RB particularly)\n          (PP (IN in)\n            (NP (NNP Somali) (NNP Region))))))\n    (. .)))'},
#  {'sentence': ' As food reserves deplete and livestock body conditions decline, the ongoing long dry season in southern and southeastern pastoral areas is likely to be characterized by sustained and increasing vulnerability ?',
#   'position': [1286, 1496],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=22/gov=-1',
#    'mark/dep=0/gov=3',
#    'compound/dep=1/gov=2',
#    'nsubj/dep=2/gov=3',
#    'advcl:as/dep=3/gov=22',
#    'cc/dep=4/gov=3',
#    'compound/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'nsubj/dep=7/gov=8',
#    'conj:and/dep=8/gov=3',
#    'advcl:as/dep=8/gov=22',
#    'punct/dep=9/gov=22',
#    'det/dep=10/gov=14',
#    'amod/dep=11/gov=14',
#    'amod/dep=12/gov=14',
#    'amod/dep=13/gov=14',
#    'nsubj/dep=14/gov=22',
#    'nsubjpass:xsubj/dep=14/gov=25',
#    'case/dep=15/gov=20',
#    'amod/dep=16/gov=20',
#    'cc/dep=17/gov=16',
#    'conj:and/dep=18/gov=16',
#    'amod/dep=18/gov=20',
#    'amod/dep=19/gov=20',
#    'nmod:in/dep=20/gov=14',
#    'cop/dep=21/gov=22',
#    'mark/dep=23/gov=25',
#    'auxpass/dep=24/gov=25',
#    'xcomp/dep=25/gov=22',
#    'case/dep=26/gov=27',
#    'nmod:agent/dep=27/gov=25',
#    'cc/dep=28/gov=27',
#    'amod/dep=29/gov=30',
#    'nmod:agent/dep=30/gov=25',
#    'conj:and/dep=30/gov=27',
#    'punct/dep=31/gov=22'],
#   'words': ['As',
#    'food',
#    'reserves',
#    'deplete',
#    'and',
#    'livestock',
#    'body',
#    'conditions',
#    'decline',
#    ',',
#    'the',
#    'ongoing',
#    'long',
#    'dry',
#    'season',
#    'in',
#    'southern',
#    'and',
#    'southeastern',
#    'pastoral',
#    'areas',
#    'is',
#    'likely',
#    'to',
#    'be',
#    'characterized',
#    'by',
#    'sustained',
#    'and',
#    'increasing',
#    'vulnerability',
#    '?'],
#   'pos-tags': ['IN',
#    'NN',
#    'NNS',
#    'VBP',
#    'CC',
#    'NN',
#    'NN',
#    'NNS',
#    'VBP',
#    ',',
#    'DT',
#    'JJ',
#    'JJ',
#    'JJ',
#    'NN',
#    'IN',
#    'JJ',
#    'CC',
#    'JJ',
#    'JJ',
#    'NNS',
#    'VBZ',
#    'JJ',
#    'TO',
#    'VB',
#    'VBN',
#    'IN',
#    'JJ',
#    'CC',
#    'VBG',
#    'NN',
#    '.'],
#   'lemma': ['as',
#    'food',
#    'reserve',
#    'deplete',
#    'and',
#    'livestock',
#    'body',
#    'condition',
#    'decline',
#    ',',
#    'the',
#    'ongoing',
#    'long',
#    'dry',
#    'season',
#    'in',
#    'southern',
#    'and',
#    'southeastern',
#    'pastoral',
#    'area',
#    'be',
#    'likely',
#    'to',
#    'be',
#    'characterize',
#    'by',
#    'sustained',
#    'and',
#    'increase',
#    'vulnerability',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (SBAR (IN As)\n      (S\n        (S\n          (NP (NN food) (NNS reserves))\n          (VP (VBP deplete)))\n        (CC and)\n        (S\n          (NP (NN livestock) (NN body) (NNS conditions))\n          (VP (VBP decline)))))\n    (, ,)\n    (NP\n      (NP (DT the) (JJ ongoing) (JJ long) (JJ dry) (NN season))\n      (PP (IN in)\n        (NP (JJ southern)\n          (CC and)\n          (JJ southeastern) (JJ pastoral) (NNS areas))))\n    (VP (VBZ is)\n      (ADJP (JJ likely)\n        (S\n          (VP (TO to)\n            (VP (VB be)\n              (VP (VBN characterized)\n                (PP (IN by)\n                  (NP\n                    (NP (JJ sustained))\n                    (CC and)\n                    (NP (VBG increasing) (NN vulnerability))))))))))\n    (. ?)))'},
#  {'sentence': 'especially in view of a possible pipeline break for food aid and nutrition support in July.',
#   'position': [1497, 1588],
#   'golden-entity-mentions': [{'text': 'July',
#     'position': [1583, 1587],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=2/gov=-1',
#    'advmod/dep=0/gov=2',
#    'case/dep=1/gov=2',
#    'case/dep=3/gov=7',
#    'det/dep=4/gov=7',
#    'amod/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'nmod:of/dep=7/gov=2',
#    'case/dep=8/gov=10',
#    'compound/dep=9/gov=10',
#    'nmod:for/dep=10/gov=7',
#    'cc/dep=11/gov=10',
#    'compound/dep=12/gov=13',
#    'nmod:for/dep=13/gov=7',
#    'conj:and/dep=13/gov=10',
#    'case/dep=14/gov=15',
#    'nmod:in/dep=15/gov=10',
#    'punct/dep=16/gov=2'],
#   'words': ['especially',
#    'in',
#    'view',
#    'of',
#    'a',
#    'possible',
#    'pipeline',
#    'break',
#    'for',
#    'food',
#    'aid',
#    'and',
#    'nutrition',
#    'support',
#    'in',
#    'July',
#    '.'],
#   'pos-tags': ['RB',
#    'IN',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'IN',
#    'NNP',
#    '.'],
#   'lemma': ['especially',
#    'in',
#    'view',
#    'of',
#    'a',
#    'possible',
#    'pipeline',
#    'break',
#    'for',
#    'food',
#    'aid',
#    'and',
#    'nutrition',
#    'support',
#    'in',
#    'July',
#    '.'],
#   'parse': '(ROOT\n  (FRAG\n    (PP (RB especially) (IN in)\n      (NP\n        (NP (NN view))\n        (PP (IN of)\n          (NP\n            (NP (DT a) (JJ possible) (NN pipeline) (NN break))\n            (PP (IN for)\n              (NP\n                (NP (NN food) (NN aid)\n                  (CC and)\n                  (NN nutrition) (NN support))\n                (PP (IN in)\n                  (NP (NNP July)))))))))\n    (. .)))'},
#  {'sentence': 'In farming areas, belg harvests are expected to be below average due to poor rainfall, while the production of meher crops is threatened by the rapid spread of a devastating new crop pest, the fall armyworm.',
#   'position': [1589, 1796],
#   'golden-entity-mentions': [{'text': 'belg',
#     'position': [1607, 1611],
#     'entity-type': 'PERSON'},
#    {'text': 'meher crops', 'position': [1700, 1711], 'entity-type': 'ORG'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=7/gov=-1',
#    'mark/dep=0/gov=1',
#    'advcl:in/dep=1/gov=7',
#    'dobj/dep=2/gov=1',
#    'punct/dep=3/gov=7',
#    'compound/dep=4/gov=5',
#    'nsubjpass/dep=5/gov=7',
#    'nsubj:xsubj/dep=5/gov=11',
#    'auxpass/dep=6/gov=7',
#    'mark/dep=8/gov=11',
#    'cop/dep=9/gov=11',
#    'case/dep=10/gov=11',
#    'xcomp/dep=11/gov=7',
#    'amod/dep=12/gov=11',
#    'case/dep=13/gov=15',
#    'amod/dep=14/gov=15',
#    'nmod:to/dep=15/gov=12',
#    'punct/dep=16/gov=11',
#    'mark/dep=17/gov=24',
#    'det/dep=18/gov=19',
#    'nsubjpass/dep=19/gov=24',
#    'case/dep=20/gov=22',
#    'compound/dep=21/gov=22',
#    'nmod:of/dep=22/gov=19',
#    'auxpass/dep=23/gov=24',
#    'advcl:while/dep=24/gov=11',
#    'case/dep=25/gov=28',
#    'det/dep=26/gov=28',
#    'amod/dep=27/gov=28',
#    'nmod:agent/dep=28/gov=24',
#    'case/dep=29/gov=34',
#    'det/dep=30/gov=34',
#    'amod/dep=31/gov=34',
#    'amod/dep=32/gov=34',
#    'compound/dep=33/gov=34',
#    'nmod:of/dep=34/gov=28',
#    'punct/dep=35/gov=34',
#    'det/dep=36/gov=38',
#    'compound/dep=37/gov=38',
#    'appos/dep=38/gov=34',
#    'punct/dep=39/gov=7'],
#   'words': ['In',
#    'farming',
#    'areas',
#    ',',
#    'belg',
#    'harvests',
#    'are',
#    'expected',
#    'to',
#    'be',
#    'below',
#    'average',
#    'due',
#    'to',
#    'poor',
#    'rainfall',
#    ',',
#    'while',
#    'the',
#    'production',
#    'of',
#    'meher',
#    'crops',
#    'is',
#    'threatened',
#    'by',
#    'the',
#    'rapid',
#    'spread',
#    'of',
#    'a',
#    'devastating',
#    'new',
#    'crop',
#    'pest',
#    ',',
#    'the',
#    'fall',
#    'armyworm',
#    '.'],
#   'pos-tags': ['IN',
#    'VBG',
#    'NNS',
#    ',',
#    'NN',
#    'NNS',
#    'VBP',
#    'VBN',
#    'TO',
#    'VB',
#    'IN',
#    'NN',
#    'JJ',
#    'TO',
#    'JJ',
#    'NNS',
#    ',',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'NN',
#    'NNS',
#    'VBZ',
#    'VBN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'VBG',
#    'JJ',
#    'NN',
#    'NN',
#    ',',
#    'DT',
#    'NN',
#    'NN',
#    '.'],
#   'lemma': ['in',
#    'farm',
#    'area',
#    ',',
#    'belg',
#    'harvest',
#    'be',
#    'expect',
#    'to',
#    'be',
#    'below',
#    'average',
#    'due',
#    'to',
#    'poor',
#    'rainfall',
#    ',',
#    'while',
#    'the',
#    'production',
#    'of',
#    'meher',
#    'crop',
#    'be',
#    'threaten',
#    'by',
#    'the',
#    'rapid',
#    'spread',
#    'of',
#    'a',
#    'devastate',
#    'new',
#    'crop',
#    'pest',
#    ',',
#    'the',
#    'fall',
#    'armyworm',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (PP (IN In)\n      (S\n        (VP (VBG farming)\n          (NP (NNS areas)))))\n    (, ,)\n    (NP (NN belg) (NNS harvests))\n    (VP (VBP are)\n      (VP (VBN expected)\n        (S\n          (VP (TO to)\n            (VP (VB be)\n              (PP (IN below)\n                (NP\n                  (NP (NN average))\n                  (ADJP (JJ due)\n                    (PP (TO to)\n                      (NP (JJ poor) (NNS rainfall))))))\n              (, ,)\n              (SBAR (IN while)\n                (S\n                  (NP\n                    (NP (DT the) (NN production))\n                    (PP (IN of)\n                      (NP (NN meher) (NNS crops))))\n                  (VP (VBZ is)\n                    (VP (VBN threatened)\n                      (PP (IN by)\n                        (NP\n                          (NP (DT the) (JJ rapid) (NN spread))\n                          (PP (IN of)\n                            (NP\n                              (NP (DT a) (VBG devastating) (JJ new) (NN crop) (NN pest))\n                              (, ,)\n                              (NP (DT the) (NN fall) (NN armyworm)))))))))))))))\n    (. .)))'},
#  {'sentence': ' To prevent further deterioration in the food security situation, emergency livelihood support will remain critical through the rest of the year to protect remaining livestock assets and safeguard agricultural production.',
#   'position': [1797, 2018],
#   'golden-entity-mentions': [{'text': 'the year',
#     'position': [1933, 1941],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=14/gov=-1',
#    'mark/dep=0/gov=1',
#    'advcl:to/dep=1/gov=14',
#    'amod/dep=2/gov=3',
#    'dobj/dep=3/gov=1',
#    'case/dep=4/gov=8',
#    'det/dep=5/gov=8',
#    'compound/dep=6/gov=8',
#    'compound/dep=7/gov=8',
#    'nmod:in/dep=8/gov=1',
#    'punct/dep=9/gov=14',
#    'compound/dep=10/gov=12',
#    'compound/dep=11/gov=12',
#    'nsubj/dep=12/gov=14',
#    'nsubj:xsubj/dep=12/gov=23',
#    'nsubj:xsubj/dep=12/gov=28',
#    'aux/dep=13/gov=14',
#    'xcomp/dep=15/gov=14',
#    'case/dep=16/gov=18',
#    'det/dep=17/gov=18',
#    'nmod:through/dep=18/gov=15',
#    'case/dep=19/gov=21',
#    'det/dep=20/gov=21',
#    'nmod:of/dep=21/gov=18',
#    'mark/dep=22/gov=23',
#    'xcomp/dep=23/gov=14',
#    'amod/dep=24/gov=26',
#    'compound/dep=25/gov=26',
#    'dobj/dep=26/gov=23',
#    'cc/dep=27/gov=23',
#    'xcomp/dep=28/gov=14',
#    'conj:and/dep=28/gov=23',
#    'amod/dep=29/gov=30',
#    'dobj/dep=30/gov=28',
#    'punct/dep=31/gov=14'],
#   'words': ['To',
#    'prevent',
#    'further',
#    'deterioration',
#    'in',
#    'the',
#    'food',
#    'security',
#    'situation',
#    ',',
#    'emergency',
#    'livelihood',
#    'support',
#    'will',
#    'remain',
#    'critical',
#    'through',
#    'the',
#    'rest',
#    'of',
#    'the',
#    'year',
#    'to',
#    'protect',
#    'remaining',
#    'livestock',
#    'assets',
#    'and',
#    'safeguard',
#    'agricultural',
#    'production',
#    '.'],
#   'pos-tags': ['TO',
#    'VB',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'NN',
#    'NN',
#    ',',
#    'NN',
#    'NN',
#    'NN',
#    'MD',
#    'VB',
#    'JJ',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'TO',
#    'VB',
#    'VBG',
#    'NN',
#    'NNS',
#    'CC',
#    'VB',
#    'JJ',
#    'NN',
#    '.'],
#   'lemma': ['to',
#    'prevent',
#    'further',
#    'deterioration',
#    'in',
#    'the',
#    'food',
#    'security',
#    'situation',
#    ',',
#    'emergency',
#    'livelihood',
#    'support',
#    'will',
#    'remain',
#    'critical',
#    'through',
#    'the',
#    'rest',
#    'of',
#    'the',
#    'year',
#    'to',
#    'protect',
#    'remain',
#    'livestock',
#    'asset',
#    'and',
#    'safeguard',
#    'agricultural',
#    'production',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (S\n      (VP (TO To)\n        (VP (VB prevent)\n          (NP (JJ further) (NN deterioration))\n          (PP (IN in)\n            (NP (DT the) (NN food) (NN security) (NN situation))))))\n    (, ,)\n    (NP (NN emergency) (NN livelihood) (NN support))\n    (VP (MD will)\n      (VP (VB remain)\n        (ADJP (JJ critical)\n          (PP (IN through)\n            (NP\n              (NP (DT the) (NN rest))\n              (PP (IN of)\n                (NP (DT the) (NN year))))))\n        (S\n          (VP (TO to)\n            (VP\n              (VP (VB protect)\n                (NP (VBG remaining) (NN livestock) (NNS assets)))\n              (CC and)\n              (VP (VB safeguard)\n                (NP (JJ agricultural) (NN production))))))))\n    (. .)))'},
#  {'sentence': ' Hotspot classification is derived using six multisector indicators, including agriculture, nutrition and markets, agreed at regional and federal levels.',
#   'position': [2019, 2172],
#   'golden-entity-mentions': [{'text': 'six',
#     'position': [2060, 2063],
#     'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'compound/dep=0/gov=1',
#    'nsubjpass/dep=1/gov=3',
#    'auxpass/dep=2/gov=3',
#    'xcomp/dep=4/gov=3',
#    'nummod/dep=5/gov=7',
#    'amod/dep=6/gov=7',
#    'nsubj/dep=7/gov=16',
#    'punct/dep=8/gov=7',
#    'case/dep=9/gov=10',
#    'nmod:including/dep=10/gov=7',
#    'punct/dep=11/gov=10',
#    'nmod:including/dep=12/gov=7',
#    'conj:and/dep=12/gov=10',
#    'cc/dep=13/gov=10',
#    'nmod:including/dep=14/gov=7',
#    'conj:and/dep=14/gov=10',
#    'punct/dep=15/gov=7',
#    'ccomp/dep=16/gov=4',
#    'case/dep=17/gov=21',
#    'amod/dep=18/gov=21',
#    'cc/dep=19/gov=18',
#    'conj:and/dep=20/gov=18',
#    'amod/dep=20/gov=21',
#    'nmod:at/dep=21/gov=16',
#    'punct/dep=22/gov=3'],
#   'words': ['Hotspot',
#    'classification',
#    'is',
#    'derived',
#    'using',
#    'six',
#    'multisector',
#    'indicators',
#    ',',
#    'including',
#    'agriculture',
#    ',',
#    'nutrition',
#    'and',
#    'markets',
#    ',',
#    'agreed',
#    'at',
#    'regional',
#    'and',
#    'federal',
#    'levels',
#    '.'],
#   'pos-tags': ['NN',
#    'NN',
#    'VBZ',
#    'VBN',
#    'VBG',
#    'CD',
#    'JJ',
#    'NNS',
#    ',',
#    'VBG',
#    'NN',
#    ',',
#    'NN',
#    'CC',
#    'NNS',
#    ',',
#    'VBD',
#    'IN',
#    'JJ',
#    'CC',
#    'JJ',
#    'NNS',
#    '.'],
#   'lemma': ['hotspot',
#    'classification',
#    'be',
#    'derive',
#    'use',
#    'six',
#    'multisector',
#    'indicator',
#    ',',
#    'include',
#    'agriculture',
#    ',',
#    'nutrition',
#    'and',
#    'market',
#    ',',
#    'agree',
#    'at',
#    'regional',
#    'and',
#    'federal',
#    'level',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP (NN Hotspot) (NN classification))\n    (VP (VBZ is)\n      (VP (VBN derived)\n        (S\n          (VP (VBG using)\n            (SBAR\n              (S\n                (NP\n                  (NP (CD six) (JJ multisector) (NNS indicators))\n                  (, ,)\n                  (PP (VBG including)\n                    (NP (NN agriculture) (, ,) (NN nutrition)\n                      (CC and)\n                      (NNS markets)))\n                  (, ,))\n                (VP (VBD agreed)\n                  (PP (IN at)\n                    (NP (JJ regional)\n                      (CC and)\n                      (JJ federal) (NNS levels))))))))))\n    (. .)))'},
#  {'sentence': 'A hotspot matrix is often used as a proxy for the acute Integrated Food Security Phase Classification (IPC) and is indicative of food security and nutrition status.',
#   'position': [2173, 2337],
#   'golden-entity-mentions': [{'text': 'Integrated Food Security Phase Classification',
#     'position': [2229, 2274],
#     'entity-type': 'ORG'},
#    {'text': 'IPC', 'position': [2276, 2279], 'entity-type': 'ORG'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=5/gov=-1',
#    'det/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nsubjpass/dep=2/gov=5',
#    'nsubj/dep=2/gov=22',
#    'auxpass/dep=3/gov=5',
#    'advmod/dep=4/gov=5',
#    'case/dep=6/gov=8',
#    'det/dep=7/gov=8',
#    'nmod:as/dep=8/gov=5',
#    'case/dep=9/gov=16',
#    'det/dep=10/gov=16',
#    'amod/dep=11/gov=16',
#    'compound/dep=12/gov=16',
#    'compound/dep=13/gov=16',
#    'compound/dep=14/gov=16',
#    'compound/dep=15/gov=16',
#    'nmod:for/dep=16/gov=8',
#    'punct/dep=17/gov=18',
#    'appos/dep=18/gov=16',
#    'punct/dep=19/gov=18',
#    'cc/dep=20/gov=5',
#    'cop/dep=21/gov=22',
#    'conj:and/dep=22/gov=5',
#    'case/dep=23/gov=25',
#    'compound/dep=24/gov=25',
#    'nmod:of/dep=25/gov=22',
#    'cc/dep=26/gov=25',
#    'compound/dep=27/gov=28',
#    'nmod:of/dep=28/gov=22',
#    'conj:and/dep=28/gov=25',
#    'punct/dep=29/gov=5'],
#   'words': ['A',
#    'hotspot',
#    'matrix',
#    'is',
#    'often',
#    'used',
#    'as',
#    'a',
#    'proxy',
#    'for',
#    'the',
#    'acute',
#    'Integrated',
#    'Food',
#    'Security',
#    'Phase',
#    'Classification',
#    '-LRB-',
#    'IPC',
#    '-RRB-',
#    'and',
#    'is',
#    'indicative',
#    'of',
#    'food',
#    'security',
#    'and',
#    'nutrition',
#    'status',
#    '.'],
#   'pos-tags': ['DT',
#    'NN',
#    'NN',
#    'VBZ',
#    'RB',
#    'VBN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NN',
#    'NN',
#    '-LRB-',
#    'NN',
#    '-RRB-',
#    'CC',
#    'VBZ',
#    'JJ',
#    'IN',
#    'NN',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    '.'],
#   'lemma': ['a',
#    'hotspot',
#    'matrix',
#    'be',
#    'often',
#    'use',
#    'as',
#    'a',
#    'proxy',
#    'for',
#    'the',
#    'acute',
#    'Integrated',
#    'Food',
#    'Security',
#    'phase',
#    'classification',
#    '-lrb-',
#    'ipc',
#    '-rrb-',
#    'and',
#    'be',
#    'indicative',
#    'of',
#    'food',
#    'security',
#    'and',
#    'nutrition',
#    'status',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP (DT A) (NN hotspot) (NN matrix))\n    (VP\n      (VP (VBZ is)\n        (ADVP (RB often))\n        (VP (VBN used)\n          (PP (IN as)\n            (NP\n              (NP (DT a) (NN proxy))\n              (PP (IN for)\n                (NP\n                  (NP (DT the) (JJ acute) (NNP Integrated) (NNP Food) (NNP Security) (NN Phase) (NN Classification))\n                  (PRN (-LRB- -LRB-)\n                    (NP (NN IPC))\n                    (-RRB- -RRB-))))))))\n      (CC and)\n      (VP (VBZ is)\n        (ADJP (JJ indicative)\n          (PP (IN of)\n            (NP\n              (NP (NN food) (NN security))\n              (CC and)\n              (NP (NN nutrition) (NN status)))))))\n    (. .)))'},
#  {'sentence': 'Scaled from Priority 1 to 3, hotspot woredas require urgent humanitarian response.',
#   'position': [2338, 2420],
#   'golden-entity-mentions': [{'text': 'Priority 1 to 3',
#     'position': [2350, 2365],
#     'entity-type': 'ORG'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=9/gov=-1',
#    'advcl/dep=0/gov=9',
#    'case/dep=1/gov=2',
#    'nmod:from/dep=2/gov=0',
#    'compound/dep=3/gov=5',
#    'dep/dep=4/gov=5',
#    'nummod/dep=5/gov=2',
#    'punct/dep=6/gov=9',
#    'compound/dep=7/gov=8',
#    'nsubj/dep=8/gov=9',
#    'amod/dep=10/gov=12',
#    'amod/dep=11/gov=12',
#    'dobj/dep=12/gov=9',
#    'punct/dep=13/gov=9'],
#   'words': ['Scaled',
#    'from',
#    'Priority',
#    '1',
#    'to',
#    '3',
#    ',',
#    'hotspot',
#    'woredas',
#    'require',
#    'urgent',
#    'humanitarian',
#    'response',
#    '.'],
#   'pos-tags': ['VBN',
#    'IN',
#    'NN',
#    'CD',
#    'TO',
#    'CD',
#    ',',
#    'NN',
#    'NNS',
#    'VBP',
#    'JJ',
#    'JJ',
#    'NN',
#    '.'],
#   'lemma': ['scale',
#    'from',
#    'priority',
#    '1',
#    'to',
#    '3',
#    ',',
#    'hotspot',
#    'woreda',
#    'require',
#    'urgent',
#    'humanitarian',
#    'response',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (S\n      (VP (VBN Scaled)\n        (PP (IN from)\n          (NP (NN Priority)\n            (QP (CD 1) (TO to) (CD 3))))))\n    (, ,)\n    (NP (NN hotspot) (NNS woredas))\n    (VP (VBP require)\n      (NP (JJ urgent) (JJ humanitarian) (NN response)))\n    (. .)))'},
#  {'sentence': ' HOTSPOTS ?',
#   'position': [2421, 2432],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['HOTSPOTS', '?'],
#   'pos-tags': ['NNS', '.'],
#   'lemma': ['hotspot', '?'],
#   'parse': '(ROOT\n  (NP (NNS HOTSPOTS) (. ?)))'},
#  {'sentence': 'DECEMBER 2015 (186 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [2433, 2483],
#   'golden-entity-mentions': [{'text': 'DECEMBER 2015',
#     'position': [2433, 2446],
#     'entity-type': 'DATE'},
#    {'text': '186', 'position': [2448, 2451], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'dep/dep=8/gov=1',
#    'punct/dep=9/gov=0'],
#   'words': ['DECEMBER',
#    '2015',
#    '-LRB-',
#    '186',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'HOTSPOTS',
#    '?'],
#   'pos-tags': ['NNP',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    '-RRB-',
#    'NNS',
#    '.'],
#   'lemma': ['DECEMBER',
#    '2015',
#    '-lrb-',
#    '186',
#    'priority',
#    '1',
#    'woredas',
#    '-rrb-',
#    'hotspot',
#    '?'],
#   'parse': '(ROOT\n  (NP\n    (NP (NNP DECEMBER))\n    (NP\n      (NP (CD 2015))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 186) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'},
#  {'sentence': 'MARCH 2016 (224 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [2484, 2531],
#   'golden-entity-mentions': [{'text': 'MARCH 2016',
#     'position': [2484, 2494],
#     'entity-type': 'DATE'},
#    {'text': '224', 'position': [2496, 2499], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'dep/dep=8/gov=1',
#    'punct/dep=9/gov=0'],
#   'words': ['MARCH',
#    '2016',
#    '-LRB-',
#    '224',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'HOTSPOTS',
#    '?'],
#   'pos-tags': ['NN',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    '-RRB-',
#    'NNS',
#    '.'],
#   'lemma': ['march',
#    '2016',
#    '-lrb-',
#    '224',
#    'priority',
#    '1',
#    'woredas',
#    '-rrb-',
#    'hotspot',
#    '?'],
#   'parse': '(ROOT\n  (NP\n    (NP (NN MARCH))\n    (NP\n      (NP (CD 2016))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 224) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'},
#  {'sentence': 'JULY 2016 (205 Priority 1 woredas)  HOTSPOTS ?',
#   'position': [2532, 2578],
#   'golden-entity-mentions': [{'text': 'JULY 2016',
#     'position': [2532, 2541],
#     'entity-type': 'DATE'},
#    {'text': '205', 'position': [2543, 2546], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'dep/dep=8/gov=1',
#    'punct/dep=9/gov=0'],
#   'words': ['JULY',
#    '2016',
#    '-LRB-',
#    '205',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'HOTSPOTS',
#    '?'],
#   'pos-tags': ['NNP',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    '-RRB-',
#    'NNS',
#    '.'],
#   'lemma': ['JULY',
#    '2016',
#    '-lrb-',
#    '205',
#    'priority',
#    '1',
#    'woredas',
#    '-rrb-',
#    'hotspot',
#    '?'],
#   'parse': '(ROOT\n  (NP\n    (NP (NNP JULY))\n    (NP\n      (NP (CD 2016))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 205) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'},
#  {'sentence': 'DECEMBER 2016  (192 Priority 1 woredas)  Feb-15 May-15 Aug-15 Dec-15 Mar-16 Jul-16 Dec-16 Jun-17  HOTSPOT CLASSIFICATION CHRONOLOGY (number of woredas)  Priority 1 Priority 2 Priority 3',
#   'position': [2579, 2764],
#   'golden-entity-mentions': [{'text': 'DECEMBER 2016',
#     'position': [2579, 2592],
#     'entity-type': 'DATE'},
#    {'text': '192', 'position': [2595, 2598], 'entity-type': 'CARDINAL'},
#    {'text': '3', 'position': [2763, 2764], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1',
#    'nummod/dep=1/gov=0',
#    'punct/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=0',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'punct/dep=7/gov=4',
#    'compound/dep=8/gov=18',
#    'compound/dep=9/gov=18',
#    'compound/dep=10/gov=18',
#    'compound/dep=11/gov=18',
#    'compound/dep=12/gov=18',
#    'compound/dep=13/gov=18',
#    'compound/dep=14/gov=18',
#    'compound/dep=15/gov=18',
#    'compound/dep=16/gov=18',
#    'compound/dep=17/gov=18',
#    'dep/dep=18/gov=0',
#    'punct/dep=19/gov=20',
#    'dep/dep=20/gov=0',
#    'case/dep=21/gov=22',
#    'nmod:of/dep=22/gov=20',
#    'punct/dep=23/gov=20',
#    'compound/dep=24/gov=26',
#    'nummod/dep=25/gov=26',
#    'dep/dep=26/gov=0',
#    'nummod/dep=27/gov=28',
#    'dep/dep=28/gov=0',
#    'dep/dep=29/gov=28'],
#   'words': ['DECEMBER',
#    '2016',
#    '-LRB-',
#    '192',
#    'Priority',
#    '1',
#    'woredas',
#    '-RRB-',
#    'Feb-15',
#    'May-15',
#    'Aug-15',
#    'Dec-15',
#    'Mar-16',
#    'Jul-16',
#    'Dec-16',
#    'Jun-17',
#    'HOTSPOT',
#    'CLASSIFICATION',
#    'CHRONOLOGY',
#    '-LRB-',
#    'number',
#    'of',
#    'woredas',
#    '-RRB-',
#    'Priority',
#    '1',
#    'Priority',
#    '2',
#    'Priority',
#    '3'],
#   'pos-tags': ['NNP',
#    'CD',
#    '-LRB-',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    '-RRB-',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    '-LRB-',
#    'NN',
#    'IN',
#    'NNS',
#    '-RRB-',
#    'NN',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    'CD'],
#   'lemma': ['DECEMBER',
#    '2016',
#    '-lrb-',
#    '192',
#    'priority',
#    '1',
#    'woredas',
#    '-rrb-',
#    'feb-15',
#    'may-15',
#    'aug-15',
#    'dec-15',
#    'mar-16',
#    'jul-16',
#    'dec-16',
#    'jun-17',
#    'hotspot',
#    'classification',
#    'chronology',
#    '-lrb-',
#    'number',
#    'of',
#    'woreda',
#    '-rrb-',
#    'priority',
#    '1',
#    'priority',
#    '2',
#    'priority',
#    '3'],
#   'parse': '(ROOT\n  (NP\n    (NP\n      (NP\n        (NP\n          (NP (NNP DECEMBER) (CD 2016))\n          (PRN (-LRB- -LRB-)\n            (NP\n              (NP (CD 192) (NN Priority))\n              (NP (CD 1) (NN woredas)))\n            (-RRB- -RRB-))\n          (NP (NN Feb-15) (NN May-15) (NN Aug-15) (NN Dec-15) (NN Mar-16) (NN Jul-16) (NN Dec-16) (NN Jun-17) (NN HOTSPOT) (NN CLASSIFICATION) (NN CHRONOLOGY)))\n        (PRN (-LRB- -LRB-)\n          (NP\n            (NP (NN number))\n            (PP (IN of)\n              (NP (NNS woredas))))\n          (-RRB- -RRB-)))\n      (NP (NN Priority) (CD 1) (NN Priority)))\n    (NP\n      (NP (CD 2) (NN Priority))\n      (NP (CD 3)))))'}]

# %%
print(sentences[0])
# Out:
# {'sentence': 'HOTSPOTS ?', 'position': [0, 10], 'golden-entity-mentions': [], 'golden-event-mentions': []}

# %%
print(post11[0])
# Out:
# {'sentence': 'HOTSPOTS ?', 'position': [0, 10], 'golden-entity-mentions': [], 'golden-event-mentions': [], 'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'], 'words': ['HOTSPOTS', '?'], 'pos-tags': ['NNS', '.'], 'lemma': ['hotspot', '?'], 'parse': '(ROOT\n  (NP (NNS HOTSPOTS) (. ?)))'}

# %%
check_it = fix_entity_indices(post11, Snlp)

# %%
print(check_it)
# Out:
# [{'sentence': 'HOTSPOTS ?', 'position': [0, 10], 'golden-entity-mentions': [], 'golden-event-mentions': [], 'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'], 'words': ['HOTSPOTS', '?'], 'pos-tags': ['NNS', '.'], 'lemma': ['hotspot', '?'], 'parse': '(ROOT\n  (NP (NNS HOTSPOTS) (. ?)))'}, {'sentence': 'JUNE 2017  (228 Priority 1 woredas)  HOTSPOTS ?', 'position': [11, 58], 'golden-entity-mentions': [{'text': 'JUNE 2017', 'position': [11, 20], 'entity-type': 'DATE', 'start': 0, 'end': 2}, {'text': '228', 'position': [23, 26], 'entity-type': 'CARDINAL', 'start': 3, 'end': 4}], 'golden-event-mentions': [], 'stanford-colcc': ['ROOT/dep=0/gov=-1', 'dep/dep=1/gov=0', 'punct/dep=2/gov=4', 'nummod/dep=3/gov=4', 'dep/dep=4/gov=1', 'nummod/dep=5/gov=6', 'dep/dep=6/gov=4', 'punct/dep=7/gov=4', 'dep/dep=8/gov=1', 'punct/dep=9/gov=0'], 'words': ['JUNE', '2017', '-LRB-', '228', 'Priority', '1', 'woredas', '-RRB-', 'HOTSPOTS', '?'], 'pos-tags': ['NNP', 'CD', '-LRB-', 'CD', 'NN', 'CD', 'NN', '-RRB-', 'NNS', '.'], 'lemma': ['JUNE', '2017', '-lrb-', '228', 'priority', '1', 'woredas', '-rrb-', 'hotspot', '?'], 'parse': '(ROOT\n  (NP\n    (NP (NNP JUNE))\n    (NP\n      (NP (CD 2017))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 228) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'}, {'sentence': 'MAY 2015 (97 Priority 1 woredas)  HOTSPOTS ?', 'position': [59, 103], 'golden-entity-mentions': [{'text': 'MAY 2015', 'position': [59, 67], 'entity-type': 'DATE', 'start': 0, 'end': 2}, {'text': '97', 'position': [69, 71], 'entity-type': 'CARDINAL', 'start': 3, 'end': 4}], 'golden-event-mentions': [], 'stanford-colcc': ['ROOT/dep=0/gov=-1', 'dep/dep=1/gov=0', 'punct/dep=2/gov=4', 'nummod/dep=3/gov=4', 'dep/dep=4/gov=1', 'nummod/dep=5/gov=6', 'dep/dep=6/gov=4', 'punct/dep=7/gov=4', 'dep/dep=8/gov=1', 'punct/dep=9/gov=0'], 'words': ['MAY', '2015', '-LRB-', '97', 'Priority', '1', 'woredas', '-RRB-', 'HOTSPOTS', '?'], 'pos-tags': ['NNP', 'CD', '-LRB-', 'CD', 'NN', 'CD', 'NN', '-RRB-', 'NNS', '.'], 'lemma': ['MAY', '2015', '-lrb-', '97', 'priority', '1', 'woredas', '-rrb-', 'hotspot', '?'], 'parse': '(ROOT\n  (NP\n    (NP (NNP MAY))\n    (NP\n      (NP (CD 2015))\n      (PRN (-LRB- -LRB-)\n        (NP\n          (NP (CD 97) (NN Priority))\n          (NP (CD 1) (NN woredas)))\n        (-RRB- -RRB-))\n      (NP (NNS HOTSPOTS)))\n    (. ?)))'}, {'sentence': 'AUGUST 2015 (142 Priority 1 woredas)  The number of woredas (districts) requiring urgent humanitarian response has returned to levels not seen since the height of El Ni?o drought impacts in 2016, and have increased in terms of total number affected and those classified as Priority 1.', 'position': [104, 388], 'golden-entity-mentions': [{'text': 'AUGUST 2015', 'position': [104, 115], 'entity-type': 'DATE', 'start': 0, 'end': 2}, {'text': '142', 'position': [117, 120], 'entity-type': 'CARDINAL', 'start': 3, 'end': 4}, {'text': '1', 'position': [130, 131], 'entity-type': 'CARDINAL', 'start': 5, 'end': 6}, {'text': 'El Ni?o', 'position': [267, 274], 'entity-type': 'LOC', 'start': 29, 'end': 31}, {'text': '2016', 'position': [294, 298], 'entity-type': 'DATE', 'start': 34, 'end': 35}, {'text': 'Priority 1', 'position': [377, 387], 'entity-type': 'LAW', 'start': 49, 'end': 51}], 'golden-event-mentions': [], 'stanford-colcc': ['ROOT/dep=20/gov=-1', 'nsubj/dep=0/gov=20', 'nsubj/dep=0/gov=38', 'nummod/dep=1/gov=0', 'punct/dep=2/gov=4', 'nummod/dep=3/gov=4', 'dep/dep=4/gov=0', 'nummod/dep=5/gov=6', 'dep/dep=6/gov=4', 'punct/dep=7/gov=4', 'det/dep=8/gov=9', 'nsubj/dep=9/gov=15', 'case/dep=10/gov=11', 'nmod:of/dep=11/gov=9', 'punct/dep=12/gov=13', 'appos/dep=13/gov=11', 'punct/dep=14/gov=13', 'parataxis/dep=15/gov=20', 'amod/dep=16/gov=18', 'amod/dep=17/gov=18', 'dobj/dep=18/gov=15', 'aux/dep=19/gov=20', 'case/dep=21/gov=22', 'nmod:to/dep=22/gov=20', 'neg/dep=23/gov=24', 'acl/dep=24/gov=22', 'case/dep=25/gov=27', 'det/dep=26/gov= ...

# %%
verify_result(check_it)
# Out:
# Complete verification

# %%
with open('test_this_cdr4.json', 'w') as f:
    json.dump(check_it, f, indent=2)
