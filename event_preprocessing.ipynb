# %%
#!/usr/bin/env python3

import sys
import os
import logging
import json
import spacy
from stanfordcorenlp import StanfordCoreNLP
from preproc.tokens import find_token_index, fix_entity_index, fix_entity_indices, get_stanford_core_data

import glob 
import pandas as pd

#from tqdm import tqdm
# from main import find_token_index
# from _parser import Parser
# import main

# %%
nlp = spacy.load('en_core_web_lg', disable=["tagger", "parser"])
max_length = os.getenv("MAX_DOCUMENT_LENGTH")
if max_length:
    nlp.max_length = int(max_length)

# %%
globbed_files = glob.glob("/Users/chilv/Documents/proj-wm/bias-stance/bias_stance/MITRE Six-Twelve Month and November Docs CDRs/*.cdr")
data = []
for one_file in globbed_files:
    frame = pd.read_json(one_file, lines=True)
    data.append(frame)

# %%
cdr_data = pd.concat(data, ignore_index = True, sort = False);

# %%
txt = cdr_data['extracted_text'][0]

# %%
sentencizer = nlp.create_pipe("sentencizer")
nlp.add_pipe(sentencizer)

# %%
text = "caitie is providing a couple of sample sentences. caitie might need some help from jewell or max."

# %%
text
# Out:
# 'caitie is providing a couple of sample sentences. caitie might need some help from jewell or max.'

# %%
doc = nlp(txt)

# %%
def sentence_dict_list(doc):
    """Returns a list of dictionaries for each sentence in a CDR.
    This is just a few of those necessary for the model.
    """
    sentences = []
    for sent in doc.sents:
        sentence_dict = {}
        sentence_dict['sentence'] = sent.text
        sentence_dict['position'] = [sent.start_char, sent.end_char]
        entities = []
        for ent in sent.ents:
            entity_dict = {}
            entity_dict['text'] = ent.text
            entity_dict['position'] = [ent.start_char, ent.end_char]
            entity_dict['entity-type'] = ent.label_
            entities.append(entity_dict)
        sentence_dict['golden-entity-mentions'] = entities
        sentence_dict['golden-event-mentions'] = []
        sentences.append(sentence_dict)
    return sentences

# %%
sentences = sentence_dict_list(doc)
sentences
# Out:
# [{'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?',
#   'position': [0, 794],
#   'golden-entity-mentions': [{'text': 'GIEWS',
#     'position': [0, 5],
#     'entity-type': 'ORG'},
#    {'text': '6 million', 'position': [294, 303], 'entity-type': 'CARDINAL'},
#    {'text': 'June 2017', 'position': [307, 316], 'entity-type': 'DATE'},
#    {'text': 'Unfavourable', 'position': [319, 331], 'entity-type': 'ORG'},
#    {'text': '2017', 'position': [346, 350], 'entity-type': 'CARDINAL'},
#    {'text': 'Fall Armyworm', 'position': [417, 430], 'entity-type': 'PERSON'},
#    {'text': 'IPC', 'position': [570, 573], 'entity-type': 'ORG'},
#    {'text': 'February 2017', 'position': [626, 639], 'entity-type': 'DATE'},
#    {'text': 'Leer', 'position': [650, 654], 'entity-type': 'ORG'},
#    {'text': 'Mayendit', 'position': [659, 667], 'entity-type': 'ORG'},
#    {'text': 'Unity State', 'position': [687, 698], 'entity-type': 'ORG'},
#    {'text': 'late June 2017.Overall',
#     'position': [728, 750],
#     'entity-type': 'DATE'},
#    {'text': 'IPC', 'position': [780, 783], 'entity-type': 'ORG'},
#    {'text': '5', 'position': [790, 791], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Catastrophe?',
#   'position': [794, 806],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'food security conditions declined from over 100 000 in February to about 45 000 in June due to sustained multi-sectoral humanitarian assistance operations and the two counties are currently classified as IPC Phase 4: ?',
#   'position': [807, 1025],
#   'golden-entity-mentions': [{'text': 'February',
#     'position': [862, 870],
#     'entity-type': 'DATE'},
#    {'text': 'about 45 000', 'position': [874, 886], 'entity-type': 'CARDINAL'},
#    {'text': 'June', 'position': [890, 894], 'entity-type': 'DATE'},
#    {'text': 'two', 'position': [970, 973], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Emergency?.',
#   'position': [1025, 1036],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'However, nationwide, the food insecure caseload (IPC Phases 3, 4 and 5) increased from about 5 million in February to a record high of 6 million in June as food access continues to be severely constrained by widespread insecurity, large scale displacements, high food prices, market disruptions, macro-economic collapse and exhaustion of households?',
#   'position': [1037, 1386],
#   'golden-entity-mentions': [{'text': '4',
#     'position': [1100, 1101],
#     'entity-type': 'CARDINAL'},
#    {'text': '5', 'position': [1106, 1107], 'entity-type': 'CARDINAL'},
#    {'text': 'about 5 million',
#     'position': [1124, 1139],
#     'entity-type': 'CARDINAL'},
#    {'text': 'February', 'position': [1143, 1151], 'entity-type': 'DATE'},
#    {'text': '6 million', 'position': [1172, 1181], 'entity-type': 'CARDINAL'},
#    {'text': 'June', 'position': [1185, 1189], 'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'coping mechanisms.',
#   'position': [1387, 1405],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'The areas of major concern are Greater Jonglei and Unity states, where over 60 percent of the population faces ?',
#   'position': [1406, 1518],
#   'golden-entity-mentions': [{'text': 'Greater Jonglei',
#     'position': [1437, 1452],
#     'entity-type': 'PERSON'},
#    {'text': 'Unity', 'position': [1457, 1462], 'entity-type': 'ORG'},
#    {'text': 'over 60 percent',
#     'position': [1477, 1492],
#     'entity-type': 'PERCENT'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Crisis?, ?',
#   'position': [1518, 1528],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'Emergency?',
#   'position': [1528, 1538],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'and ?',
#   'position': [1539, 1544],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'Catastrophe?',
#   'position': [1544, 1556],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'levels of food insecurity.',
#   'position': [1557, 1583],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'In particular, the people facing catastrophic conditions are located in Ayod County in Greater Jonglei State and in Leer, Koch and Mayendit counties in Unity State.',
#   'position': [1584, 1748],
#   'golden-entity-mentions': [{'text': 'Ayod County',
#     'position': [1656, 1667],
#     'entity-type': 'GPE'},
#    {'text': 'Greater Jonglei State',
#     'position': [1671, 1692],
#     'entity-type': 'GPE'},
#    {'text': 'Leer, Koch', 'position': [1700, 1710], 'entity-type': 'ORG'},
#    {'text': 'Mayendit', 'position': [1715, 1723], 'entity-type': 'GPE'},
#    {'text': 'Unity State', 'position': [1736, 1747], 'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Since the start of the conflict in mid-December 2013, about 3.9 million people were forced to flee their homes due to insecurity, including about 1.9 million IDPs and 2 million that sought refuge in neighbouring countries (Uganda, the Sudan, the Democratic Republic of the Congo, Ethiopia and Kenya).',
#   'position': [1749, 2049],
#   'golden-entity-mentions': [{'text': 'mid-December 2013',
#     'position': [1784, 1801],
#     'entity-type': 'DATE'},
#    {'text': 'about 3.9 million',
#     'position': [1803, 1820],
#     'entity-type': 'CARDINAL'},
#    {'text': 'about 1.9 million',
#     'position': [1889, 1906],
#     'entity-type': 'CARDINAL'},
#    {'text': '2 million', 'position': [1916, 1925], 'entity-type': 'CARDINAL'},
#    {'text': 'Uganda', 'position': [1972, 1978], 'entity-type': 'GPE'},
#    {'text': 'Sudan', 'position': [1984, 1989], 'entity-type': 'GPE'},
#    {'text': 'the Democratic Republic of the Congo',
#     'position': [1991, 2027],
#     'entity-type': 'GPE'},
#    {'text': 'Ethiopia', 'position': [2029, 2037], 'entity-type': 'GPE'},
#    {'text': 'Kenya', 'position': [2042, 2047], 'entity-type': 'GPE'}],
#   'golden-event-mentions': []},
#  {'sentence': '\n\nSharply reduced crop production expected in 2017 due to conflict and pest outbreaks In southern bi-modal rainfall areas, harvesting of first season crops was concluded in August.',
#   'position': [2049, 2229],
#   'golden-entity-mentions': [{'text': '2017',
#     'position': [2095, 2099],
#     'entity-type': 'DATE'},
#    {'text': 'first', 'position': [2186, 2191], 'entity-type': 'ORDINAL'},
#    {'text': 'August', 'position': [2222, 2228], 'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Seasonal rains were above- average in the ?',
#   'position': [2230, 2273],
#   'golden-entity-mentions': [{'text': 'Seasonal',
#     'position': [2230, 2238],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'green belt?,',
#   'position': [2273, 2285],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'including the former Central and Western Equatoria states, while in the former Eastern Equatoria State they started in late April with about a one-month delay.',
#   'position': [2286, 2445],
#   'golden-entity-mentions': [{'text': 'Central',
#     'position': [2307, 2314],
#     'entity-type': 'ORG'},
#    {'text': 'Eastern Equatoria State',
#     'position': [2365, 2388],
#     'entity-type': 'ORG'},
#    {'text': 'late April', 'position': [2405, 2415], 'entity-type': 'DATE'},
#    {'text': 'one-month', 'position': [2429, 2438], 'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'In northern and central uni-modal rainfall areas, harvesting of short cycle sorghum and maize crops has recently started, while long cycle sorghum crops will be gathered from November to January.',
#   'position': [2446, 2641],
#   'golden-entity-mentions': [{'text': 'November to January',
#     'position': [2621, 2640],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Weather conditions have been generally favourable so far as seasonal rains have been average to above average, thus benefiting vegetation conditions.',
#   'position': [2642, 2791],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'However, prospects for 2017 aggregate cereal production are generally unfavourable as agricultural activities continue to be severely affected by the protracted and widespread insecurity, which is constraining farmers?',
#   'position': [2792, 3010],
#   'golden-entity-mentions': [{'text': '2017',
#     'position': [2815, 2819],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'access to fields and is causing large scale displacement of people, input shortages and damage to households?',
#   'position': [3011, 3120],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'productive assets.',
#   'position': [3121, 3139],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': []},
#  {'sentence': 'In the traditionally surplusproducing areas of southern Greater Equatoria Region, crop production is expected to be lower than the already poor 2016 output due to recent massive displacements outside the former Central and Eastern Equatoria states.',
#   'position': [3140, 3388],
#   'golden-entity-mentions': [{'text': 'Greater Equatoria Region',
#     'position': [3196, 3220],
#     'entity-type': 'PERSON'},
#    {'text': '2016', 'position': [3284, 3288], 'entity-type': 'DATE'},
#    {'text': 'Central', 'position': [3351, 3358], 'entity-type': 'ORG'},
#    {'text': 'Eastern Equatoria',
#     'position': [3363, 3380],
#     'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Notably, about 75 percent of the population of the former Central Equatoria State has reportedly left their living areas.',
#   'position': [3389, 3510],
#   'golden-entity-mentions': [{'text': 'about 75 percent',
#     'position': [3398, 3414],
#     'entity-type': 'PERCENT'},
#    {'text': 'Central Equatoria State',
#     'position': [3447, 3470],
#     'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': 'In addition, Fall Armyworm infestations have been reported in all regions of the country, with significant crop damage, especially in parts of former Northern Bahr el Ghazal, Eastern Equatoria and Central Equatoria states.',
#   'position': [3511, 3733],
#   'golden-entity-mentions': [{'text': 'Fall Armyworm',
#     'position': [3524, 3537],
#     'entity-type': 'PERSON'},
#    {'text': 'Northern Bahr el Ghazal',
#     'position': [3661, 3684],
#     'entity-type': 'NORP'},
#    {'text': 'Eastern Equatoria',
#     'position': [3686, 3703],
#     'entity-type': 'ORG'},
#    {'text': 'Central Equatoria',
#     'position': [3708, 3725],
#     'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': '\n\nPrices of cereals at exceptionally high levels In the capital, Juba, prices of maize and sorghum more than doubled in the first semester of 2017, reaching record levels in June, driven by a tight supply situation, market disruptions, hyperinflation and a significant depreciation of the local currency.',
#   'position': [3733, 4037],
#   'golden-entity-mentions': [{'text': 'Juba',
#     'position': [3798, 3802],
#     'entity-type': 'PERSON'},
#    {'text': 'the first semester of 2017',
#     'position': [3853, 3879],
#     'entity-type': 'DATE'},
#    {'text': 'June', 'position': [3907, 3911], 'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Subsequently, they declined by about 12 percent between June and August, following the first season harvest in southern bimodal rainfall areas and the establishment, by the Government, of a trading company selling basic food commodities at subsidized prices.',
#   'position': [4038, 4296],
#   'golden-entity-mentions': [{'text': 'about 12 percent',
#     'position': [4069, 4085],
#     'entity-type': 'PERCENT'},
#    {'text': 'between June and August',
#     'position': [4086, 4109],
#     'entity-type': 'DATE'},
#    {'text': 'first', 'position': [4125, 4130], 'entity-type': 'ORDINAL'},
#    {'text': 'Government', 'position': [4211, 4221], 'entity-type': 'ORG'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Prices of groundnuts decreased by 22 percent over the same period, while prices of wheat flour continued to soar in recent months, reaching new record highs in August.',
#   'position': [4297, 4464],
#   'golden-entity-mentions': [{'text': '22 percent',
#     'position': [4331, 4341],
#     'entity-type': 'PERCENT'},
#    {'text': 'the same period',
#     'position': [4347, 4362],
#     'entity-type': 'DATE'},
#    {'text': 'recent months', 'position': [4413, 4426], 'entity-type': 'DATE'},
#    {'text': 'August', 'position': [4457, 4463], 'entity-type': 'DATE'}],
#   'golden-event-mentions': []},
#  {'sentence': 'Overall, prices of these food staples in August were more than twice the high levels in August last year and up to 12 times higher than in the corresponding period two years earlier.',
#   'position': [4465, 4647],
#   'golden-entity-mentions': [{'text': 'August',
#     'position': [4506, 4512],
#     'entity-type': 'DATE'},
#    {'text': 'August last year',
#     'position': [4553, 4569],
#     'entity-type': 'DATE'},
#    {'text': 'up to 12', 'position': [4574, 4582], 'entity-type': 'CARDINAL'},
#    {'text': 'two years earlier',
#     'position': [4629, 4646],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': []}]

# %%
class StanfordNLP:
    """Getting Stanford running with necessary annotators"""
    def __init__(self, host='http://localhost', port=9000):
        self.nlp = StanfordCoreNLP(host, port=port,
                                   timeout=60000)  # , quiet=False, logging_level=logging.DEBUG)
        self.props = {
            'annotators': 'tokenize,ssplit,pos,lemma,parse',
            'pipelineLanguage': 'en',
            'outputFormat': 'json'
        }

    def annotate(self, sentence):
        return self.nlp.annotate(sentence, properties=self.props)

# %%
Snlp = StanfordNLP()

# %%
post11 = get_stanford_core_data(sentences, Snlp)

# %%
post11
# Out:
# [{'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?',
#   'position': [0, 794],
#   'golden-entity-mentions': [{'text': 'GIEWS',
#     'position': [0, 5],
#     'entity-type': 'ORG'},
#    {'text': '6 million', 'position': [294, 303], 'entity-type': 'CARDINAL'},
#    {'text': 'June 2017', 'position': [307, 316], 'entity-type': 'DATE'},
#    {'text': 'Unfavourable', 'position': [319, 331], 'entity-type': 'ORG'},
#    {'text': '2017', 'position': [346, 350], 'entity-type': 'CARDINAL'},
#    {'text': 'Fall Armyworm', 'position': [417, 430], 'entity-type': 'PERSON'},
#    {'text': 'IPC', 'position': [570, 573], 'entity-type': 'ORG'},
#    {'text': 'February 2017', 'position': [626, 639], 'entity-type': 'DATE'},
#    {'text': 'Leer', 'position': [650, 654], 'entity-type': 'ORG'},
#    {'text': 'Mayendit', 'position': [659, 667], 'entity-type': 'ORG'},
#    {'text': 'Unity State', 'position': [687, 698], 'entity-type': 'ORG'},
#    {'text': 'late June 2017.Overall',
#     'position': [728, 750],
#     'entity-type': 'DATE'},
#    {'text': 'IPC', 'position': [780, 783], 'entity-type': 'ORG'},
#    {'text': '5', 'position': [790, 791], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=24/gov=-1',
#    'compound/dep=0/gov=2',
#    'amod/dep=1/gov=2',
#    'nsubj/dep=2/gov=24',
#    'cc/dep=3/gov=2',
#    'amod/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'conj:and/dep=6/gov=2',
#    'nsubj/dep=6/gov=24',
#    'case/dep=7/gov=8',
#    'nmod:on/dep=8/gov=6',
#    'cc/dep=9/gov=8',
#    'nmod:on/dep=10/gov=6',
#    'conj:and/dep=10/gov=8',
#    'compound/dep=11/gov=17',
#    'compound/dep=12/gov=17',
#    'compound/dep=13/gov=17',
#    'compound/dep=14/gov=17',
#    'compound/dep=15/gov=17',
#    'compound/dep=16/gov=17',
#    'dep/dep=17/gov=6',
#    'punct/dep=18/gov=6',
#    'amod/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'dep/dep=21/gov=6',
#    'compound/dep=22/gov=23',
#    'dep/dep=23/gov=21',
#    'compound:prt/dep=25/gov=24',
#    'punct/dep=26/gov=24',
#    'cc/dep=27/gov=24',
#    'compound/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nsubj/dep=30/gov=110',
#    'advmod/dep=31/gov=32',
#    'amod/dep=32/gov=36',
#    'case/dep=33/gov=35',
#    'det/dep=34/gov=35',
#    'nmod:across/dep=35/gov=32',
#    'nmod/dep=36/gov=30',
#    'amod/dep=37/gov=38',
#    'dep/dep=38/gov=36',
#    'acl/dep=39/gov=38',
#    'case/dep=40/gov=41',
#    'nmod:at/dep=41/gov=39',
#    'amod/dep=42/gov=49',
#    'compound/dep=43/gov=44',
#    'dep/dep=44/gov=42',
#    'case/dep=45/gov=46',
#    'nmod:in/dep=46/gov=44',
#    'nummod/dep=47/gov=46',
#    'compound/dep=48/gov=49',
#    'nsubj/dep=49/gov=72',
#    'case/dep=50/gov=66',
#    'nummod/dep=51/gov=52',
#    'nmod:npmod/dep=52/gov=53',
#    'amod/dep=53/gov=66',
#    'case/dep=54/gov=56',
#    'amod/dep=55/gov=56',
#    'nmod:to/dep=56/gov=53',
#    'punct/dep=57/gov=56',
#    'amod/dep=58/gov=60',
#    'compound/dep=59/gov=60',
#    'nmod:to/dep=60/gov=53',
#    'conj:and/dep=60/gov=56',
#    'cc/dep=61/gov=56',
#    'compound/dep=62/gov=64',
#    'compound/dep=63/gov=64',
#    'nmod:to/dep=64/gov=53',
#    'conj:and/dep=64/gov=56',
#    'compound/dep=65/gov=66',
#    'nmod:for/dep=66/gov=49',
#    'case/dep=67/gov=71',
#    'advmod/dep=68/gov=69',
#    'amod/dep=69/gov=71',
#    'compound/dep=70/gov=71',
#    'nmod:at/dep=71/gov=66',
#    'acl:relcl/dep=72/gov=41',
#    'compound:prt/dep=73/gov=72',
#    'punct/dep=74/gov=72',
#    'cc/dep=75/gov=72',
#    'compound/dep=76/gov=78',
#    'compound/dep=77/gov=78',
#    'acl:relcl/dep=78/gov=41',
#    'conj:but/dep=78/gov=72',
#    'advmod/dep=79/gov=80',
#    'amod/dep=80/gov=78',
#    'case/dep=81/gov=86',
#    'mwe/dep=82/gov=81',
#    'det/dep=83/gov=86',
#    'amod/dep=84/gov=86',
#    'compound/dep=85/gov=86',
#    'nmod:according_to/dep=86/gov=78',
#    'punct/dep=87/gov=86',
#    'compound/dep=88/gov=89',
#    'appos/dep=89/gov=86',
#    'punct/dep=90/gov=30',
#    'advmod/dep=91/gov=92',
#    'acl/dep=92/gov=30',
#    'case/dep=93/gov=94',
#    'nmod:in/dep=94/gov=92',
#    'nummod/dep=95/gov=94',
#    'case/dep=96/gov=98',
#    'amod/dep=97/gov=98',
#    'nmod:in/dep=98/gov=94',
#    'cc/dep=99/gov=98',
#    'compound/dep=100/gov=101',
#    'nmod:in/dep=101/gov=94',
#    'conj:and/dep=101/gov=98',
#    'case/dep=102/gov=105',
#    'amod/dep=103/gov=105',
#    'compound/dep=104/gov=105',
#    'nmod:in/dep=105/gov=92',
#    'punct/dep=106/gov=30',
#    'aux/dep=107/gov=110',
#    'neg/dep=108/gov=109',
#    'advmod/dep=109/gov=110',
#    'conj:but/dep=110/gov=24',
#    'case/dep=111/gov=112',
#    'nmod:by/dep=112/gov=110',
#    'nmod:tmod/dep=113/gov=110',
#    'nummod/dep=114/gov=113',
#    'punct/dep=115/gov=24'],
#   'words': ['GIEWS',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'Brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-September-2017',
#    'FOOD',
#    'SECURITY',
#    'SNAPSHOT',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimated',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crops',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    'and',
#    'Fall',
#    'Armyworm',
#    'infestations',
#    'Food',
#    'prices',
#    'at',
#    'exceptionally',
#    'high',
#    'levels',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'According',
#    'to',
#    'the',
#    'latest',
#    'IPC',
#    'analysis',
#    ',',
#    'famine',
#    'conditions',
#    ',',
#    'previously',
#    'reported',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'counties',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'were',
#    'no',
#    'longer',
#    'occurring',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'pos-tags': ['NN',
#    'JJ',
#    'NN',
#    'CC',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'NNP',
#    'NNP',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    ':',
#    'JJ',
#    'NN',
#    'NN',
#    'NNP',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'IN',
#    'DT',
#    'NN',
#    'NNP',
#    'JJ',
#    'NN',
#    'VBN',
#    'IN',
#    'NN',
#    'JJ',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'CD',
#    'NNP',
#    'NNS',
#    'IN',
#    'CD',
#    'NNS',
#    'JJ',
#    'TO',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'NN',
#    'NN',
#    'NNS',
#    'NN',
#    'NNS',
#    'IN',
#    'RB',
#    'JJ',
#    'NNS',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'VBG',
#    'TO',
#    'DT',
#    'JJS',
#    'NN',
#    'NN',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'CD',
#    'IN',
#    'JJ',
#    'NNP',
#    'CC',
#    'NNP',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNP',
#    'NNP',
#    ',',
#    'VBD',
#    'RB',
#    'RB',
#    'VBG',
#    'IN',
#    'JJ',
#    'NNP',
#    'CD',
#    '.'],
#   'lemma': ['giews',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-september-2017',
#    'food',
#    'security',
#    'SNAPSHOT',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimate',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crop',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    'and',
#    'fall',
#    'armyworm',
#    'infestation',
#    'food',
#    'price',
#    'at',
#    'exceptionally',
#    'high',
#    'level',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'accord',
#    'to',
#    'the',
#    'latest',
#    'ipc',
#    'analysis',
#    ',',
#    'famine',
#    'condition',
#    ',',
#    'previously',
#    'report',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'county',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'be',
#    'no',
#    'longer',
#    'occur',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (S\n      (NP\n        (NP (NN GIEWS) (JJ global) (NN information))\n        (CC and)\n        (NP\n          (NP\n            (NP\n              (NP (JJ early) (NN warning) (NN system))\n              (PP (IN on)\n                (NP (NN food)\n                  (CC and)\n                  (NN agriculture))))\n            (NP (NNP GIEWS) (NNP Country) (NN Brief) (NNP South) (NNP Sudan) (NNP Reference) (NNP Date)))\n          (: :)\n          (NP\n            (NP (JJ 14-September-2017) (NN FOOD) (NN SECURITY))\n            (NP (NNP SNAPSHOT) (NN Famine)))))\n      (VP (VBD phased)\n        (PRT (RP out))))\n    (, ,)\n    (CC but)\n    (S\n      (NP\n        (NP (NN food) (NN security) (NN situation))\n        (PP\n          (NP\n            (ADJP (RB still) (JJ dire)\n              (PP (IN across)\n                (NP (DT the) (NN country))))\n            (NNP Food))\n          (NP\n            (NP (JJ insecure) (NN caseload))\n            (VP (VBN estimated)\n              (PP (IN at)\n                (NP\n                  (NP (NN record))\n                  (SBAR\n                    (WHNP\n                      (NP\n                        (ADJP (JJ high)\n                          (NP\n                            (NP\n                              (QP (CD 6) (CD million)))\n                            (PP (IN in)\n                              (NP (NNP June) (CD 2017)))))\n                        (NNP Unfavourable) (NNS prospects))\n                      (PP (IN for)\n                        (NP\n                          (NP\n                            (ADJP\n                              (NP (CD 2017) (NNS crops))\n                              (JJ due)\n                              (PP (TO to)\n                                (NP\n                                  (NP (JJ widespread) (NN insecurity))\n                                  (, ,)\n                                  (NP (JJ large) (NN scale) (NNS displacements))\n                                  (CC and)\n                                  (NP (NN Fall) (NN Armyworm) (NNS infestations)))))\n                            (NN Food) (NNS prices))\n                          (PP (IN at)\n                            (NP\n                              (ADJP (RB exceptionally) (JJ high))\n                              (NNS levels) (NN Famine))))))\n                    (S\n                      (VP\n                        (VP (VBD phased)\n                          (PRT (RP out)))\n                        (, ,)\n                        (CC but)\n                        (VP\n                          (NP\n                            (NP (NN food) (NN security) (NN situation))\n                            (ADJP (RB still) (JJ dire)))\n                          (PP (VBG According)\n                            (PP (TO to)\n                              (NP\n                                (NP (DT the) (JJS latest) (NN IPC) (NN analysis))\n                                (, ,)\n                                (NP (NN famine) (NNS conditions))))))))))))))\n        (, ,)\n        (VP\n          (ADVP (RB previously))\n          (VBN reported)\n          (PP (IN in)\n            (NP\n              (NP (NNP February) (CD 2017))\n              (PP (IN in)\n                (NP (JJ former) (NNP Leer)\n                  (CC and)\n                  (NNP Mayendit) (NNS counties)))))\n          (PP (IN in)\n            (NP (JJ former) (NNP Unity) (NNP State))))\n        (, ,))\n      (VP (VBD were)\n        (ADVP (RB no) (RB longer))\n        (VP (VBG occurring)\n          (PP (IN by)\n            (NP (JJ late)))\n          (NP-TMP (NNP June) (CD 2017)))))\n    (. .)))'},
#  {'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?',
#   'position': [0, 794],
#   'golden-entity-mentions': [{'text': 'GIEWS',
#     'position': [0, 5],
#     'entity-type': 'ORG'},
#    {'text': '6 million', 'position': [294, 303], 'entity-type': 'CARDINAL'},
#    {'text': 'June 2017', 'position': [307, 316], 'entity-type': 'DATE'},
#    {'text': 'Unfavourable', 'position': [319, 331], 'entity-type': 'ORG'},
#    {'text': '2017', 'position': [346, 350], 'entity-type': 'CARDINAL'},
#    {'text': 'Fall Armyworm', 'position': [417, 430], 'entity-type': 'PERSON'},
#    {'text': 'IPC', 'position': [570, 573], 'entity-type': 'ORG'},
#    {'text': 'February 2017', 'position': [626, 639], 'entity-type': 'DATE'},
#    {'text': 'Leer', 'position': [650, 654], 'entity-type': 'ORG'},
#    {'text': 'Mayendit', 'position': [659, 667], 'entity-type': 'ORG'},
#    {'text': 'Unity State', 'position': [687, 698], 'entity-type': 'ORG'},
#    {'text': 'late June 2017.Overall',
#     'position': [728, 750],
#     'entity-type': 'DATE'},
#    {'text': 'IPC', 'position': [780, 783], 'entity-type': 'ORG'},
#    {'text': '5', 'position': [790, 791], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=24/gov=-1',
#    'compound/dep=0/gov=2',
#    'amod/dep=1/gov=2',
#    'nsubj/dep=2/gov=24',
#    'cc/dep=3/gov=2',
#    'amod/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'conj:and/dep=6/gov=2',
#    'nsubj/dep=6/gov=24',
#    'case/dep=7/gov=8',
#    'nmod:on/dep=8/gov=6',
#    'cc/dep=9/gov=8',
#    'nmod:on/dep=10/gov=6',
#    'conj:and/dep=10/gov=8',
#    'compound/dep=11/gov=17',
#    'compound/dep=12/gov=17',
#    'compound/dep=13/gov=17',
#    'compound/dep=14/gov=17',
#    'compound/dep=15/gov=17',
#    'compound/dep=16/gov=17',
#    'dep/dep=17/gov=6',
#    'punct/dep=18/gov=6',
#    'amod/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'dep/dep=21/gov=6',
#    'compound/dep=22/gov=23',
#    'dep/dep=23/gov=21',
#    'compound:prt/dep=25/gov=24',
#    'punct/dep=26/gov=24',
#    'cc/dep=27/gov=24',
#    'compound/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nsubj/dep=30/gov=110',
#    'advmod/dep=31/gov=32',
#    'amod/dep=32/gov=36',
#    'case/dep=33/gov=35',
#    'det/dep=34/gov=35',
#    'nmod:across/dep=35/gov=32',
#    'nmod/dep=36/gov=30',
#    'amod/dep=37/gov=38',
#    'dep/dep=38/gov=36',
#    'acl/dep=39/gov=38',
#    'case/dep=40/gov=41',
#    'nmod:at/dep=41/gov=39',
#    'amod/dep=42/gov=49',
#    'compound/dep=43/gov=44',
#    'dep/dep=44/gov=42',
#    'case/dep=45/gov=46',
#    'nmod:in/dep=46/gov=44',
#    'nummod/dep=47/gov=46',
#    'compound/dep=48/gov=49',
#    'nsubj/dep=49/gov=72',
#    'case/dep=50/gov=66',
#    'nummod/dep=51/gov=52',
#    'nmod:npmod/dep=52/gov=53',
#    'amod/dep=53/gov=66',
#    'case/dep=54/gov=56',
#    'amod/dep=55/gov=56',
#    'nmod:to/dep=56/gov=53',
#    'punct/dep=57/gov=56',
#    'amod/dep=58/gov=60',
#    'compound/dep=59/gov=60',
#    'nmod:to/dep=60/gov=53',
#    'conj:and/dep=60/gov=56',
#    'cc/dep=61/gov=56',
#    'compound/dep=62/gov=64',
#    'compound/dep=63/gov=64',
#    'nmod:to/dep=64/gov=53',
#    'conj:and/dep=64/gov=56',
#    'compound/dep=65/gov=66',
#    'nmod:for/dep=66/gov=49',
#    'case/dep=67/gov=71',
#    'advmod/dep=68/gov=69',
#    'amod/dep=69/gov=71',
#    'compound/dep=70/gov=71',
#    'nmod:at/dep=71/gov=66',
#    'acl:relcl/dep=72/gov=41',
#    'compound:prt/dep=73/gov=72',
#    'punct/dep=74/gov=72',
#    'cc/dep=75/gov=72',
#    'compound/dep=76/gov=78',
#    'compound/dep=77/gov=78',
#    'acl:relcl/dep=78/gov=41',
#    'conj:but/dep=78/gov=72',
#    'advmod/dep=79/gov=80',
#    'amod/dep=80/gov=78',
#    'case/dep=81/gov=86',
#    'mwe/dep=82/gov=81',
#    'det/dep=83/gov=86',
#    'amod/dep=84/gov=86',
#    'compound/dep=85/gov=86',
#    'nmod:according_to/dep=86/gov=78',
#    'punct/dep=87/gov=86',
#    'compound/dep=88/gov=89',
#    'appos/dep=89/gov=86',
#    'punct/dep=90/gov=30',
#    'advmod/dep=91/gov=92',
#    'acl/dep=92/gov=30',
#    'case/dep=93/gov=94',
#    'nmod:in/dep=94/gov=92',
#    'nummod/dep=95/gov=94',
#    'case/dep=96/gov=98',
#    'amod/dep=97/gov=98',
#    'nmod:in/dep=98/gov=94',
#    'cc/dep=99/gov=98',
#    'compound/dep=100/gov=101',
#    'nmod:in/dep=101/gov=94',
#    'conj:and/dep=101/gov=98',
#    'case/dep=102/gov=105',
#    'amod/dep=103/gov=105',
#    'compound/dep=104/gov=105',
#    'nmod:in/dep=105/gov=92',
#    'punct/dep=106/gov=30',
#    'aux/dep=107/gov=110',
#    'neg/dep=108/gov=109',
#    'advmod/dep=109/gov=110',
#    'conj:but/dep=110/gov=24',
#    'case/dep=111/gov=112',
#    'nmod:by/dep=112/gov=110',
#    'nmod:tmod/dep=113/gov=110',
#    'nummod/dep=114/gov=113',
#    'punct/dep=115/gov=24'],
#   'words': ['GIEWS',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'Brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-September-2017',
#    'FOOD',
#    'SECURITY',
#    'SNAPSHOT',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimated',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crops',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    'and',
#    'Fall',
#    'Armyworm',
#    'infestations',
#    'Food',
#    'prices',
#    'at',
#    'exceptionally',
#    'high',
#    'levels',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'According',
#    'to',
#    'the',
#    'latest',
#    'IPC',
#    'analysis',
#    ',',
#    'famine',
#    'conditions',
#    ',',
#    'previously',
#    'reported',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'counties',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'were',
#    'no',
#    'longer',
#    'occurring',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'pos-tags': ['NN',
#    'JJ',
#    'NN',
#    'CC',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'NNP',
#    'NNP',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    ':',
#    'JJ',
#    'NN',
#    'NN',
#    'NNP',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'IN',
#    'DT',
#    'NN',
#    'NNP',
#    'JJ',
#    'NN',
#    'VBN',
#    'IN',
#    'NN',
#    'JJ',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'CD',
#    'NNP',
#    'NNS',
#    'IN',
#    'CD',
#    'NNS',
#    'JJ',
#    'TO',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'NN',
#    'NN',
#    'NNS',
#    'NN',
#    'NNS',
#    'IN',
#    'RB',
#    'JJ',
#    'NNS',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'VBG',
#    'TO',
#    'DT',
#    'JJS',
#    'NN',
#    'NN',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'CD',
#    'IN',
#    'JJ',
#    'NNP',
#    'CC',
#    'NNP',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNP',
#    'NNP',
#    ',',
#    'VBD',
#    'RB',
#    'RB',
#    'VBG',
#    'IN',
#    'JJ',
#    'NNP',
#    'CD',
#    '.'],
#   'lemma': ['giews',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-september-2017',
#    'food',
#    'security',
#    'SNAPSHOT',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimate',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crop',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    'and',
#    'fall',
#    'armyworm',
#    'infestation',
#    'food',
#    'price',
#    'at',
#    'exceptionally',
#    'high',
#    'level',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'accord',
#    'to',
#    'the',
#    'latest',
#    'ipc',
#    'analysis',
#    ',',
#    'famine',
#    'condition',
#    ',',
#    'previously',
#    'report',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'county',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'be',
#    'no',
#    'longer',
#    'occur',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (S\n      (NP\n        (NP (NN GIEWS) (JJ global) (NN information))\n        (CC and)\n        (NP\n          (NP\n            (NP\n              (NP (JJ early) (NN warning) (NN system))\n              (PP (IN on)\n                (NP (NN food)\n                  (CC and)\n                  (NN agriculture))))\n            (NP (NNP GIEWS) (NNP Country) (NN Brief) (NNP South) (NNP Sudan) (NNP Reference) (NNP Date)))\n          (: :)\n          (NP\n            (NP (JJ 14-September-2017) (NN FOOD) (NN SECURITY))\n            (NP (NNP SNAPSHOT) (NN Famine)))))\n      (VP (VBD phased)\n        (PRT (RP out))))\n    (, ,)\n    (CC but)\n    (S\n      (NP\n        (NP (NN food) (NN security) (NN situation))\n        (PP\n          (NP\n            (ADJP (RB still) (JJ dire)\n              (PP (IN across)\n                (NP (DT the) (NN country))))\n            (NNP Food))\n          (NP\n            (NP (JJ insecure) (NN caseload))\n            (VP (VBN estimated)\n              (PP (IN at)\n                (NP\n                  (NP (NN record))\n                  (SBAR\n                    (WHNP\n                      (NP\n                        (ADJP (JJ high)\n                          (NP\n                            (NP\n                              (QP (CD 6) (CD million)))\n                            (PP (IN in)\n                              (NP (NNP June) (CD 2017)))))\n                        (NNP Unfavourable) (NNS prospects))\n                      (PP (IN for)\n                        (NP\n                          (NP\n                            (ADJP\n                              (NP (CD 2017) (NNS crops))\n                              (JJ due)\n                              (PP (TO to)\n                                (NP\n                                  (NP (JJ widespread) (NN insecurity))\n                                  (, ,)\n                                  (NP (JJ large) (NN scale) (NNS displacements))\n                                  (CC and)\n                                  (NP (NN Fall) (NN Armyworm) (NNS infestations)))))\n                            (NN Food) (NNS prices))\n                          (PP (IN at)\n                            (NP\n                              (ADJP (RB exceptionally) (JJ high))\n                              (NNS levels) (NN Famine))))))\n                    (S\n                      (VP\n                        (VP (VBD phased)\n                          (PRT (RP out)))\n                        (, ,)\n                        (CC but)\n                        (VP\n                          (NP\n                            (NP (NN food) (NN security) (NN situation))\n                            (ADJP (RB still) (JJ dire)))\n                          (PP (VBG According)\n                            (PP (TO to)\n                              (NP\n                                (NP (DT the) (JJS latest) (NN IPC) (NN analysis))\n                                (, ,)\n                                (NP (NN famine) (NNS conditions))))))))))))))\n        (, ,)\n        (VP\n          (ADVP (RB previously))\n          (VBN reported)\n          (PP (IN in)\n            (NP\n              (NP (NNP February) (CD 2017))\n              (PP (IN in)\n                (NP (JJ former) (NNP Leer)\n                  (CC and)\n                  (NNP Mayendit) (NNS counties)))))\n          (PP (IN in)\n            (NP (JJ former) (NNP Unity) (NNP State))))\n        (, ,))\n      (VP (VBD were)\n        (ADVP (RB no) (RB longer))\n        (VP (VBG occurring)\n          (PP (IN by)\n            (NP (JJ late)))\n          (NP-TMP (NNP June) (CD 2017)))))\n    (. .)))'},
#  {'sentence': 'Catastrophe?',
#   'position': [794, 806],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Catastrophe', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['catastrophe', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Catastrophe))\n    (. ?)))'},
#  {'sentence': 'Catastrophe?',
#   'position': [794, 806],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Catastrophe', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['catastrophe', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Catastrophe))\n    (. ?)))'},
#  {'sentence': 'food security conditions declined from over 100 000 in February to about 45 000 in June due to sustained multi-sectoral humanitarian assistance operations and the two counties are currently classified as IPC Phase 4: ?',
#   'position': [807, 1025],
#   'golden-entity-mentions': [{'text': 'February',
#     'position': [862, 870],
#     'entity-type': 'DATE'},
#    {'text': 'about 45 000', 'position': [874, 886], 'entity-type': 'CARDINAL'},
#    {'text': 'June', 'position': [890, 894], 'entity-type': 'DATE'},
#    {'text': 'two', 'position': [970, 973], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'compound/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nsubj/dep=2/gov=3',
#    'advmod/dep=4/gov=29',
#    'case/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'nmod:over/dep=7/gov=4',
#    'case/dep=8/gov=9',
#    'nmod:in/dep=9/gov=7',
#    'mark/dep=10/gov=13',
#    'dep/dep=11/gov=13',
#    'compound/dep=12/gov=13',
#    'acl:to/dep=13/gov=9',
#    'case/dep=14/gov=15',
#    'nmod:in/dep=15/gov=13',
#    'amod/dep=16/gov=15',
#    'case/dep=17/gov=22',
#    'amod/dep=18/gov=22',
#    'amod/dep=19/gov=22',
#    'amod/dep=20/gov=22',
#    'compound/dep=21/gov=22',
#    'nmod:to/dep=22/gov=16',
#    'cc/dep=23/gov=22',
#    'det/dep=24/gov=26',
#    'nummod/dep=25/gov=26',
#    'nmod:to/dep=26/gov=16',
#    'conj:and/dep=26/gov=22',
#    'auxpass/dep=27/gov=29',
#    'advmod/dep=28/gov=29',
#    'dep/dep=29/gov=3',
#    'case/dep=30/gov=32',
#    'compound/dep=31/gov=32',
#    'nmod:as/dep=32/gov=29',
#    'nsubjpass/dep=33/gov=29',
#    'punct/dep=34/gov=29',
#    'punct/dep=35/gov=3'],
#   'words': ['food',
#    'security',
#    'conditions',
#    'declined',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operations',
#    'and',
#    'the',
#    'two',
#    'counties',
#    'are',
#    'currently',
#    'classified',
#    'as',
#    'IPC',
#    'Phase',
#    '4',
#    ':',
#    '?'],
#   'pos-tags': ['NN',
#    'NN',
#    'NNS',
#    'VBD',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'JJ',
#    'TO',
#    'JJ',
#    'JJ',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'DT',
#    'CD',
#    'NNS',
#    'VBP',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'NN',
#    'CD',
#    ':',
#    '.'],
#   'lemma': ['food',
#    'security',
#    'condition',
#    'decline',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operation',
#    'and',
#    'the',
#    'two',
#    'county',
#    'be',
#    'currently',
#    'classify',
#    'as',
#    'IPC',
#    'phase',
#    '4',
#    ':',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (NP (NN food) (NN security) (NNS conditions))\n    (VP (VBD declined)\n      (SBAR\n        (SINV\n          (ADVP (IN from)\n            (PP (IN over)\n              (NP\n                (QP (CD 100) (CD 000)))\n              (PP (IN in)\n                (NP\n                  (NP (NNP February))\n                  (SBAR\n                    (S\n                      (VP (TO to)\n                        (VP (IN about)\n                          (NP\n                            (QP (CD 45) (CD 000)))\n                          (PP (IN in)\n                            (NP\n                              (NP (NNP June))\n                              (ADJP (JJ due)\n                                (PP (TO to)\n                                  (NP\n                                    (NP (JJ sustained) (JJ multi-sectoral) (JJ humanitarian) (NN assistance) (NNS operations))\n                                    (CC and)\n                                    (NP (DT the) (CD two) (NNS counties)))))))))))))))\n          (VP (VBP are)\n            (ADVP (RB currently))\n            (VP (VBN classified)\n              (PP (IN as)\n                (NP (NNP IPC) (NN Phase)))))\n          (NP (CD 4))\n          (: :))))\n    (. ?)))'},
#  {'sentence': 'food security conditions declined from over 100 000 in February to about 45 000 in June due to sustained multi-sectoral humanitarian assistance operations and the two counties are currently classified as IPC Phase 4: ?',
#   'position': [807, 1025],
#   'golden-entity-mentions': [{'text': 'February',
#     'position': [862, 870],
#     'entity-type': 'DATE'},
#    {'text': 'about 45 000', 'position': [874, 886], 'entity-type': 'CARDINAL'},
#    {'text': 'June', 'position': [890, 894], 'entity-type': 'DATE'},
#    {'text': 'two', 'position': [970, 973], 'entity-type': 'CARDINAL'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'compound/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nsubj/dep=2/gov=3',
#    'advmod/dep=4/gov=29',
#    'case/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'nmod:over/dep=7/gov=4',
#    'case/dep=8/gov=9',
#    'nmod:in/dep=9/gov=7',
#    'mark/dep=10/gov=13',
#    'dep/dep=11/gov=13',
#    'compound/dep=12/gov=13',
#    'acl:to/dep=13/gov=9',
#    'case/dep=14/gov=15',
#    'nmod:in/dep=15/gov=13',
#    'amod/dep=16/gov=15',
#    'case/dep=17/gov=22',
#    'amod/dep=18/gov=22',
#    'amod/dep=19/gov=22',
#    'amod/dep=20/gov=22',
#    'compound/dep=21/gov=22',
#    'nmod:to/dep=22/gov=16',
#    'cc/dep=23/gov=22',
#    'det/dep=24/gov=26',
#    'nummod/dep=25/gov=26',
#    'nmod:to/dep=26/gov=16',
#    'conj:and/dep=26/gov=22',
#    'auxpass/dep=27/gov=29',
#    'advmod/dep=28/gov=29',
#    'dep/dep=29/gov=3',
#    'case/dep=30/gov=32',
#    'compound/dep=31/gov=32',
#    'nmod:as/dep=32/gov=29',
#    'nsubjpass/dep=33/gov=29',
#    'punct/dep=34/gov=29',
#    'punct/dep=35/gov=3'],
#   'words': ['food',
#    'security',
#    'conditions',
#    'declined',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operations',
#    'and',
#    'the',
#    'two',
#    'counties',
#    'are',
#    'currently',
#    'classified',
#    'as',
#    'IPC',
#    'Phase',
#    '4',
#    ':',
#    '?'],
#   'pos-tags': ['NN',
#    'NN',
#    'NNS',
#    'VBD',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'JJ',
#    'TO',
#    'JJ',
#    'JJ',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'DT',
#    'CD',
#    'NNS',
#    'VBP',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'NN',
#    'CD',
#    ':',
#    '.'],
#   'lemma': ['food',
#    'security',
#    'condition',
#    'decline',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operation',
#    'and',
#    'the',
#    'two',
#    'county',
#    'be',
#    'currently',
#    'classify',
#    'as',
#    'IPC',
#    'phase',
#    '4',
#    ':',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (NP (NN food) (NN security) (NNS conditions))\n    (VP (VBD declined)\n      (SBAR\n        (SINV\n          (ADVP (IN from)\n            (PP (IN over)\n              (NP\n                (QP (CD 100) (CD 000)))\n              (PP (IN in)\n                (NP\n                  (NP (NNP February))\n                  (SBAR\n                    (S\n                      (VP (TO to)\n                        (VP (IN about)\n                          (NP\n                            (QP (CD 45) (CD 000)))\n                          (PP (IN in)\n                            (NP\n                              (NP (NNP June))\n                              (ADJP (JJ due)\n                                (PP (TO to)\n                                  (NP\n                                    (NP (JJ sustained) (JJ multi-sectoral) (JJ humanitarian) (NN assistance) (NNS operations))\n                                    (CC and)\n                                    (NP (DT the) (CD two) (NNS counties)))))))))))))))\n          (VP (VBP are)\n            (ADVP (RB currently))\n            (VP (VBN classified)\n              (PP (IN as)\n                (NP (NNP IPC) (NN Phase)))))\n          (NP (CD 4))\n          (: :))))\n    (. ?)))'},
#  {'sentence': 'Emergency?.',
#   'position': [1025, 1036],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Emergency', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['emergency', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Emergency))\n    (. ?)))'},
#  {'sentence': 'Emergency?.',
#   'position': [1025, 1036],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Emergency', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['emergency', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Emergency))\n    (. ?)))'},
#  {'sentence': 'However, nationwide, the food insecure caseload (IPC Phases 3, 4 and 5) increased from about 5 million in February to a record high of 6 million in June as food access continues to be severely constrained by widespread insecurity, large scale displacements, high food prices, market disruptions, macro-economic collapse and exhaustion of households?',
#   'position': [1037, 1386],
#   'golden-entity-mentions': [{'text': '4',
#     'position': [1100, 1101],
#     'entity-type': 'CARDINAL'},
#    {'text': '5', 'position': [1106, 1107], 'entity-type': 'CARDINAL'},
#    {'text': 'about 5 million',
#     'position': [1124, 1139],
#     'entity-type': 'CARDINAL'},
#    {'text': 'February', 'position': [1143, 1151], 'entity-type': 'DATE'},
#    {'text': '6 million', 'position': [1172, 1181], 'entity-type': 'CARDINAL'},
#    {'text': 'June', 'position': [1185, 1189], 'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=36/gov=-1',
#    'advmod/dep=0/gov=36',
#    'punct/dep=1/gov=36',
#    'advmod/dep=2/gov=36',
#    'punct/dep=3/gov=36',
#    'det/dep=4/gov=7',
#    'compound/dep=5/gov=7',
#    'amod/dep=6/gov=7',
#    'nsubj/dep=7/gov=36',
#    'nsubjpass:xsubj/dep=7/gov=40',
#    'punct/dep=8/gov=10',
#    'compound/dep=9/gov=10',
#    'dep/dep=10/gov=7',
#    'dep/dep=11/gov=10',
#    'punct/dep=12/gov=10',
#    'appos/dep=13/gov=10',
#    'cc/dep=14/gov=13',
#    'appos/dep=15/gov=10',
#    'conj:and/dep=15/gov=13',
#    'punct/dep=16/gov=10',
#    'acl/dep=17/gov=7',
#    'case/dep=18/gov=21',
#    'case/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'nmod:about/dep=21/gov=17',
#    'case/dep=22/gov=23',
#    'nmod:in/dep=23/gov=21',
#    'case/dep=24/gov=27',
#    'det/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'nmod:to/dep=27/gov=17',
#    'case/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nmod:of/dep=30/gov=27',
#    'case/dep=31/gov=32',
#    'nmod:in/dep=32/gov=30',
#    'case/dep=33/gov=35',
#    'compound/dep=34/gov=35',
#    'nmod:as/dep=35/gov=17',
#    'mark/dep=37/gov=40',
#    'auxpass/dep=38/gov=40',
#    'advmod/dep=39/gov=40',
#    'xcomp/dep=40/gov=36',
#    'case/dep=41/gov=43',
#    'amod/dep=42/gov=43',
#    'nmod:agent/dep=43/gov=40',
#    'punct/dep=44/gov=43',
#    'amod/dep=45/gov=47',
#    'compound/dep=46/gov=47',
#    'nmod:agent/dep=47/gov=40',
#    'conj:and/dep=47/gov=43',
#    'punct/dep=48/gov=43',
#    'amod/dep=49/gov=51',
#    'compound/dep=50/gov=51',
#    'nmod:agent/dep=51/gov=40',
#    'conj:and/dep=51/gov=43',
#    'punct/dep=52/gov=43',
#    'compound/dep=53/gov=54',
#    'nmod:agent/dep=54/gov=40',
#    'conj:and/dep=54/gov=43',
#    'punct/dep=55/gov=43',
#    'amod/dep=56/gov=57',
#    'nmod:agent/dep=57/gov=40',
#    'conj:and/dep=57/gov=43',
#    'cc/dep=58/gov=43',
#    'nmod:agent/dep=59/gov=40',
#    'conj:and/dep=59/gov=43',
#    'case/dep=60/gov=61',
#    'nmod:of/dep=61/gov=59',
#    'punct/dep=62/gov=36'],
#   'words': ['However',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-LRB-',
#    'IPC',
#    'Phases',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-RRB-',
#    'increased',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continues',
#    'to',
#    'be',
#    'severely',
#    'constrained',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    ',',
#    'high',
#    'food',
#    'prices',
#    ',',
#    'market',
#    'disruptions',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'households',
#    '?'],
#   'pos-tags': ['RB',
#    ',',
#    'JJ',
#    ',',
#    'DT',
#    'NN',
#    'JJ',
#    'NN',
#    '-LRB-',
#    'NN',
#    'NNS',
#    'CD',
#    ',',
#    'CD',
#    'CC',
#    'CD',
#    '-RRB-',
#    'VBN',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'IN',
#    'NN',
#    'NN',
#    'VBZ',
#    'TO',
#    'VB',
#    'RB',
#    'VBN',
#    'IN',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'CC',
#    'NN',
#    'IN',
#    'NNS',
#    '.'],
#   'lemma': ['however',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-lrb-',
#    'ipc',
#    'phase',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-rrb-',
#    'increase',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continue',
#    'to',
#    'be',
#    'severely',
#    'constrain',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    ',',
#    'high',
#    'food',
#    'price',
#    ',',
#    'market',
#    'disruption',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'household',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB However))\n    (, ,)\n    (ADVP (JJ nationwide))\n    (, ,)\n    (NP\n      (NP\n        (NP (DT the) (NN food) (JJ insecure) (NN caseload))\n        (PRN (-LRB- -LRB-)\n          (NP\n            (NP (NN IPC) (NNS Phases))\n            (NP (CD 3))\n            (, ,)\n            (NP (CD 4)\n              (CC and)\n              (CD 5)))\n          (-RRB- -RRB-)))\n      (VP (VBN increased)\n        (PP (IN from) (IN about)\n          (NP\n            (NP\n              (QP (CD 5) (CD million)))\n            (PP (IN in)\n              (NP (NNP February)))))\n        (PP (TO to)\n          (NP\n            (NP (DT a) (NN record) (NN high))\n            (PP (IN of)\n              (NP\n                (NP\n                  (QP (CD 6) (CD million)))\n                (PP (IN in)\n                  (NP (NNP June)))))))\n        (PP (IN as)\n          (NP (NN food) (NN access)))))\n    (VP (VBZ continues)\n      (S\n        (VP (TO to)\n          (VP (VB be)\n            (VP\n              (ADVP (RB severely))\n              (VBN constrained)\n              (PP (IN by)\n                (NP\n                  (NP (JJ widespread) (NN insecurity))\n                  (, ,)\n                  (NP (JJ large) (NN scale) (NNS displacements))\n                  (, ,)\n                  (NP (JJ high) (NN food) (NNS prices))\n                  (, ,)\n                  (NP (NN market) (NNS disruptions))\n                  (, ,)\n                  (NP (JJ macro-economic) (NN collapse))\n                  (CC and)\n                  (NP\n                    (NP (NN exhaustion))\n                    (PP (IN of)\n                      (NP (NNS households)))))))))))\n    (. ?)))'},
#  {'sentence': 'However, nationwide, the food insecure caseload (IPC Phases 3, 4 and 5) increased from about 5 million in February to a record high of 6 million in June as food access continues to be severely constrained by widespread insecurity, large scale displacements, high food prices, market disruptions, macro-economic collapse and exhaustion of households?',
#   'position': [1037, 1386],
#   'golden-entity-mentions': [{'text': '4',
#     'position': [1100, 1101],
#     'entity-type': 'CARDINAL'},
#    {'text': '5', 'position': [1106, 1107], 'entity-type': 'CARDINAL'},
#    {'text': 'about 5 million',
#     'position': [1124, 1139],
#     'entity-type': 'CARDINAL'},
#    {'text': 'February', 'position': [1143, 1151], 'entity-type': 'DATE'},
#    {'text': '6 million', 'position': [1172, 1181], 'entity-type': 'CARDINAL'},
#    {'text': 'June', 'position': [1185, 1189], 'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=36/gov=-1',
#    'advmod/dep=0/gov=36',
#    'punct/dep=1/gov=36',
#    'advmod/dep=2/gov=36',
#    'punct/dep=3/gov=36',
#    'det/dep=4/gov=7',
#    'compound/dep=5/gov=7',
#    'amod/dep=6/gov=7',
#    'nsubj/dep=7/gov=36',
#    'nsubjpass:xsubj/dep=7/gov=40',
#    'punct/dep=8/gov=10',
#    'compound/dep=9/gov=10',
#    'dep/dep=10/gov=7',
#    'dep/dep=11/gov=10',
#    'punct/dep=12/gov=10',
#    'appos/dep=13/gov=10',
#    'cc/dep=14/gov=13',
#    'appos/dep=15/gov=10',
#    'conj:and/dep=15/gov=13',
#    'punct/dep=16/gov=10',
#    'acl/dep=17/gov=7',
#    'case/dep=18/gov=21',
#    'case/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'nmod:about/dep=21/gov=17',
#    'case/dep=22/gov=23',
#    'nmod:in/dep=23/gov=21',
#    'case/dep=24/gov=27',
#    'det/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'nmod:to/dep=27/gov=17',
#    'case/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nmod:of/dep=30/gov=27',
#    'case/dep=31/gov=32',
#    'nmod:in/dep=32/gov=30',
#    'case/dep=33/gov=35',
#    'compound/dep=34/gov=35',
#    'nmod:as/dep=35/gov=17',
#    'mark/dep=37/gov=40',
#    'auxpass/dep=38/gov=40',
#    'advmod/dep=39/gov=40',
#    'xcomp/dep=40/gov=36',
#    'case/dep=41/gov=43',
#    'amod/dep=42/gov=43',
#    'nmod:agent/dep=43/gov=40',
#    'punct/dep=44/gov=43',
#    'amod/dep=45/gov=47',
#    'compound/dep=46/gov=47',
#    'nmod:agent/dep=47/gov=40',
#    'conj:and/dep=47/gov=43',
#    'punct/dep=48/gov=43',
#    'amod/dep=49/gov=51',
#    'compound/dep=50/gov=51',
#    'nmod:agent/dep=51/gov=40',
#    'conj:and/dep=51/gov=43',
#    'punct/dep=52/gov=43',
#    'compound/dep=53/gov=54',
#    'nmod:agent/dep=54/gov=40',
#    'conj:and/dep=54/gov=43',
#    'punct/dep=55/gov=43',
#    'amod/dep=56/gov=57',
#    'nmod:agent/dep=57/gov=40',
#    'conj:and/dep=57/gov=43',
#    'cc/dep=58/gov=43',
#    'nmod:agent/dep=59/gov=40',
#    'conj:and/dep=59/gov=43',
#    'case/dep=60/gov=61',
#    'nmod:of/dep=61/gov=59',
#    'punct/dep=62/gov=36'],
#   'words': ['However',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-LRB-',
#    'IPC',
#    'Phases',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-RRB-',
#    'increased',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continues',
#    'to',
#    'be',
#    'severely',
#    'constrained',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    ',',
#    'high',
#    'food',
#    'prices',
#    ',',
#    'market',
#    'disruptions',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'households',
#    '?'],
#   'pos-tags': ['RB',
#    ',',
#    'JJ',
#    ',',
#    'DT',
#    'NN',
#    'JJ',
#    'NN',
#    '-LRB-',
#    'NN',
#    'NNS',
#    'CD',
#    ',',
#    'CD',
#    'CC',
#    'CD',
#    '-RRB-',
#    'VBN',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'IN',
#    'NN',
#    'NN',
#    'VBZ',
#    'TO',
#    'VB',
#    'RB',
#    'VBN',
#    'IN',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'CC',
#    'NN',
#    'IN',
#    'NNS',
#    '.'],
#   'lemma': ['however',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-lrb-',
#    'ipc',
#    'phase',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-rrb-',
#    'increase',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continue',
#    'to',
#    'be',
#    'severely',
#    'constrain',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    ',',
#    'high',
#    'food',
#    'price',
#    ',',
#    'market',
#    'disruption',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'household',
#    '?'],
# ...
#    'rainfall',
#    'areas',
#    'and',
#    'the',
#    'establishment',
#    ',',
#    'by',
#    'the',
#    'Government',
#    ',',
#    'of',
#    'a',
#    'trading',
#    'company',
#    'selling',
#    'basic',
#    'food',
#    'commodities',
#    'at',
#    'subsidized',
#    'prices',
#    '.'],
#   'pos-tags': ['RB',
#    ',',
#    'PRP',
#    'VBD',
#    'IN',
#    'RB',
#    'CD',
#    'NN',
#    'IN',
#    'NNP',
#    'CC',
#    'NNP',
#    ',',
#    'VBG',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'JJ',
#    'JJ',
#    'NNS',
#    'NNS',
#    'CC',
#    'DT',
#    'NN',
#    ',',
#    'IN',
#    'DT',
#    'NN',
#    ',',
#    'IN',
#    'DT',
#    'NN',
#    'NN',
#    'VBG',
#    'JJ',
#    'NN',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNS',
#    '.'],
#   'lemma': ['subsequently',
#    ',',
#    'they',
#    'decline',
#    'by',
#    'about',
#    '12',
#    'percent',
#    'between',
#    'June',
#    'and',
#    'August',
#    ',',
#    'follow',
#    'the',
#    'first',
#    'season',
#    'harvest',
#    'in',
#    'southern',
#    'bimodal',
#    'rainfall',
#    'area',
#    'and',
#    'the',
#    'establishment',
#    ',',
#    'by',
#    'the',
#    'government',
#    ',',
#    'of',
#    'a',
#    'trading',
#    'company',
#    'sell',
#    'basic',
#    'food',
#    'commodity',
#    'at',
#    'subsidized',
#    'price',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB Subsequently))\n    (, ,)\n    (NP (PRP they))\n    (VP (VBD declined)\n      (PP (IN by)\n        (NP\n          (NP\n            (QP (RB about) (CD 12))\n            (NN percent))\n          (PP (IN between)\n            (NP (NNP June)\n              (CC and)\n              (NNP August)))\n          (, ,)\n          (PP (VBG following)\n            (NP\n              (NP (DT the) (JJ first) (NN season) (NN harvest))\n              (PP (IN in)\n                (NP\n                  (NP (JJ southern) (JJ bimodal) (NNS rainfall) (NNS areas))\n                  (CC and)\n                  (NP (DT the) (NN establishment))))))))\n      (, ,)\n      (PP (IN by)\n        (NP\n          (NP (DT the) (NN Government))\n          (, ,)\n          (PP (IN of)\n            (NP\n              (NP (DT a) (NN trading) (NN company))\n              (VP (VBG selling)\n                (NP (JJ basic) (NN food) (NNS commodities))\n                (PP (IN at)\n                  (NP (JJ subsidized) (NNS prices)))))))))\n    (. .)))'},
#  {'sentence': 'Prices of groundnuts decreased by 22 percent over the same period, while prices of wheat flour continued to soar in recent months, reaching new record highs in August.',
#   'position': [4297, 4464],
#   'golden-entity-mentions': [{'text': '22 percent',
#     'position': [4331, 4341],
#     'entity-type': 'PERCENT'},
#    {'text': 'the same period',
#     'position': [4347, 4362],
#     'entity-type': 'DATE'},
#    {'text': 'recent months', 'position': [4413, 4426], 'entity-type': 'DATE'},
#    {'text': 'August', 'position': [4457, 4463], 'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'nsubj/dep=0/gov=3',
#    'case/dep=1/gov=2',
#    'nmod:of/dep=2/gov=0',
#    'case/dep=4/gov=6',
#    'nummod/dep=5/gov=6',
#    'nmod:by/dep=6/gov=3',
#    'case/dep=7/gov=10',
#    'det/dep=8/gov=10',
#    'amod/dep=9/gov=10',
#    'nmod:over/dep=10/gov=3',
#    'punct/dep=11/gov=3',
#    'mark/dep=12/gov=17',
#    'nsubj/dep=13/gov=17',
#    'nsubj:xsubj/dep=13/gov=19',
#    'case/dep=14/gov=16',
#    'compound/dep=15/gov=16',
#    'nmod:of/dep=16/gov=13',
#    'advcl:while/dep=17/gov=3',
#    'mark/dep=18/gov=19',
#    'xcomp/dep=19/gov=17',
#    'case/dep=20/gov=22',
#    'amod/dep=21/gov=22',
#    'nmod:in/dep=22/gov=19',
#    'punct/dep=23/gov=17',
#    'xcomp/dep=24/gov=17',
#    'amod/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'dobj/dep=27/gov=24',
#    'case/dep=28/gov=29',
#    'nmod:in/dep=29/gov=24',
#    'punct/dep=30/gov=3'],
#   'words': ['Prices',
#    'of',
#    'groundnuts',
#    'decreased',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'prices',
#    'of',
#    'wheat',
#    'flour',
#    'continued',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'months',
#    ',',
#    'reaching',
#    'new',
#    'record',
#    'highs',
#    'in',
#    'August',
#    '.'],
#   'pos-tags': ['NNS',
#    'IN',
#    'NNS',
#    'VBN',
#    'IN',
#    'CD',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'IN',
#    'NNS',
#    'IN',
#    'NN',
#    'NN',
#    'VBD',
#    'TO',
#    'VB',
#    'IN',
#    'JJ',
#    'NNS',
#    ',',
#    'VBG',
#    'JJ',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    '.'],
#   'lemma': ['price',
#    'of',
#    'groundnut',
#    'decrease',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'price',
#    'of',
#    'wheat',
#    'flour',
#    'continue',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'month',
#    ',',
#    'reach',
#    'new',
#    'record',
#    'high',
#    'in',
#    'August',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (NNS Prices))\n      (PP (IN of)\n        (NP (NNS groundnuts))))\n    (VP (VBN decreased)\n      (PP (IN by)\n        (NP (CD 22) (NN percent)))\n      (PP (IN over)\n        (NP (DT the) (JJ same) (NN period)))\n      (, ,)\n      (SBAR (IN while)\n        (S\n          (NP\n            (NP (NNS prices))\n            (PP (IN of)\n              (NP (NN wheat) (NN flour))))\n          (VP (VBD continued)\n            (S\n              (VP (TO to)\n                (VP (VB soar)\n                  (PP (IN in)\n                    (NP (JJ recent) (NNS months))))))\n            (, ,)\n            (S\n              (VP (VBG reaching)\n                (NP (JJ new) (NN record) (NNS highs))\n                (PP (IN in)\n                  (NP (NNP August)))))))))\n    (. .)))'},
#  {'sentence': 'Prices of groundnuts decreased by 22 percent over the same period, while prices of wheat flour continued to soar in recent months, reaching new record highs in August.',
#   'position': [4297, 4464],
#   'golden-entity-mentions': [{'text': '22 percent',
#     'position': [4331, 4341],
#     'entity-type': 'PERCENT'},
#    {'text': 'the same period',
#     'position': [4347, 4362],
#     'entity-type': 'DATE'},
#    {'text': 'recent months', 'position': [4413, 4426], 'entity-type': 'DATE'},
#    {'text': 'August', 'position': [4457, 4463], 'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'nsubj/dep=0/gov=3',
#    'case/dep=1/gov=2',
#    'nmod:of/dep=2/gov=0',
#    'case/dep=4/gov=6',
#    'nummod/dep=5/gov=6',
#    'nmod:by/dep=6/gov=3',
#    'case/dep=7/gov=10',
#    'det/dep=8/gov=10',
#    'amod/dep=9/gov=10',
#    'nmod:over/dep=10/gov=3',
#    'punct/dep=11/gov=3',
#    'mark/dep=12/gov=17',
#    'nsubj/dep=13/gov=17',
#    'nsubj:xsubj/dep=13/gov=19',
#    'case/dep=14/gov=16',
#    'compound/dep=15/gov=16',
#    'nmod:of/dep=16/gov=13',
#    'advcl:while/dep=17/gov=3',
#    'mark/dep=18/gov=19',
#    'xcomp/dep=19/gov=17',
#    'case/dep=20/gov=22',
#    'amod/dep=21/gov=22',
#    'nmod:in/dep=22/gov=19',
#    'punct/dep=23/gov=17',
#    'xcomp/dep=24/gov=17',
#    'amod/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'dobj/dep=27/gov=24',
#    'case/dep=28/gov=29',
#    'nmod:in/dep=29/gov=24',
#    'punct/dep=30/gov=3'],
#   'words': ['Prices',
#    'of',
#    'groundnuts',
#    'decreased',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'prices',
#    'of',
#    'wheat',
#    'flour',
#    'continued',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'months',
#    ',',
#    'reaching',
#    'new',
#    'record',
#    'highs',
#    'in',
#    'August',
#    '.'],
#   'pos-tags': ['NNS',
#    'IN',
#    'NNS',
#    'VBN',
#    'IN',
#    'CD',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'IN',
#    'NNS',
#    'IN',
#    'NN',
#    'NN',
#    'VBD',
#    'TO',
#    'VB',
#    'IN',
#    'JJ',
#    'NNS',
#    ',',
#    'VBG',
#    'JJ',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    '.'],
#   'lemma': ['price',
#    'of',
#    'groundnut',
#    'decrease',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'price',
#    'of',
#    'wheat',
#    'flour',
#    'continue',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'month',
#    ',',
#    'reach',
#    'new',
#    'record',
#    'high',
#    'in',
#    'August',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (NNS Prices))\n      (PP (IN of)\n        (NP (NNS groundnuts))))\n    (VP (VBN decreased)\n      (PP (IN by)\n        (NP (CD 22) (NN percent)))\n      (PP (IN over)\n        (NP (DT the) (JJ same) (NN period)))\n      (, ,)\n      (SBAR (IN while)\n        (S\n          (NP\n            (NP (NNS prices))\n            (PP (IN of)\n              (NP (NN wheat) (NN flour))))\n          (VP (VBD continued)\n            (S\n              (VP (TO to)\n                (VP (VB soar)\n                  (PP (IN in)\n                    (NP (JJ recent) (NNS months))))))\n            (, ,)\n            (S\n              (VP (VBG reaching)\n                (NP (JJ new) (NN record) (NNS highs))\n                (PP (IN in)\n                  (NP (NNP August)))))))))\n    (. .)))'},
#  {'sentence': 'Overall, prices of these food staples in August were more than twice the high levels in August last year and up to 12 times higher than in the corresponding period two years earlier.',
#   'position': [4465, 4647],
#   'golden-entity-mentions': [{'text': 'August',
#     'position': [4506, 4512],
#     'entity-type': 'DATE'},
#    {'text': 'August last year',
#     'position': [4553, 4569],
#     'entity-type': 'DATE'},
#    {'text': 'up to 12', 'position': [4574, 4582], 'entity-type': 'CARDINAL'},
#    {'text': 'two years earlier',
#     'position': [4629, 4646],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=10/gov=-1',
#    'advmod/dep=0/gov=10',
#    'punct/dep=1/gov=10',
#    'nsubj/dep=2/gov=10',
#    'nsubj/dep=2/gov=25',
#    'case/dep=3/gov=6',
#    'det/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'nmod:of/dep=6/gov=2',
#    'case/dep=7/gov=8',
#    'nmod:in/dep=8/gov=6',
#    'cop/dep=9/gov=10',
#    'case/dep=11/gov=15',
#    'advmod/dep=12/gov=15',
#    'det/dep=13/gov=15',
#    'amod/dep=14/gov=15',
#    'nmod:than/dep=15/gov=10',
#    'case/dep=16/gov=17',
#    'nmod:in/dep=17/gov=15',
#    'amod/dep=18/gov=19',
#    'nmod:tmod/dep=19/gov=15',
#    'cc/dep=20/gov=10',
#    'dep/dep=21/gov=23',
#    'mwe/dep=22/gov=21',
#    'nummod/dep=23/gov=24',
#    'nmod:npmod/dep=24/gov=25',
#    'conj:and/dep=25/gov=10',
#    'case/dep=26/gov=30',
#    'case/dep=27/gov=30',
#    'det/dep=28/gov=30',
#    'amod/dep=29/gov=30',
#    'nmod:in/dep=30/gov=25',
#    'nummod/dep=31/gov=32',
#    'nmod:npmod/dep=32/gov=33',
#    'advmod/dep=33/gov=10',
#    'punct/dep=34/gov=10'],
#   'words': ['Overall',
#    ',',
#    'prices',
#    'of',
#    'these',
#    'food',
#    'staples',
#    'in',
#    'August',
#    'were',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'levels',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'times',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'years',
#    'earlier',
#    '.'],
#   'pos-tags': ['RB',
#    ',',
#    'NNS',
#    'IN',
#    'DT',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    'VBD',
#    'JJR',
#    'IN',
#    'RB',
#    'DT',
#    'JJ',
#    'NNS',
#    'IN',
#    'NNP',
#    'JJ',
#    'NN',
#    'CC',
#    'IN',
#    'TO',
#    'CD',
#    'NNS',
#    'JJR',
#    'IN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'CD',
#    'NNS',
#    'RBR',
#    '.'],
#   'lemma': ['overall',
#    ',',
#    'price',
#    'of',
#    'these',
#    'food',
#    'staple',
#    'in',
#    'August',
#    'be',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'level',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'time',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'year',
#    'earlier',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB Overall))\n    (, ,)\n    (NP\n      (NP (NNS prices))\n      (PP (IN of)\n        (NP\n          (NP (DT these) (NN food) (NNS staples))\n          (PP (IN in)\n            (NP (NNP August))))))\n    (VP (VBD were)\n      (ADJP\n        (ADJP (JJR more)\n          (PP (IN than)\n            (NP\n              (NP (RB twice) (DT the) (JJ high) (NNS levels))\n              (PP (IN in)\n                (NP (NNP August)))\n              (NP-TMP (JJ last) (NN year)))))\n        (CC and)\n        (ADJP\n          (NP\n            (QP (IN up) (TO to) (CD 12))\n            (NNS times))\n          (JJR higher)\n          (PP (IN than)\n            (PP (IN in)\n              (NP (DT the) (JJ corresponding) (NN period)))))\n        (ADVP\n          (NP (CD two) (NNS years))\n          (RBR earlier))))\n    (. .)))'},
#  {'sentence': 'Overall, prices of these food staples in August were more than twice the high levels in August last year and up to 12 times higher than in the corresponding period two years earlier.',
#   'position': [4465, 4647],
#   'golden-entity-mentions': [{'text': 'August',
#     'position': [4506, 4512],
#     'entity-type': 'DATE'},
#    {'text': 'August last year',
#     'position': [4553, 4569],
#     'entity-type': 'DATE'},
#    {'text': 'up to 12', 'position': [4574, 4582], 'entity-type': 'CARDINAL'},
#    {'text': 'two years earlier',
#     'position': [4629, 4646],
#     'entity-type': 'DATE'}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=10/gov=-1',
#    'advmod/dep=0/gov=10',
#    'punct/dep=1/gov=10',
#    'nsubj/dep=2/gov=10',
#    'nsubj/dep=2/gov=25',
#    'case/dep=3/gov=6',
#    'det/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'nmod:of/dep=6/gov=2',
#    'case/dep=7/gov=8',
#    'nmod:in/dep=8/gov=6',
#    'cop/dep=9/gov=10',
#    'case/dep=11/gov=15',
#    'advmod/dep=12/gov=15',
#    'det/dep=13/gov=15',
#    'amod/dep=14/gov=15',
#    'nmod:than/dep=15/gov=10',
#    'case/dep=16/gov=17',
#    'nmod:in/dep=17/gov=15',
#    'amod/dep=18/gov=19',
#    'nmod:tmod/dep=19/gov=15',
#    'cc/dep=20/gov=10',
#    'dep/dep=21/gov=23',
#    'mwe/dep=22/gov=21',
#    'nummod/dep=23/gov=24',
#    'nmod:npmod/dep=24/gov=25',
#    'conj:and/dep=25/gov=10',
#    'case/dep=26/gov=30',
#    'case/dep=27/gov=30',
#    'det/dep=28/gov=30',
#    'amod/dep=29/gov=30',
#    'nmod:in/dep=30/gov=25',
#    'nummod/dep=31/gov=32',
#    'nmod:npmod/dep=32/gov=33',
#    'advmod/dep=33/gov=10',
#    'punct/dep=34/gov=10'],
#   'words': ['Overall',
#    ',',
#    'prices',
#    'of',
#    'these',
#    'food',
#    'staples',
#    'in',
#    'August',
#    'were',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'levels',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'times',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'years',
#    'earlier',
#    '.'],
#   'pos-tags': ['RB',
#    ',',
#    'NNS',
#    'IN',
#    'DT',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    'VBD',
#    'JJR',
#    'IN',
#    'RB',
#    'DT',
#    'JJ',
#    'NNS',
#    'IN',
#    'NNP',
#    'JJ',
#    'NN',
#    'CC',
#    'IN',
#    'TO',
#    'CD',
#    'NNS',
#    'JJR',
#    'IN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'CD',
#    'NNS',
#    'RBR',
#    '.'],
#   'lemma': ['overall',
#    ',',
#    'price',
#    'of',
#    'these',
#    'food',
#    'staple',
#    'in',
#    'August',
#    'be',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'level',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'time',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'year',
#    'earlier',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB Overall))\n    (, ,)\n    (NP\n      (NP (NNS prices))\n      (PP (IN of)\n        (NP\n          (NP (DT these) (NN food) (NNS staples))\n          (PP (IN in)\n            (NP (NNP August))))))\n    (VP (VBD were)\n      (ADJP\n        (ADJP (JJR more)\n          (PP (IN than)\n            (NP\n              (NP (RB twice) (DT the) (JJ high) (NNS levels))\n              (PP (IN in)\n                (NP (NNP August)))\n              (NP-TMP (JJ last) (NN year)))))\n        (CC and)\n        (ADJP\n          (NP\n            (QP (IN up) (TO to) (CD 12))\n            (NNS times))\n          (JJR higher)\n          (PP (IN than)\n            (PP (IN in)\n              (NP (DT the) (JJ corresponding) (NN period)))))\n        (ADVP\n          (NP (CD two) (NNS years))\n          (RBR earlier))))\n    (. .)))'}]

# %%
print(sentences[0])
# Out:
# {'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?', 'position': [0, 794], 'golden-entity-mentions': [{'text': 'GIEWS', 'position': [0, 5], 'entity-type': 'ORG'}, {'text': '6 million', 'position': [294, 303], 'entity-type': 'CARDINAL'}, {'text': 'June 2017', 'position': [307, 316], 'entity-type': 'DATE'}, {'text': 'Unfavourable', 'position': [319, 331], 'entity-type': 'ORG'}, {'text': '2017', 'position': [346, 350], 'entity-type': 'CARDINAL'}, {'text': 'Fall Armyworm', 'position': [417, 430], 'entity-type': 'PERSON'}, {'text': 'IPC', 'position': [570, 573], 'entity-type': 'ORG'}, {'text': 'February 2017', 'position': [626, 639], 'entity-type': 'DATE'}, {'text': 'Leer', 'position': [650, 654], 'entity-type': 'ORG'}, {'text': 'Mayendit', 'position': [659, 667], 'entity-type': 'ORG'}, {'text': 'Unity State', 'position': [687, 698], 'entity-type': 'ORG'}, {'text': 'late June 2017.Overall', 'position': [728, 750], 'entity-type': 'DATE'}, {'text': 'IPC', 'position': [780, 783], 'entity-type': 'ORG'}, {'text': '5', 'position': [790, 791], 'entity-type': 'CARDINAL'}], 'golden-event-mentions': []}

# %%
print(post11[0])
# Out:
# {'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?', 'position': [0, 794], 'golden-entity-mentions': [{'text': 'GIEWS', 'position': [0, 5], 'entity-type': 'ORG'}, {'text': '6 million', 'position': [294, 303], 'entity-type': 'CARDINAL'}, {'text': 'June 2017', 'position': [307, 316], 'entity-type': 'DATE'}, {'text': 'Unfavourable', 'position': [319, 331], 'entity-type': 'ORG'}, {'text': '2017', 'position': [346, 350], 'entity-type': 'CARDINAL'}, {'text': 'Fall Armyworm', 'position': [417, 430], 'entity-type': 'PERSON'}, {'text': 'IPC', 'position': [570, 573], 'entity-type': 'ORG'}, {'text': 'February 2017', 'position': [626, 639], 'entity-type': 'DATE'}, {'text': 'Leer', 'position': [650, 654], 'entity-type': 'ORG'}, {'text': 'Mayendit', 'position': [659, 667], 'entity-type': 'ORG'}, {'text': 'Unity State', 'position': [687, 698], 'entity-type': 'ORG'}, {'text': 'late June 2017.Overall', 'position': [728, 750], 'entity-type': 'DATE'}, {'text': 'IPC', 'position': [780, 783], 'entity-type': 'ORG'}, {'text': '5', 'position': [790, 791], 'entity-type': 'CARDINAL'}], 'golden-event-mentions': [], 'stanford-colcc': ['ROOT/dep=24/gov=-1', 'compound/dep=0/gov=2', 'amod/dep=1/gov=2', 'nsubj/dep=2/gov=24', 'cc/dep=3/gov=2', 'amod/dep=4/gov=6', 'compound/dep=5/gov=6', 'conj:and/dep=6/gov=2', 'nsubj/dep=6/gov=24', 'case/dep=7/gov=8', 'nmod:on/dep=8/gov=6', 'cc/dep=9/gov=8', 'nmod:on/dep=10/gov=6', 'conj:and/dep=10/gov=8', 'compound/dep=11/gov=17', 'compound/dep=12/gov=17', 'compound/dep=13/gov=17', 'compound/dep=14/gov=17', 'compound/dep=15/gov=17', 'compound/dep=16/gov=17', 'dep/dep=17/gov=6', 'punct/dep=18/gov=6', 'amod/dep=19/gov=21', 'compound/dep=20/gov=21', 'dep/dep=21/gov=6', 'compound/dep=22/gov=23', 'dep/dep=23/gov=21', 'compound:prt/dep=25/gov=24', 'punct/dep=26/gov=24', 'cc/dep=27/gov=24', 'compound/dep=28/gov=30', 'compound/dep=29/gov=30', 'nsubj/dep=30/gov=110', 'advmod/dep=31/gov=32', 'amod/dep=32/gov=36', 'case/dep=33/gov=35', 'det/dep=34/gov=35', 'nmod:across/dep=35/gov=32', 'nmod/dep=36/gov=30', 'amod/dep=37/gov=38', 'dep/dep=38/gov=36', 'acl/dep=39/gov=38', 'case/dep=40/gov=41', 'nmod:at/dep=41/gov=39', 'amod/dep=42/gov=49', 'compound/dep=43/gov=44', 'dep/dep=44/gov=42', 'case/dep=45/gov=46', 'nmod:in/dep=46/gov=44', 'nummod/dep=47/gov=46', 'compound/dep=48/gov=49', 'nsubj/dep=49/gov=72', 'case/dep=50/gov=66', 'nummod/dep=51/gov=52', 'nmod:npmod/dep=52/gov=53', 'amod/dep=53/gov=66', 'case/dep=54/gov=56', 'amod/dep=55/gov=56', 'nmod:to/dep=56/gov=53', 'punct/dep=57/gov=56', 'amod/dep=58/gov=60', 'compound/dep=59/gov=60', 'nmod:to/dep=60/gov=53', 'conj:and/dep=60/gov=56', 'cc/dep=61/gov=56', 'compound/dep=62/gov=64', 'compound/dep=63/gov=64', 'nmod:to/dep=64/gov=53', 'conj:and/dep=64/gov=56', 'compound/dep=65/gov=66', 'nmod:for/dep=66/gov=49', 'case/dep=67/gov=71', 'advmod/dep=68/gov=69', 'amod/dep=69/gov=71', 'compound/dep=70/gov=71', 'nmod:at/dep=71/gov=66', 'acl:relcl/dep=72/gov=41', 'compound:prt/dep=73/gov=72', 'punct/dep=74/gov=72', 'cc/dep=75/gov=72', 'compound/dep=76/gov=78', 'compound/dep=77/gov=78', 'acl:relcl/dep=78/gov=41', 'conj:but/dep=78/gov=72', 'advmod/dep=79/gov=80', 'amod/dep=80/gov=78', 'case/dep=81/gov=86', 'mwe/dep=82/gov=81', 'det/dep=83/gov=86 ...

# %%
check_it = fix_entity_indices(post11, Snlp)

# %%
check_it
# Out:
# [{'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?',
#   'position': [0, 794],
#   'golden-entity-mentions': [{'text': 'GIEWS',
#     'position': [0, 5],
#     'entity-type': 'ORG',
#     'start': 0,
#     'end': 1},
#    {'text': '6 million',
#     'position': [294, 303],
#     'entity-type': 'CARDINAL',
#     'start': 43,
#     'end': 45},
#    {'text': 'June 2017',
#     'position': [307, 316],
#     'entity-type': 'DATE',
#     'start': 46,
#     'end': 48},
#    {'text': 'Unfavourable',
#     'position': [319, 331],
#     'entity-type': 'ORG',
#     'start': 48,
#     'end': 49},
#    {'text': '2017',
#     'position': [346, 350],
#     'entity-type': 'CARDINAL',
#     'start': 51,
#     'end': 52},
#    {'text': 'Fall Armyworm',
#     'position': [417, 430],
#     'entity-type': 'PERSON',
#     'start': 62,
#     'end': 64},
#    {'text': 'IPC',
#     'position': [570, 573],
#     'entity-type': 'ORG',
#     'start': 85,
#     'end': 86},
#    {'text': 'February 2017',
#     'position': [626, 639],
#     'entity-type': 'DATE',
#     'start': 94,
#     'end': 96},
#    {'text': 'Leer',
#     'position': [650, 654],
#     'entity-type': 'ORG',
#     'start': 98,
#     'end': 99},
#    {'text': 'Mayendit',
#     'position': [659, 667],
#     'entity-type': 'ORG',
#     'start': 100,
#     'end': 101},
#    {'text': 'Unity State',
#     'position': [687, 698],
#     'entity-type': 'ORG',
#     'start': 104,
#     'end': 106},
#    {'text': 'late June 2017.Overall',
#     'position': [728, 750],
#     'entity-type': 'DATE',
#     'start': 112,
#     'end': -1},
#    {'text': 'IPC',
#     'position': [780, 783],
#     'entity-type': 'ORG',
#     'start': 115,
#     'end': -1},
#    {'text': '5',
#     'position': [790, 791],
#     'entity-type': 'CARDINAL',
#     'start': 115,
#     'end': -1}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=24/gov=-1',
#    'compound/dep=0/gov=2',
#    'amod/dep=1/gov=2',
#    'nsubj/dep=2/gov=24',
#    'cc/dep=3/gov=2',
#    'amod/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'conj:and/dep=6/gov=2',
#    'nsubj/dep=6/gov=24',
#    'case/dep=7/gov=8',
#    'nmod:on/dep=8/gov=6',
#    'cc/dep=9/gov=8',
#    'nmod:on/dep=10/gov=6',
#    'conj:and/dep=10/gov=8',
#    'compound/dep=11/gov=17',
#    'compound/dep=12/gov=17',
#    'compound/dep=13/gov=17',
#    'compound/dep=14/gov=17',
#    'compound/dep=15/gov=17',
#    'compound/dep=16/gov=17',
#    'dep/dep=17/gov=6',
#    'punct/dep=18/gov=6',
#    'amod/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'dep/dep=21/gov=6',
#    'compound/dep=22/gov=23',
#    'dep/dep=23/gov=21',
#    'compound:prt/dep=25/gov=24',
#    'punct/dep=26/gov=24',
#    'cc/dep=27/gov=24',
#    'compound/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nsubj/dep=30/gov=110',
#    'advmod/dep=31/gov=32',
#    'amod/dep=32/gov=36',
#    'case/dep=33/gov=35',
#    'det/dep=34/gov=35',
#    'nmod:across/dep=35/gov=32',
#    'nmod/dep=36/gov=30',
#    'amod/dep=37/gov=38',
#    'dep/dep=38/gov=36',
#    'acl/dep=39/gov=38',
#    'case/dep=40/gov=41',
#    'nmod:at/dep=41/gov=39',
#    'amod/dep=42/gov=49',
#    'compound/dep=43/gov=44',
#    'dep/dep=44/gov=42',
#    'case/dep=45/gov=46',
#    'nmod:in/dep=46/gov=44',
#    'nummod/dep=47/gov=46',
#    'compound/dep=48/gov=49',
#    'nsubj/dep=49/gov=72',
#    'case/dep=50/gov=66',
#    'nummod/dep=51/gov=52',
#    'nmod:npmod/dep=52/gov=53',
#    'amod/dep=53/gov=66',
#    'case/dep=54/gov=56',
#    'amod/dep=55/gov=56',
#    'nmod:to/dep=56/gov=53',
#    'punct/dep=57/gov=56',
#    'amod/dep=58/gov=60',
#    'compound/dep=59/gov=60',
#    'nmod:to/dep=60/gov=53',
#    'conj:and/dep=60/gov=56',
#    'cc/dep=61/gov=56',
#    'compound/dep=62/gov=64',
#    'compound/dep=63/gov=64',
#    'nmod:to/dep=64/gov=53',
#    'conj:and/dep=64/gov=56',
#    'compound/dep=65/gov=66',
#    'nmod:for/dep=66/gov=49',
#    'case/dep=67/gov=71',
#    'advmod/dep=68/gov=69',
#    'amod/dep=69/gov=71',
#    'compound/dep=70/gov=71',
#    'nmod:at/dep=71/gov=66',
#    'acl:relcl/dep=72/gov=41',
#    'compound:prt/dep=73/gov=72',
#    'punct/dep=74/gov=72',
#    'cc/dep=75/gov=72',
#    'compound/dep=76/gov=78',
#    'compound/dep=77/gov=78',
#    'acl:relcl/dep=78/gov=41',
#    'conj:but/dep=78/gov=72',
#    'advmod/dep=79/gov=80',
#    'amod/dep=80/gov=78',
#    'case/dep=81/gov=86',
#    'mwe/dep=82/gov=81',
#    'det/dep=83/gov=86',
#    'amod/dep=84/gov=86',
#    'compound/dep=85/gov=86',
#    'nmod:according_to/dep=86/gov=78',
#    'punct/dep=87/gov=86',
#    'compound/dep=88/gov=89',
#    'appos/dep=89/gov=86',
#    'punct/dep=90/gov=30',
#    'advmod/dep=91/gov=92',
#    'acl/dep=92/gov=30',
#    'case/dep=93/gov=94',
#    'nmod:in/dep=94/gov=92',
#    'nummod/dep=95/gov=94',
#    'case/dep=96/gov=98',
#    'amod/dep=97/gov=98',
#    'nmod:in/dep=98/gov=94',
#    'cc/dep=99/gov=98',
#    'compound/dep=100/gov=101',
#    'nmod:in/dep=101/gov=94',
#    'conj:and/dep=101/gov=98',
#    'case/dep=102/gov=105',
#    'amod/dep=103/gov=105',
#    'compound/dep=104/gov=105',
#    'nmod:in/dep=105/gov=92',
#    'punct/dep=106/gov=30',
#    'aux/dep=107/gov=110',
#    'neg/dep=108/gov=109',
#    'advmod/dep=109/gov=110',
#    'conj:but/dep=110/gov=24',
#    'case/dep=111/gov=112',
#    'nmod:by/dep=112/gov=110',
#    'nmod:tmod/dep=113/gov=110',
#    'nummod/dep=114/gov=113',
#    'punct/dep=115/gov=24'],
#   'words': ['GIEWS',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'Brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-September-2017',
#    'FOOD',
#    'SECURITY',
#    'SNAPSHOT',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimated',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crops',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    'and',
#    'Fall',
#    'Armyworm',
#    'infestations',
#    'Food',
#    'prices',
#    'at',
#    'exceptionally',
#    'high',
#    'levels',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'According',
#    'to',
#    'the',
#    'latest',
#    'IPC',
#    'analysis',
#    ',',
#    'famine',
#    'conditions',
#    ',',
#    'previously',
#    'reported',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'counties',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'were',
#    'no',
#    'longer',
#    'occurring',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'pos-tags': ['NN',
#    'JJ',
#    'NN',
#    'CC',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'NNP',
#    'NNP',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    ':',
#    'JJ',
#    'NN',
#    'NN',
#    'NNP',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'IN',
#    'DT',
#    'NN',
#    'NNP',
#    'JJ',
#    'NN',
#    'VBN',
#    'IN',
#    'NN',
#    'JJ',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'CD',
#    'NNP',
#    'NNS',
#    'IN',
#    'CD',
#    'NNS',
#    'JJ',
#    'TO',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'NN',
#    'NN',
#    'NNS',
#    'NN',
#    'NNS',
#    'IN',
#    'RB',
#    'JJ',
#    'NNS',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'VBG',
#    'TO',
#    'DT',
#    'JJS',
#    'NN',
#    'NN',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'CD',
#    'IN',
#    'JJ',
#    'NNP',
#    'CC',
#    'NNP',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNP',
#    'NNP',
#    ',',
#    'VBD',
#    'RB',
#    'RB',
#    'VBG',
#    'IN',
#    'JJ',
#    'NNP',
#    'CD',
#    '.'],
#   'lemma': ['giews',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-september-2017',
#    'food',
#    'security',
#    'SNAPSHOT',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimate',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crop',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    'and',
#    'fall',
#    'armyworm',
#    'infestation',
#    'food',
#    'price',
#    'at',
#    'exceptionally',
#    'high',
#    'level',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'accord',
#    'to',
#    'the',
#    'latest',
#    'ipc',
#    'analysis',
#    ',',
#    'famine',
#    'condition',
#    ',',
#    'previously',
#    'report',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'county',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'be',
#    'no',
#    'longer',
#    'occur',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (S\n      (NP\n        (NP (NN GIEWS) (JJ global) (NN information))\n        (CC and)\n        (NP\n          (NP\n            (NP\n              (NP (JJ early) (NN warning) (NN system))\n              (PP (IN on)\n                (NP (NN food)\n                  (CC and)\n                  (NN agriculture))))\n            (NP (NNP GIEWS) (NNP Country) (NN Brief) (NNP South) (NNP Sudan) (NNP Reference) (NNP Date)))\n          (: :)\n          (NP\n            (NP (JJ 14-September-2017) (NN FOOD) (NN SECURITY))\n            (NP (NNP SNAPSHOT) (NN Famine)))))\n      (VP (VBD phased)\n        (PRT (RP out))))\n    (, ,)\n    (CC but)\n    (S\n      (NP\n        (NP (NN food) (NN security) (NN situation))\n        (PP\n          (NP\n            (ADJP (RB still) (JJ dire)\n              (PP (IN across)\n                (NP (DT the) (NN country))))\n            (NNP Food))\n          (NP\n            (NP (JJ insecure) (NN caseload))\n            (VP (VBN estimated)\n              (PP (IN at)\n                (NP\n                  (NP (NN record))\n                  (SBAR\n                    (WHNP\n                      (NP\n                        (ADJP (JJ high)\n                          (NP\n                            (NP\n                              (QP (CD 6) (CD million)))\n                            (PP (IN in)\n                              (NP (NNP June) (CD 2017)))))\n                        (NNP Unfavourable) (NNS prospects))\n                      (PP (IN for)\n                        (NP\n                          (NP\n                            (ADJP\n                              (NP (CD 2017) (NNS crops))\n                              (JJ due)\n                              (PP (TO to)\n                                (NP\n                                  (NP (JJ widespread) (NN insecurity))\n                                  (, ,)\n                                  (NP (JJ large) (NN scale) (NNS displacements))\n                                  (CC and)\n                                  (NP (NN Fall) (NN Armyworm) (NNS infestations)))))\n                            (NN Food) (NNS prices))\n                          (PP (IN at)\n                            (NP\n                              (ADJP (RB exceptionally) (JJ high))\n                              (NNS levels) (NN Famine))))))\n                    (S\n                      (VP\n                        (VP (VBD phased)\n                          (PRT (RP out)))\n                        (, ,)\n                        (CC but)\n                        (VP\n                          (NP\n                            (NP (NN food) (NN security) (NN situation))\n                            (ADJP (RB still) (JJ dire)))\n                          (PP (VBG According)\n                            (PP (TO to)\n                              (NP\n                                (NP (DT the) (JJS latest) (NN IPC) (NN analysis))\n                                (, ,)\n                                (NP (NN famine) (NNS conditions))))))))))))))\n        (, ,)\n        (VP\n          (ADVP (RB previously))\n          (VBN reported)\n          (PP (IN in)\n            (NP\n              (NP (NNP February) (CD 2017))\n              (PP (IN in)\n                (NP (JJ former) (NNP Leer)\n                  (CC and)\n                  (NNP Mayendit) (NNS counties)))))\n          (PP (IN in)\n            (NP (JJ former) (NNP Unity) (NNP State))))\n        (, ,))\n      (VP (VBD were)\n        (ADVP (RB no) (RB longer))\n        (VP (VBG occurring)\n          (PP (IN by)\n            (NP (JJ late)))\n          (NP-TMP (NNP June) (CD 2017)))))\n    (. .)))'},
#  {'sentence': 'GIEWS global information and early warning system on food and agriculture\n\nGIEWS Country Brief South Sudan\n\nReference Date: 14-September-2017\n\nFOOD SECURITY SNAPSHOT\n\n Famine phased out, but food security situation still dire across the country\n\nFood insecure caseload estimated at record high 6 million in June 2017\n\n Unfavourable prospects for 2017 crops due to widespread insecurity, large scale displacements and Fall Armyworm infestations\n\n Food prices at exceptionally high levels\n\nFamine phased out, but food security situation still dire According to the latest IPC analysis, famine conditions, previously reported in February 2017 in former Leer and Mayendit counties in former Unity State, were no longer occurring by late June 2017.Overall, the number of people facing IPC Phase 5: ?',
#   'position': [0, 794],
#   'golden-entity-mentions': [{'text': 'GIEWS',
#     'position': [0, 5],
#     'entity-type': 'ORG',
#     'start': 0,
#     'end': 1},
#    {'text': '6 million',
#     'position': [294, 303],
#     'entity-type': 'CARDINAL',
#     'start': 43,
#     'end': 45},
#    {'text': 'June 2017',
#     'position': [307, 316],
#     'entity-type': 'DATE',
#     'start': 46,
#     'end': 48},
#    {'text': 'Unfavourable',
#     'position': [319, 331],
#     'entity-type': 'ORG',
#     'start': 48,
#     'end': 49},
#    {'text': '2017',
#     'position': [346, 350],
#     'entity-type': 'CARDINAL',
#     'start': 51,
#     'end': 52},
#    {'text': 'Fall Armyworm',
#     'position': [417, 430],
#     'entity-type': 'PERSON',
#     'start': 62,
#     'end': 64},
#    {'text': 'IPC',
#     'position': [570, 573],
#     'entity-type': 'ORG',
#     'start': 85,
#     'end': 86},
#    {'text': 'February 2017',
#     'position': [626, 639],
#     'entity-type': 'DATE',
#     'start': 94,
#     'end': 96},
#    {'text': 'Leer',
#     'position': [650, 654],
#     'entity-type': 'ORG',
#     'start': 98,
#     'end': 99},
#    {'text': 'Mayendit',
#     'position': [659, 667],
#     'entity-type': 'ORG',
#     'start': 100,
#     'end': 101},
#    {'text': 'Unity State',
#     'position': [687, 698],
#     'entity-type': 'ORG',
#     'start': 104,
#     'end': 106},
#    {'text': 'late June 2017.Overall',
#     'position': [728, 750],
#     'entity-type': 'DATE',
#     'start': 112,
#     'end': -1},
#    {'text': 'IPC',
#     'position': [780, 783],
#     'entity-type': 'ORG',
#     'start': 115,
#     'end': -1},
#    {'text': '5',
#     'position': [790, 791],
#     'entity-type': 'CARDINAL',
#     'start': 115,
#     'end': -1}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=24/gov=-1',
#    'compound/dep=0/gov=2',
#    'amod/dep=1/gov=2',
#    'nsubj/dep=2/gov=24',
#    'cc/dep=3/gov=2',
#    'amod/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'conj:and/dep=6/gov=2',
#    'nsubj/dep=6/gov=24',
#    'case/dep=7/gov=8',
#    'nmod:on/dep=8/gov=6',
#    'cc/dep=9/gov=8',
#    'nmod:on/dep=10/gov=6',
#    'conj:and/dep=10/gov=8',
#    'compound/dep=11/gov=17',
#    'compound/dep=12/gov=17',
#    'compound/dep=13/gov=17',
#    'compound/dep=14/gov=17',
#    'compound/dep=15/gov=17',
#    'compound/dep=16/gov=17',
#    'dep/dep=17/gov=6',
#    'punct/dep=18/gov=6',
#    'amod/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'dep/dep=21/gov=6',
#    'compound/dep=22/gov=23',
#    'dep/dep=23/gov=21',
#    'compound:prt/dep=25/gov=24',
#    'punct/dep=26/gov=24',
#    'cc/dep=27/gov=24',
#    'compound/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nsubj/dep=30/gov=110',
#    'advmod/dep=31/gov=32',
#    'amod/dep=32/gov=36',
#    'case/dep=33/gov=35',
#    'det/dep=34/gov=35',
#    'nmod:across/dep=35/gov=32',
#    'nmod/dep=36/gov=30',
#    'amod/dep=37/gov=38',
#    'dep/dep=38/gov=36',
#    'acl/dep=39/gov=38',
#    'case/dep=40/gov=41',
#    'nmod:at/dep=41/gov=39',
#    'amod/dep=42/gov=49',
#    'compound/dep=43/gov=44',
#    'dep/dep=44/gov=42',
#    'case/dep=45/gov=46',
#    'nmod:in/dep=46/gov=44',
#    'nummod/dep=47/gov=46',
#    'compound/dep=48/gov=49',
#    'nsubj/dep=49/gov=72',
#    'case/dep=50/gov=66',
#    'nummod/dep=51/gov=52',
#    'nmod:npmod/dep=52/gov=53',
#    'amod/dep=53/gov=66',
#    'case/dep=54/gov=56',
#    'amod/dep=55/gov=56',
#    'nmod:to/dep=56/gov=53',
#    'punct/dep=57/gov=56',
#    'amod/dep=58/gov=60',
#    'compound/dep=59/gov=60',
#    'nmod:to/dep=60/gov=53',
#    'conj:and/dep=60/gov=56',
#    'cc/dep=61/gov=56',
#    'compound/dep=62/gov=64',
#    'compound/dep=63/gov=64',
#    'nmod:to/dep=64/gov=53',
#    'conj:and/dep=64/gov=56',
#    'compound/dep=65/gov=66',
#    'nmod:for/dep=66/gov=49',
#    'case/dep=67/gov=71',
#    'advmod/dep=68/gov=69',
#    'amod/dep=69/gov=71',
#    'compound/dep=70/gov=71',
#    'nmod:at/dep=71/gov=66',
#    'acl:relcl/dep=72/gov=41',
#    'compound:prt/dep=73/gov=72',
#    'punct/dep=74/gov=72',
#    'cc/dep=75/gov=72',
#    'compound/dep=76/gov=78',
#    'compound/dep=77/gov=78',
#    'acl:relcl/dep=78/gov=41',
#    'conj:but/dep=78/gov=72',
#    'advmod/dep=79/gov=80',
#    'amod/dep=80/gov=78',
#    'case/dep=81/gov=86',
#    'mwe/dep=82/gov=81',
#    'det/dep=83/gov=86',
#    'amod/dep=84/gov=86',
#    'compound/dep=85/gov=86',
#    'nmod:according_to/dep=86/gov=78',
#    'punct/dep=87/gov=86',
#    'compound/dep=88/gov=89',
#    'appos/dep=89/gov=86',
#    'punct/dep=90/gov=30',
#    'advmod/dep=91/gov=92',
#    'acl/dep=92/gov=30',
#    'case/dep=93/gov=94',
#    'nmod:in/dep=94/gov=92',
#    'nummod/dep=95/gov=94',
#    'case/dep=96/gov=98',
#    'amod/dep=97/gov=98',
#    'nmod:in/dep=98/gov=94',
#    'cc/dep=99/gov=98',
#    'compound/dep=100/gov=101',
#    'nmod:in/dep=101/gov=94',
#    'conj:and/dep=101/gov=98',
#    'case/dep=102/gov=105',
#    'amod/dep=103/gov=105',
#    'compound/dep=104/gov=105',
#    'nmod:in/dep=105/gov=92',
#    'punct/dep=106/gov=30',
#    'aux/dep=107/gov=110',
#    'neg/dep=108/gov=109',
#    'advmod/dep=109/gov=110',
#    'conj:but/dep=110/gov=24',
#    'case/dep=111/gov=112',
#    'nmod:by/dep=112/gov=110',
#    'nmod:tmod/dep=113/gov=110',
#    'nummod/dep=114/gov=113',
#    'punct/dep=115/gov=24'],
#   'words': ['GIEWS',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'Brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-September-2017',
#    'FOOD',
#    'SECURITY',
#    'SNAPSHOT',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimated',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crops',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    'and',
#    'Fall',
#    'Armyworm',
#    'infestations',
#    'Food',
#    'prices',
#    'at',
#    'exceptionally',
#    'high',
#    'levels',
#    'Famine',
#    'phased',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'According',
#    'to',
#    'the',
#    'latest',
#    'IPC',
#    'analysis',
#    ',',
#    'famine',
#    'conditions',
#    ',',
#    'previously',
#    'reported',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'counties',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'were',
#    'no',
#    'longer',
#    'occurring',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'pos-tags': ['NN',
#    'JJ',
#    'NN',
#    'CC',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'NNP',
#    'NNP',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    ':',
#    'JJ',
#    'NN',
#    'NN',
#    'NNP',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'IN',
#    'DT',
#    'NN',
#    'NNP',
#    'JJ',
#    'NN',
#    'VBN',
#    'IN',
#    'NN',
#    'JJ',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'CD',
#    'NNP',
#    'NNS',
#    'IN',
#    'CD',
#    'NNS',
#    'JJ',
#    'TO',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'NN',
#    'NN',
#    'NNS',
#    'NN',
#    'NNS',
#    'IN',
#    'RB',
#    'JJ',
#    'NNS',
#    'NN',
#    'VBD',
#    'RP',
#    ',',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'RB',
#    'JJ',
#    'VBG',
#    'TO',
#    'DT',
#    'JJS',
#    'NN',
#    'NN',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'CD',
#    'IN',
#    'JJ',
#    'NNP',
#    'CC',
#    'NNP',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNP',
#    'NNP',
#    ',',
#    'VBD',
#    'RB',
#    'RB',
#    'VBG',
#    'IN',
#    'JJ',
#    'NNP',
#    'CD',
#    '.'],
#   'lemma': ['giews',
#    'global',
#    'information',
#    'and',
#    'early',
#    'warning',
#    'system',
#    'on',
#    'food',
#    'and',
#    'agriculture',
#    'GIEWS',
#    'Country',
#    'brief',
#    'South',
#    'Sudan',
#    'Reference',
#    'Date',
#    ':',
#    '14-september-2017',
#    'food',
#    'security',
#    'SNAPSHOT',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'across',
#    'the',
#    'country',
#    'Food',
#    'insecure',
#    'caseload',
#    'estimate',
#    'at',
#    'record',
#    'high',
#    '6',
#    'million',
#    'in',
#    'June',
#    '2017',
#    'Unfavourable',
#    'prospects',
#    'for',
#    '2017',
#    'crop',
#    'due',
#    'to',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    'and',
#    'fall',
#    'armyworm',
#    'infestation',
#    'food',
#    'price',
#    'at',
#    'exceptionally',
#    'high',
#    'level',
#    'famine',
#    'phase',
#    'out',
#    ',',
#    'but',
#    'food',
#    'security',
#    'situation',
#    'still',
#    'dire',
#    'accord',
#    'to',
#    'the',
#    'latest',
#    'ipc',
#    'analysis',
#    ',',
#    'famine',
#    'condition',
#    ',',
#    'previously',
#    'report',
#    'in',
#    'February',
#    '2017',
#    'in',
#    'former',
#    'Leer',
#    'and',
#    'Mayendit',
#    'county',
#    'in',
#    'former',
#    'Unity',
#    'State',
#    ',',
#    'be',
#    'no',
#    'longer',
#    'occur',
#    'by',
#    'late',
#    'June',
#    '2017',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (S\n      (NP\n        (NP (NN GIEWS) (JJ global) (NN information))\n        (CC and)\n        (NP\n          (NP\n            (NP\n              (NP (JJ early) (NN warning) (NN system))\n              (PP (IN on)\n                (NP (NN food)\n                  (CC and)\n                  (NN agriculture))))\n            (NP (NNP GIEWS) (NNP Country) (NN Brief) (NNP South) (NNP Sudan) (NNP Reference) (NNP Date)))\n          (: :)\n          (NP\n            (NP (JJ 14-September-2017) (NN FOOD) (NN SECURITY))\n            (NP (NNP SNAPSHOT) (NN Famine)))))\n      (VP (VBD phased)\n        (PRT (RP out))))\n    (, ,)\n    (CC but)\n    (S\n      (NP\n        (NP (NN food) (NN security) (NN situation))\n        (PP\n          (NP\n            (ADJP (RB still) (JJ dire)\n              (PP (IN across)\n                (NP (DT the) (NN country))))\n            (NNP Food))\n          (NP\n            (NP (JJ insecure) (NN caseload))\n            (VP (VBN estimated)\n              (PP (IN at)\n                (NP\n                  (NP (NN record))\n                  (SBAR\n                    (WHNP\n                      (NP\n                        (ADJP (JJ high)\n                          (NP\n                            (NP\n                              (QP (CD 6) (CD million)))\n                            (PP (IN in)\n                              (NP (NNP June) (CD 2017)))))\n                        (NNP Unfavourable) (NNS prospects))\n                      (PP (IN for)\n                        (NP\n                          (NP\n                            (ADJP\n                              (NP (CD 2017) (NNS crops))\n                              (JJ due)\n                              (PP (TO to)\n                                (NP\n                                  (NP (JJ widespread) (NN insecurity))\n                                  (, ,)\n                                  (NP (JJ large) (NN scale) (NNS displacements))\n                                  (CC and)\n                                  (NP (NN Fall) (NN Armyworm) (NNS infestations)))))\n                            (NN Food) (NNS prices))\n                          (PP (IN at)\n                            (NP\n                              (ADJP (RB exceptionally) (JJ high))\n                              (NNS levels) (NN Famine))))))\n                    (S\n                      (VP\n                        (VP (VBD phased)\n                          (PRT (RP out)))\n                        (, ,)\n                        (CC but)\n                        (VP\n                          (NP\n                            (NP (NN food) (NN security) (NN situation))\n                            (ADJP (RB still) (JJ dire)))\n                          (PP (VBG According)\n                            (PP (TO to)\n                              (NP\n                                (NP (DT the) (JJS latest) (NN IPC) (NN analysis))\n                                (, ,)\n                                (NP (NN famine) (NNS conditions))))))))))))))\n        (, ,)\n        (VP\n          (ADVP (RB previously))\n          (VBN reported)\n          (PP (IN in)\n            (NP\n              (NP (NNP February) (CD 2017))\n              (PP (IN in)\n                (NP (JJ former) (NNP Leer)\n                  (CC and)\n                  (NNP Mayendit) (NNS counties)))))\n          (PP (IN in)\n            (NP (JJ former) (NNP Unity) (NNP State))))\n        (, ,))\n      (VP (VBD were)\n        (ADVP (RB no) (RB longer))\n        (VP (VBG occurring)\n          (PP (IN by)\n            (NP (JJ late)))\n          (NP-TMP (NNP June) (CD 2017)))))\n    (. .)))'},
#  {'sentence': 'Catastrophe?',
#   'position': [794, 806],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Catastrophe', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['catastrophe', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Catastrophe))\n    (. ?)))'},
#  {'sentence': 'Catastrophe?',
#   'position': [794, 806],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Catastrophe', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['catastrophe', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Catastrophe))\n    (. ?)))'},
#  {'sentence': 'food security conditions declined from over 100 000 in February to about 45 000 in June due to sustained multi-sectoral humanitarian assistance operations and the two counties are currently classified as IPC Phase 4: ?',
#   'position': [807, 1025],
#   'golden-entity-mentions': [{'text': 'February',
#     'position': [862, 870],
#     'entity-type': 'DATE',
#     'start': 9,
#     'end': 10},
#    {'text': 'about 45 000',
#     'position': [874, 886],
#     'entity-type': 'CARDINAL',
#     'start': 11,
#     'end': 14},
#    {'text': 'June',
#     'position': [890, 894],
#     'entity-type': 'DATE',
#     'start': 15,
#     'end': 16},
#    {'text': 'two',
#     'position': [970, 973],
#     'entity-type': 'CARDINAL',
#     'start': 25,
#     'end': 26}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'compound/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nsubj/dep=2/gov=3',
#    'advmod/dep=4/gov=29',
#    'case/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'nmod:over/dep=7/gov=4',
#    'case/dep=8/gov=9',
#    'nmod:in/dep=9/gov=7',
#    'mark/dep=10/gov=13',
#    'dep/dep=11/gov=13',
#    'compound/dep=12/gov=13',
#    'acl:to/dep=13/gov=9',
#    'case/dep=14/gov=15',
#    'nmod:in/dep=15/gov=13',
#    'amod/dep=16/gov=15',
#    'case/dep=17/gov=22',
#    'amod/dep=18/gov=22',
#    'amod/dep=19/gov=22',
#    'amod/dep=20/gov=22',
#    'compound/dep=21/gov=22',
#    'nmod:to/dep=22/gov=16',
#    'cc/dep=23/gov=22',
#    'det/dep=24/gov=26',
#    'nummod/dep=25/gov=26',
#    'nmod:to/dep=26/gov=16',
#    'conj:and/dep=26/gov=22',
#    'auxpass/dep=27/gov=29',
#    'advmod/dep=28/gov=29',
#    'dep/dep=29/gov=3',
#    'case/dep=30/gov=32',
#    'compound/dep=31/gov=32',
#    'nmod:as/dep=32/gov=29',
#    'nsubjpass/dep=33/gov=29',
#    'punct/dep=34/gov=29',
#    'punct/dep=35/gov=3'],
#   'words': ['food',
#    'security',
#    'conditions',
#    'declined',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operations',
#    'and',
#    'the',
#    'two',
#    'counties',
#    'are',
#    'currently',
#    'classified',
#    'as',
#    'IPC',
#    'Phase',
#    '4',
#    ':',
#    '?'],
#   'pos-tags': ['NN',
#    'NN',
#    'NNS',
#    'VBD',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'JJ',
#    'TO',
#    'JJ',
#    'JJ',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'DT',
#    'CD',
#    'NNS',
#    'VBP',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'NN',
#    'CD',
#    ':',
#    '.'],
#   'lemma': ['food',
#    'security',
#    'condition',
#    'decline',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operation',
#    'and',
#    'the',
#    'two',
#    'county',
#    'be',
#    'currently',
#    'classify',
#    'as',
#    'IPC',
#    'phase',
#    '4',
#    ':',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (NP (NN food) (NN security) (NNS conditions))\n    (VP (VBD declined)\n      (SBAR\n        (SINV\n          (ADVP (IN from)\n            (PP (IN over)\n              (NP\n                (QP (CD 100) (CD 000)))\n              (PP (IN in)\n                (NP\n                  (NP (NNP February))\n                  (SBAR\n                    (S\n                      (VP (TO to)\n                        (VP (IN about)\n                          (NP\n                            (QP (CD 45) (CD 000)))\n                          (PP (IN in)\n                            (NP\n                              (NP (NNP June))\n                              (ADJP (JJ due)\n                                (PP (TO to)\n                                  (NP\n                                    (NP (JJ sustained) (JJ multi-sectoral) (JJ humanitarian) (NN assistance) (NNS operations))\n                                    (CC and)\n                                    (NP (DT the) (CD two) (NNS counties)))))))))))))))\n          (VP (VBP are)\n            (ADVP (RB currently))\n            (VP (VBN classified)\n              (PP (IN as)\n                (NP (NNP IPC) (NN Phase)))))\n          (NP (CD 4))\n          (: :))))\n    (. ?)))'},
#  {'sentence': 'food security conditions declined from over 100 000 in February to about 45 000 in June due to sustained multi-sectoral humanitarian assistance operations and the two counties are currently classified as IPC Phase 4: ?',
#   'position': [807, 1025],
#   'golden-entity-mentions': [{'text': 'February',
#     'position': [862, 870],
#     'entity-type': 'DATE',
#     'start': 9,
#     'end': 10},
#    {'text': 'about 45 000',
#     'position': [874, 886],
#     'entity-type': 'CARDINAL',
#     'start': 11,
#     'end': 14},
#    {'text': 'June',
#     'position': [890, 894],
#     'entity-type': 'DATE',
#     'start': 15,
#     'end': 16},
#    {'text': 'two',
#     'position': [970, 973],
#     'entity-type': 'CARDINAL',
#     'start': 25,
#     'end': 26}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'compound/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nsubj/dep=2/gov=3',
#    'advmod/dep=4/gov=29',
#    'case/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'nmod:over/dep=7/gov=4',
#    'case/dep=8/gov=9',
#    'nmod:in/dep=9/gov=7',
#    'mark/dep=10/gov=13',
#    'dep/dep=11/gov=13',
#    'compound/dep=12/gov=13',
#    'acl:to/dep=13/gov=9',
#    'case/dep=14/gov=15',
#    'nmod:in/dep=15/gov=13',
#    'amod/dep=16/gov=15',
#    'case/dep=17/gov=22',
#    'amod/dep=18/gov=22',
#    'amod/dep=19/gov=22',
#    'amod/dep=20/gov=22',
#    'compound/dep=21/gov=22',
#    'nmod:to/dep=22/gov=16',
#    'cc/dep=23/gov=22',
#    'det/dep=24/gov=26',
#    'nummod/dep=25/gov=26',
#    'nmod:to/dep=26/gov=16',
#    'conj:and/dep=26/gov=22',
#    'auxpass/dep=27/gov=29',
#    'advmod/dep=28/gov=29',
#    'dep/dep=29/gov=3',
#    'case/dep=30/gov=32',
#    'compound/dep=31/gov=32',
#    'nmod:as/dep=32/gov=29',
#    'nsubjpass/dep=33/gov=29',
#    'punct/dep=34/gov=29',
#    'punct/dep=35/gov=3'],
#   'words': ['food',
#    'security',
#    'conditions',
#    'declined',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operations',
#    'and',
#    'the',
#    'two',
#    'counties',
#    'are',
#    'currently',
#    'classified',
#    'as',
#    'IPC',
#    'Phase',
#    '4',
#    ':',
#    '?'],
#   'pos-tags': ['NN',
#    'NN',
#    'NNS',
#    'VBD',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'JJ',
#    'TO',
#    'JJ',
#    'JJ',
#    'JJ',
#    'NN',
#    'NNS',
#    'CC',
#    'DT',
#    'CD',
#    'NNS',
#    'VBP',
#    'RB',
#    'VBN',
#    'IN',
#    'NNP',
#    'NN',
#    'CD',
#    ':',
#    '.'],
#   'lemma': ['food',
#    'security',
#    'condition',
#    'decline',
#    'from',
#    'over',
#    '100',
#    '000',
#    'in',
#    'February',
#    'to',
#    'about',
#    '45',
#    '000',
#    'in',
#    'June',
#    'due',
#    'to',
#    'sustained',
#    'multi-sectoral',
#    'humanitarian',
#    'assistance',
#    'operation',
#    'and',
#    'the',
#    'two',
#    'county',
#    'be',
#    'currently',
#    'classify',
#    'as',
#    'IPC',
#    'phase',
#    '4',
#    ':',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (NP (NN food) (NN security) (NNS conditions))\n    (VP (VBD declined)\n      (SBAR\n        (SINV\n          (ADVP (IN from)\n            (PP (IN over)\n              (NP\n                (QP (CD 100) (CD 000)))\n              (PP (IN in)\n                (NP\n                  (NP (NNP February))\n                  (SBAR\n                    (S\n                      (VP (TO to)\n                        (VP (IN about)\n                          (NP\n                            (QP (CD 45) (CD 000)))\n                          (PP (IN in)\n                            (NP\n                              (NP (NNP June))\n                              (ADJP (JJ due)\n                                (PP (TO to)\n                                  (NP\n                                    (NP (JJ sustained) (JJ multi-sectoral) (JJ humanitarian) (NN assistance) (NNS operations))\n                                    (CC and)\n                                    (NP (DT the) (CD two) (NNS counties)))))))))))))))\n          (VP (VBP are)\n            (ADVP (RB currently))\n            (VP (VBN classified)\n              (PP (IN as)\n                (NP (NNP IPC) (NN Phase)))))\n          (NP (CD 4))\n          (: :))))\n    (. ?)))'},
#  {'sentence': 'Emergency?.',
#   'position': [1025, 1036],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Emergency', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['emergency', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Emergency))\n    (. ?)))'},
#  {'sentence': 'Emergency?.',
#   'position': [1025, 1036],
#   'golden-entity-mentions': [],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=0/gov=-1', 'punct/dep=1/gov=0'],
#   'words': ['Emergency', '?'],
#   'pos-tags': ['NN', '.'],
#   'lemma': ['emergency', '?'],
#   'parse': '(ROOT\n  (FRAG\n    (NP (NN Emergency))\n    (. ?)))'},
#  {'sentence': 'However, nationwide, the food insecure caseload (IPC Phases 3, 4 and 5) increased from about 5 million in February to a record high of 6 million in June as food access continues to be severely constrained by widespread insecurity, large scale displacements, high food prices, market disruptions, macro-economic collapse and exhaustion of households?',
#   'position': [1037, 1386],
#   'golden-entity-mentions': [{'text': '4',
#     'position': [1100, 1101],
#     'entity-type': 'CARDINAL',
#     'start': 13,
#     'end': 14},
#    {'text': '5',
#     'position': [1106, 1107],
#     'entity-type': 'CARDINAL',
#     'start': 15,
#     'end': 16},
#    {'text': 'about 5 million',
#     'position': [1124, 1139],
#     'entity-type': 'CARDINAL',
#     'start': 19,
#     'end': 22},
#    {'text': 'February',
#     'position': [1143, 1151],
#     'entity-type': 'DATE',
#     'start': 23,
#     'end': 24},
#    {'text': '6 million',
#     'position': [1172, 1181],
#     'entity-type': 'CARDINAL',
#     'start': 29,
#     'end': 31},
#    {'text': 'June',
#     'position': [1185, 1189],
#     'entity-type': 'DATE',
#     'start': 32,
#     'end': 33}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=36/gov=-1',
#    'advmod/dep=0/gov=36',
#    'punct/dep=1/gov=36',
#    'advmod/dep=2/gov=36',
#    'punct/dep=3/gov=36',
#    'det/dep=4/gov=7',
#    'compound/dep=5/gov=7',
#    'amod/dep=6/gov=7',
#    'nsubj/dep=7/gov=36',
#    'nsubjpass:xsubj/dep=7/gov=40',
#    'punct/dep=8/gov=10',
#    'compound/dep=9/gov=10',
#    'dep/dep=10/gov=7',
#    'dep/dep=11/gov=10',
#    'punct/dep=12/gov=10',
#    'appos/dep=13/gov=10',
#    'cc/dep=14/gov=13',
#    'appos/dep=15/gov=10',
#    'conj:and/dep=15/gov=13',
#    'punct/dep=16/gov=10',
#    'acl/dep=17/gov=7',
#    'case/dep=18/gov=21',
#    'case/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'nmod:about/dep=21/gov=17',
#    'case/dep=22/gov=23',
#    'nmod:in/dep=23/gov=21',
#    'case/dep=24/gov=27',
#    'det/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'nmod:to/dep=27/gov=17',
#    'case/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nmod:of/dep=30/gov=27',
#    'case/dep=31/gov=32',
#    'nmod:in/dep=32/gov=30',
#    'case/dep=33/gov=35',
#    'compound/dep=34/gov=35',
#    'nmod:as/dep=35/gov=17',
#    'mark/dep=37/gov=40',
#    'auxpass/dep=38/gov=40',
#    'advmod/dep=39/gov=40',
#    'xcomp/dep=40/gov=36',
#    'case/dep=41/gov=43',
#    'amod/dep=42/gov=43',
#    'nmod:agent/dep=43/gov=40',
#    'punct/dep=44/gov=43',
#    'amod/dep=45/gov=47',
#    'compound/dep=46/gov=47',
#    'nmod:agent/dep=47/gov=40',
#    'conj:and/dep=47/gov=43',
#    'punct/dep=48/gov=43',
#    'amod/dep=49/gov=51',
#    'compound/dep=50/gov=51',
#    'nmod:agent/dep=51/gov=40',
#    'conj:and/dep=51/gov=43',
#    'punct/dep=52/gov=43',
#    'compound/dep=53/gov=54',
#    'nmod:agent/dep=54/gov=40',
#    'conj:and/dep=54/gov=43',
#    'punct/dep=55/gov=43',
#    'amod/dep=56/gov=57',
#    'nmod:agent/dep=57/gov=40',
#    'conj:and/dep=57/gov=43',
#    'cc/dep=58/gov=43',
#    'nmod:agent/dep=59/gov=40',
#    'conj:and/dep=59/gov=43',
#    'case/dep=60/gov=61',
#    'nmod:of/dep=61/gov=59',
#    'punct/dep=62/gov=36'],
#   'words': ['However',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-LRB-',
#    'IPC',
#    'Phases',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-RRB-',
#    'increased',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continues',
#    'to',
#    'be',
#    'severely',
#    'constrained',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    ',',
#    'high',
#    'food',
#    'prices',
#    ',',
#    'market',
#    'disruptions',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'households',
#    '?'],
#   'pos-tags': ['RB',
#    ',',
#    'JJ',
#    ',',
#    'DT',
#    'NN',
#    'JJ',
#    'NN',
#    '-LRB-',
#    'NN',
#    'NNS',
#    'CD',
#    ',',
#    'CD',
#    'CC',
#    'CD',
#    '-RRB-',
#    'VBN',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'IN',
#    'NN',
#    'NN',
#    'VBZ',
#    'TO',
#    'VB',
#    'RB',
#    'VBN',
#    'IN',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'CC',
#    'NN',
#    'IN',
#    'NNS',
#    '.'],
#   'lemma': ['however',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-lrb-',
#    'ipc',
#    'phase',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-rrb-',
#    'increase',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continue',
#    'to',
#    'be',
#    'severely',
#    'constrain',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacement',
#    ',',
#    'high',
#    'food',
#    'price',
#    ',',
#    'market',
#    'disruption',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'household',
#    '?'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB However))\n    (, ,)\n    (ADVP (JJ nationwide))\n    (, ,)\n    (NP\n      (NP\n        (NP (DT the) (NN food) (JJ insecure) (NN caseload))\n        (PRN (-LRB- -LRB-)\n          (NP\n            (NP (NN IPC) (NNS Phases))\n            (NP (CD 3))\n            (, ,)\n            (NP (CD 4)\n              (CC and)\n              (CD 5)))\n          (-RRB- -RRB-)))\n      (VP (VBN increased)\n        (PP (IN from) (IN about)\n          (NP\n            (NP\n              (QP (CD 5) (CD million)))\n            (PP (IN in)\n              (NP (NNP February)))))\n        (PP (TO to)\n          (NP\n            (NP (DT a) (NN record) (NN high))\n            (PP (IN of)\n              (NP\n                (NP\n                  (QP (CD 6) (CD million)))\n                (PP (IN in)\n                  (NP (NNP June)))))))\n        (PP (IN as)\n          (NP (NN food) (NN access)))))\n    (VP (VBZ continues)\n      (S\n        (VP (TO to)\n          (VP (VB be)\n            (VP\n              (ADVP (RB severely))\n              (VBN constrained)\n              (PP (IN by)\n                (NP\n                  (NP (JJ widespread) (NN insecurity))\n                  (, ,)\n                  (NP (JJ large) (NN scale) (NNS displacements))\n                  (, ,)\n                  (NP (JJ high) (NN food) (NNS prices))\n                  (, ,)\n                  (NP (NN market) (NNS disruptions))\n                  (, ,)\n                  (NP (JJ macro-economic) (NN collapse))\n                  (CC and)\n                  (NP\n                    (NP (NN exhaustion))\n                    (PP (IN of)\n                      (NP (NNS households)))))))))))\n    (. ?)))'},
#  {'sentence': 'However, nationwide, the food insecure caseload (IPC Phases 3, 4 and 5) increased from about 5 million in February to a record high of 6 million in June as food access continues to be severely constrained by widespread insecurity, large scale displacements, high food prices, market disruptions, macro-economic collapse and exhaustion of households?',
#   'position': [1037, 1386],
#   'golden-entity-mentions': [{'text': '4',
#     'position': [1100, 1101],
#     'entity-type': 'CARDINAL',
#     'start': 13,
#     'end': 14},
#    {'text': '5',
#     'position': [1106, 1107],
#     'entity-type': 'CARDINAL',
#     'start': 15,
#     'end': 16},
#    {'text': 'about 5 million',
#     'position': [1124, 1139],
#     'entity-type': 'CARDINAL',
#     'start': 19,
#     'end': 22},
#    {'text': 'February',
#     'position': [1143, 1151],
#     'entity-type': 'DATE',
#     'start': 23,
#     'end': 24},
#    {'text': '6 million',
#     'position': [1172, 1181],
#     'entity-type': 'CARDINAL',
#     'start': 29,
#     'end': 31},
#    {'text': 'June',
#     'position': [1185, 1189],
#     'entity-type': 'DATE',
#     'start': 32,
#     'end': 33}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=36/gov=-1',
#    'advmod/dep=0/gov=36',
#    'punct/dep=1/gov=36',
#    'advmod/dep=2/gov=36',
#    'punct/dep=3/gov=36',
#    'det/dep=4/gov=7',
#    'compound/dep=5/gov=7',
#    'amod/dep=6/gov=7',
#    'nsubj/dep=7/gov=36',
#    'nsubjpass:xsubj/dep=7/gov=40',
#    'punct/dep=8/gov=10',
#    'compound/dep=9/gov=10',
#    'dep/dep=10/gov=7',
#    'dep/dep=11/gov=10',
#    'punct/dep=12/gov=10',
#    'appos/dep=13/gov=10',
#    'cc/dep=14/gov=13',
#    'appos/dep=15/gov=10',
#    'conj:and/dep=15/gov=13',
#    'punct/dep=16/gov=10',
#    'acl/dep=17/gov=7',
#    'case/dep=18/gov=21',
#    'case/dep=19/gov=21',
#    'compound/dep=20/gov=21',
#    'nmod:about/dep=21/gov=17',
#    'case/dep=22/gov=23',
#    'nmod:in/dep=23/gov=21',
#    'case/dep=24/gov=27',
#    'det/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'nmod:to/dep=27/gov=17',
#    'case/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'nmod:of/dep=30/gov=27',
#    'case/dep=31/gov=32',
#    'nmod:in/dep=32/gov=30',
#    'case/dep=33/gov=35',
#    'compound/dep=34/gov=35',
#    'nmod:as/dep=35/gov=17',
#    'mark/dep=37/gov=40',
#    'auxpass/dep=38/gov=40',
#    'advmod/dep=39/gov=40',
#    'xcomp/dep=40/gov=36',
#    'case/dep=41/gov=43',
#    'amod/dep=42/gov=43',
#    'nmod:agent/dep=43/gov=40',
#    'punct/dep=44/gov=43',
#    'amod/dep=45/gov=47',
#    'compound/dep=46/gov=47',
#    'nmod:agent/dep=47/gov=40',
#    'conj:and/dep=47/gov=43',
#    'punct/dep=48/gov=43',
#    'amod/dep=49/gov=51',
#    'compound/dep=50/gov=51',
#    'nmod:agent/dep=51/gov=40',
#    'conj:and/dep=51/gov=43',
#    'punct/dep=52/gov=43',
#    'compound/dep=53/gov=54',
#    'nmod:agent/dep=54/gov=40',
#    'conj:and/dep=54/gov=43',
#    'punct/dep=55/gov=43',
#    'amod/dep=56/gov=57',
#    'nmod:agent/dep=57/gov=40',
#    'conj:and/dep=57/gov=43',
#    'cc/dep=58/gov=43',
#    'nmod:agent/dep=59/gov=40',
#    'conj:and/dep=59/gov=43',
#    'case/dep=60/gov=61',
#    'nmod:of/dep=61/gov=59',
#    'punct/dep=62/gov=36'],
#   'words': ['However',
#    ',',
#    'nationwide',
#    ',',
#    'the',
#    'food',
#    'insecure',
#    'caseload',
#    '-LRB-',
#    'IPC',
#    'Phases',
#    '3',
#    ',',
#    '4',
#    'and',
#    '5',
#    '-RRB-',
#    'increased',
#    'from',
#    'about',
#    '5',
#    'million',
#    'in',
#    'February',
#    'to',
#    'a',
#    'record',
#    'high',
#    'of',
#    '6',
#    'million',
#    'in',
#    'June',
#    'as',
#    'food',
#    'access',
#    'continues',
#    'to',
#    'be',
#    'severely',
#    'constrained',
#    'by',
#    'widespread',
#    'insecurity',
#    ',',
#    'large',
#    'scale',
#    'displacements',
#    ',',
#    'high',
#    'food',
#    'prices',
#    ',',
#    'market',
#    'disruptions',
#    ',',
#    'macro-economic',
#    'collapse',
#    'and',
#    'exhaustion',
#    'of',
#    'households',
#    '?'],
#   'pos-tags': ['RB',
#    ',',
#    'JJ',
#    ',',
#    'DT',
#    'NN',
#    'JJ',
#    'NN',
#    '-LRB-',
#    'NN',
#    'NNS',
#    'CD',
#    ',',
#    'CD',
#    'CC',
#    'CD',
#    '-RRB-',
#    'VBN',
#    'IN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'TO',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'CD',
#    'CD',
#    'IN',
#    'NNP',
#    'IN',
#    'NN',
#    'NN',
#    'VBZ',
#    'TO',
#    'VB',
#    'RB',
#    'VBN',
#    'IN',
#    'JJ',
#    'NN',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'JJ',
#    'NN',
#    'NNS',
#    ',',
#    'NN',
#    'NNS',
#    ',',
# ...
#    ',',
#    'IN',
#    'DT',
#    'NN',
#    'NN',
#    'VBG',
#    'JJ',
#    'NN',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNS',
#    '.'],
#   'lemma': ['subsequently',
#    ',',
#    'they',
#    'decline',
#    'by',
#    'about',
#    '12',
#    'percent',
#    'between',
#    'June',
#    'and',
#    'August',
#    ',',
#    'follow',
#    'the',
#    'first',
#    'season',
#    'harvest',
#    'in',
#    'southern',
#    'bimodal',
#    'rainfall',
#    'area',
#    'and',
#    'the',
#    'establishment',
#    ',',
#    'by',
#    'the',
#    'government',
#    ',',
#    'of',
#    'a',
#    'trading',
#    'company',
#    'sell',
#    'basic',
#    'food',
#    'commodity',
#    'at',
#    'subsidized',
#    'price',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB Subsequently))\n    (, ,)\n    (NP (PRP they))\n    (VP (VBD declined)\n      (PP (IN by)\n        (NP\n          (NP\n            (QP (RB about) (CD 12))\n            (NN percent))\n          (PP (IN between)\n            (NP (NNP June)\n              (CC and)\n              (NNP August)))\n          (, ,)\n          (PP (VBG following)\n            (NP\n              (NP (DT the) (JJ first) (NN season) (NN harvest))\n              (PP (IN in)\n                (NP\n                  (NP (JJ southern) (JJ bimodal) (NNS rainfall) (NNS areas))\n                  (CC and)\n                  (NP (DT the) (NN establishment))))))))\n      (, ,)\n      (PP (IN by)\n        (NP\n          (NP (DT the) (NN Government))\n          (, ,)\n          (PP (IN of)\n            (NP\n              (NP (DT a) (NN trading) (NN company))\n              (VP (VBG selling)\n                (NP (JJ basic) (NN food) (NNS commodities))\n                (PP (IN at)\n                  (NP (JJ subsidized) (NNS prices)))))))))\n    (. .)))'},
#  {'sentence': 'Prices of groundnuts decreased by 22 percent over the same period, while prices of wheat flour continued to soar in recent months, reaching new record highs in August.',
#   'position': [4297, 4464],
#   'golden-entity-mentions': [{'text': '22 percent',
#     'position': [4331, 4341],
#     'entity-type': 'PERCENT',
#     'start': 5,
#     'end': 7},
#    {'text': 'the same period',
#     'position': [4347, 4362],
#     'entity-type': 'DATE',
#     'start': 8,
#     'end': 11},
#    {'text': 'recent months',
#     'position': [4413, 4426],
#     'entity-type': 'DATE',
#     'start': 21,
#     'end': 23},
#    {'text': 'August',
#     'position': [4457, 4463],
#     'entity-type': 'DATE',
#     'start': 29,
#     'end': 30}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'nsubj/dep=0/gov=3',
#    'case/dep=1/gov=2',
#    'nmod:of/dep=2/gov=0',
#    'case/dep=4/gov=6',
#    'nummod/dep=5/gov=6',
#    'nmod:by/dep=6/gov=3',
#    'case/dep=7/gov=10',
#    'det/dep=8/gov=10',
#    'amod/dep=9/gov=10',
#    'nmod:over/dep=10/gov=3',
#    'punct/dep=11/gov=3',
#    'mark/dep=12/gov=17',
#    'nsubj/dep=13/gov=17',
#    'nsubj:xsubj/dep=13/gov=19',
#    'case/dep=14/gov=16',
#    'compound/dep=15/gov=16',
#    'nmod:of/dep=16/gov=13',
#    'advcl:while/dep=17/gov=3',
#    'mark/dep=18/gov=19',
#    'xcomp/dep=19/gov=17',
#    'case/dep=20/gov=22',
#    'amod/dep=21/gov=22',
#    'nmod:in/dep=22/gov=19',
#    'punct/dep=23/gov=17',
#    'xcomp/dep=24/gov=17',
#    'amod/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'dobj/dep=27/gov=24',
#    'case/dep=28/gov=29',
#    'nmod:in/dep=29/gov=24',
#    'punct/dep=30/gov=3'],
#   'words': ['Prices',
#    'of',
#    'groundnuts',
#    'decreased',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'prices',
#    'of',
#    'wheat',
#    'flour',
#    'continued',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'months',
#    ',',
#    'reaching',
#    'new',
#    'record',
#    'highs',
#    'in',
#    'August',
#    '.'],
#   'pos-tags': ['NNS',
#    'IN',
#    'NNS',
#    'VBN',
#    'IN',
#    'CD',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'IN',
#    'NNS',
#    'IN',
#    'NN',
#    'NN',
#    'VBD',
#    'TO',
#    'VB',
#    'IN',
#    'JJ',
#    'NNS',
#    ',',
#    'VBG',
#    'JJ',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    '.'],
#   'lemma': ['price',
#    'of',
#    'groundnut',
#    'decrease',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'price',
#    'of',
#    'wheat',
#    'flour',
#    'continue',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'month',
#    ',',
#    'reach',
#    'new',
#    'record',
#    'high',
#    'in',
#    'August',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (NNS Prices))\n      (PP (IN of)\n        (NP (NNS groundnuts))))\n    (VP (VBN decreased)\n      (PP (IN by)\n        (NP (CD 22) (NN percent)))\n      (PP (IN over)\n        (NP (DT the) (JJ same) (NN period)))\n      (, ,)\n      (SBAR (IN while)\n        (S\n          (NP\n            (NP (NNS prices))\n            (PP (IN of)\n              (NP (NN wheat) (NN flour))))\n          (VP (VBD continued)\n            (S\n              (VP (TO to)\n                (VP (VB soar)\n                  (PP (IN in)\n                    (NP (JJ recent) (NNS months))))))\n            (, ,)\n            (S\n              (VP (VBG reaching)\n                (NP (JJ new) (NN record) (NNS highs))\n                (PP (IN in)\n                  (NP (NNP August)))))))))\n    (. .)))'},
#  {'sentence': 'Prices of groundnuts decreased by 22 percent over the same period, while prices of wheat flour continued to soar in recent months, reaching new record highs in August.',
#   'position': [4297, 4464],
#   'golden-entity-mentions': [{'text': '22 percent',
#     'position': [4331, 4341],
#     'entity-type': 'PERCENT',
#     'start': 5,
#     'end': 7},
#    {'text': 'the same period',
#     'position': [4347, 4362],
#     'entity-type': 'DATE',
#     'start': 8,
#     'end': 11},
#    {'text': 'recent months',
#     'position': [4413, 4426],
#     'entity-type': 'DATE',
#     'start': 21,
#     'end': 23},
#    {'text': 'August',
#     'position': [4457, 4463],
#     'entity-type': 'DATE',
#     'start': 29,
#     'end': 30}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=3/gov=-1',
#    'nsubj/dep=0/gov=3',
#    'case/dep=1/gov=2',
#    'nmod:of/dep=2/gov=0',
#    'case/dep=4/gov=6',
#    'nummod/dep=5/gov=6',
#    'nmod:by/dep=6/gov=3',
#    'case/dep=7/gov=10',
#    'det/dep=8/gov=10',
#    'amod/dep=9/gov=10',
#    'nmod:over/dep=10/gov=3',
#    'punct/dep=11/gov=3',
#    'mark/dep=12/gov=17',
#    'nsubj/dep=13/gov=17',
#    'nsubj:xsubj/dep=13/gov=19',
#    'case/dep=14/gov=16',
#    'compound/dep=15/gov=16',
#    'nmod:of/dep=16/gov=13',
#    'advcl:while/dep=17/gov=3',
#    'mark/dep=18/gov=19',
#    'xcomp/dep=19/gov=17',
#    'case/dep=20/gov=22',
#    'amod/dep=21/gov=22',
#    'nmod:in/dep=22/gov=19',
#    'punct/dep=23/gov=17',
#    'xcomp/dep=24/gov=17',
#    'amod/dep=25/gov=27',
#    'compound/dep=26/gov=27',
#    'dobj/dep=27/gov=24',
#    'case/dep=28/gov=29',
#    'nmod:in/dep=29/gov=24',
#    'punct/dep=30/gov=3'],
#   'words': ['Prices',
#    'of',
#    'groundnuts',
#    'decreased',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'prices',
#    'of',
#    'wheat',
#    'flour',
#    'continued',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'months',
#    ',',
#    'reaching',
#    'new',
#    'record',
#    'highs',
#    'in',
#    'August',
#    '.'],
#   'pos-tags': ['NNS',
#    'IN',
#    'NNS',
#    'VBN',
#    'IN',
#    'CD',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'IN',
#    'NNS',
#    'IN',
#    'NN',
#    'NN',
#    'VBD',
#    'TO',
#    'VB',
#    'IN',
#    'JJ',
#    'NNS',
#    ',',
#    'VBG',
#    'JJ',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    '.'],
#   'lemma': ['price',
#    'of',
#    'groundnut',
#    'decrease',
#    'by',
#    '22',
#    'percent',
#    'over',
#    'the',
#    'same',
#    'period',
#    ',',
#    'while',
#    'price',
#    'of',
#    'wheat',
#    'flour',
#    'continue',
#    'to',
#    'soar',
#    'in',
#    'recent',
#    'month',
#    ',',
#    'reach',
#    'new',
#    'record',
#    'high',
#    'in',
#    'August',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (NP\n      (NP (NNS Prices))\n      (PP (IN of)\n        (NP (NNS groundnuts))))\n    (VP (VBN decreased)\n      (PP (IN by)\n        (NP (CD 22) (NN percent)))\n      (PP (IN over)\n        (NP (DT the) (JJ same) (NN period)))\n      (, ,)\n      (SBAR (IN while)\n        (S\n          (NP\n            (NP (NNS prices))\n            (PP (IN of)\n              (NP (NN wheat) (NN flour))))\n          (VP (VBD continued)\n            (S\n              (VP (TO to)\n                (VP (VB soar)\n                  (PP (IN in)\n                    (NP (JJ recent) (NNS months))))))\n            (, ,)\n            (S\n              (VP (VBG reaching)\n                (NP (JJ new) (NN record) (NNS highs))\n                (PP (IN in)\n                  (NP (NNP August)))))))))\n    (. .)))'},
#  {'sentence': 'Overall, prices of these food staples in August were more than twice the high levels in August last year and up to 12 times higher than in the corresponding period two years earlier.',
#   'position': [4465, 4647],
#   'golden-entity-mentions': [{'text': 'August',
#     'position': [4506, 4512],
#     'entity-type': 'DATE',
#     'start': 8,
#     'end': 9},
#    {'text': 'August last year',
#     'position': [4553, 4569],
#     'entity-type': 'DATE',
#     'start': 17,
#     'end': 20},
#    {'text': 'up to 12',
#     'position': [4574, 4582],
#     'entity-type': 'CARDINAL',
#     'start': 21,
#     'end': 24},
#    {'text': 'two years earlier',
#     'position': [4629, 4646],
#     'entity-type': 'DATE',
#     'start': 31,
#     'end': 34}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=10/gov=-1',
#    'advmod/dep=0/gov=10',
#    'punct/dep=1/gov=10',
#    'nsubj/dep=2/gov=10',
#    'nsubj/dep=2/gov=25',
#    'case/dep=3/gov=6',
#    'det/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'nmod:of/dep=6/gov=2',
#    'case/dep=7/gov=8',
#    'nmod:in/dep=8/gov=6',
#    'cop/dep=9/gov=10',
#    'case/dep=11/gov=15',
#    'advmod/dep=12/gov=15',
#    'det/dep=13/gov=15',
#    'amod/dep=14/gov=15',
#    'nmod:than/dep=15/gov=10',
#    'case/dep=16/gov=17',
#    'nmod:in/dep=17/gov=15',
#    'amod/dep=18/gov=19',
#    'nmod:tmod/dep=19/gov=15',
#    'cc/dep=20/gov=10',
#    'dep/dep=21/gov=23',
#    'mwe/dep=22/gov=21',
#    'nummod/dep=23/gov=24',
#    'nmod:npmod/dep=24/gov=25',
#    'conj:and/dep=25/gov=10',
#    'case/dep=26/gov=30',
#    'case/dep=27/gov=30',
#    'det/dep=28/gov=30',
#    'amod/dep=29/gov=30',
#    'nmod:in/dep=30/gov=25',
#    'nummod/dep=31/gov=32',
#    'nmod:npmod/dep=32/gov=33',
#    'advmod/dep=33/gov=10',
#    'punct/dep=34/gov=10'],
#   'words': ['Overall',
#    ',',
#    'prices',
#    'of',
#    'these',
#    'food',
#    'staples',
#    'in',
#    'August',
#    'were',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'levels',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'times',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'years',
#    'earlier',
#    '.'],
#   'pos-tags': ['RB',
#    ',',
#    'NNS',
#    'IN',
#    'DT',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    'VBD',
#    'JJR',
#    'IN',
#    'RB',
#    'DT',
#    'JJ',
#    'NNS',
#    'IN',
#    'NNP',
#    'JJ',
#    'NN',
#    'CC',
#    'IN',
#    'TO',
#    'CD',
#    'NNS',
#    'JJR',
#    'IN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'CD',
#    'NNS',
#    'RBR',
#    '.'],
#   'lemma': ['overall',
#    ',',
#    'price',
#    'of',
#    'these',
#    'food',
#    'staple',
#    'in',
#    'August',
#    'be',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'level',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'time',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'year',
#    'earlier',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB Overall))\n    (, ,)\n    (NP\n      (NP (NNS prices))\n      (PP (IN of)\n        (NP\n          (NP (DT these) (NN food) (NNS staples))\n          (PP (IN in)\n            (NP (NNP August))))))\n    (VP (VBD were)\n      (ADJP\n        (ADJP (JJR more)\n          (PP (IN than)\n            (NP\n              (NP (RB twice) (DT the) (JJ high) (NNS levels))\n              (PP (IN in)\n                (NP (NNP August)))\n              (NP-TMP (JJ last) (NN year)))))\n        (CC and)\n        (ADJP\n          (NP\n            (QP (IN up) (TO to) (CD 12))\n            (NNS times))\n          (JJR higher)\n          (PP (IN than)\n            (PP (IN in)\n              (NP (DT the) (JJ corresponding) (NN period)))))\n        (ADVP\n          (NP (CD two) (NNS years))\n          (RBR earlier))))\n    (. .)))'},
#  {'sentence': 'Overall, prices of these food staples in August were more than twice the high levels in August last year and up to 12 times higher than in the corresponding period two years earlier.',
#   'position': [4465, 4647],
#   'golden-entity-mentions': [{'text': 'August',
#     'position': [4506, 4512],
#     'entity-type': 'DATE',
#     'start': 8,
#     'end': 9},
#    {'text': 'August last year',
#     'position': [4553, 4569],
#     'entity-type': 'DATE',
#     'start': 17,
#     'end': 20},
#    {'text': 'up to 12',
#     'position': [4574, 4582],
#     'entity-type': 'CARDINAL',
#     'start': 21,
#     'end': 24},
#    {'text': 'two years earlier',
#     'position': [4629, 4646],
#     'entity-type': 'DATE',
#     'start': 31,
#     'end': 34}],
#   'golden-event-mentions': [],
#   'stanford-colcc': ['ROOT/dep=10/gov=-1',
#    'advmod/dep=0/gov=10',
#    'punct/dep=1/gov=10',
#    'nsubj/dep=2/gov=10',
#    'nsubj/dep=2/gov=25',
#    'case/dep=3/gov=6',
#    'det/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'nmod:of/dep=6/gov=2',
#    'case/dep=7/gov=8',
#    'nmod:in/dep=8/gov=6',
#    'cop/dep=9/gov=10',
#    'case/dep=11/gov=15',
#    'advmod/dep=12/gov=15',
#    'det/dep=13/gov=15',
#    'amod/dep=14/gov=15',
#    'nmod:than/dep=15/gov=10',
#    'case/dep=16/gov=17',
#    'nmod:in/dep=17/gov=15',
#    'amod/dep=18/gov=19',
#    'nmod:tmod/dep=19/gov=15',
#    'cc/dep=20/gov=10',
#    'dep/dep=21/gov=23',
#    'mwe/dep=22/gov=21',
#    'nummod/dep=23/gov=24',
#    'nmod:npmod/dep=24/gov=25',
#    'conj:and/dep=25/gov=10',
#    'case/dep=26/gov=30',
#    'case/dep=27/gov=30',
#    'det/dep=28/gov=30',
#    'amod/dep=29/gov=30',
#    'nmod:in/dep=30/gov=25',
#    'nummod/dep=31/gov=32',
#    'nmod:npmod/dep=32/gov=33',
#    'advmod/dep=33/gov=10',
#    'punct/dep=34/gov=10'],
#   'words': ['Overall',
#    ',',
#    'prices',
#    'of',
#    'these',
#    'food',
#    'staples',
#    'in',
#    'August',
#    'were',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'levels',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'times',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'years',
#    'earlier',
#    '.'],
#   'pos-tags': ['RB',
#    ',',
#    'NNS',
#    'IN',
#    'DT',
#    'NN',
#    'NNS',
#    'IN',
#    'NNP',
#    'VBD',
#    'JJR',
#    'IN',
#    'RB',
#    'DT',
#    'JJ',
#    'NNS',
#    'IN',
#    'NNP',
#    'JJ',
#    'NN',
#    'CC',
#    'IN',
#    'TO',
#    'CD',
#    'NNS',
#    'JJR',
#    'IN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'CD',
#    'NNS',
#    'RBR',
#    '.'],
#   'lemma': ['overall',
#    ',',
#    'price',
#    'of',
#    'these',
#    'food',
#    'staple',
#    'in',
#    'August',
#    'be',
#    'more',
#    'than',
#    'twice',
#    'the',
#    'high',
#    'level',
#    'in',
#    'August',
#    'last',
#    'year',
#    'and',
#    'up',
#    'to',
#    '12',
#    'time',
#    'higher',
#    'than',
#    'in',
#    'the',
#    'corresponding',
#    'period',
#    'two',
#    'year',
#    'earlier',
#    '.'],
#   'parse': '(ROOT\n  (S\n    (ADVP (RB Overall))\n    (, ,)\n    (NP\n      (NP (NNS prices))\n      (PP (IN of)\n        (NP\n          (NP (DT these) (NN food) (NNS staples))\n          (PP (IN in)\n            (NP (NNP August))))))\n    (VP (VBD were)\n      (ADJP\n        (ADJP (JJR more)\n          (PP (IN than)\n            (NP\n              (NP (RB twice) (DT the) (JJ high) (NNS levels))\n              (PP (IN in)\n                (NP (NNP August)))\n              (NP-TMP (JJ last) (NN year)))))\n        (CC and)\n        (ADJP\n          (NP\n            (QP (IN up) (TO to) (CD 12))\n            (NNS times))\n          (JJR higher)\n          (PP (IN than)\n            (PP (IN in)\n              (NP (DT the) (JJ corresponding) (NN period)))))\n        (ADVP\n          (NP (CD two) (NNS years))\n          (RBR earlier))))\n    (. .)))'}]

# %%
##fix the above function so it returns all of the already existing values

# %%
with open('test_this.json', 'w') as f:
    json.dump(check_it, f, indent=2)
